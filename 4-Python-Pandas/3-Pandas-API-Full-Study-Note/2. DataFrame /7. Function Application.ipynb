# %% [markdown]
# # 7. Function Application

# %% [markdown]
# ### Examples

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Load sample datasets
tips = sns.load_dataset('tips')
flights = sns.load_dataset('flights')
titanic = sns.load_dataset('titanic')
iris = sns.load_dataset('iris')

print("Datasets loaded:")
print(f"Tips shape: {tips.shape}")
print(f"Flights shape: {flights.shape}")
print(f"Titanic shape: {titanic.shape}")
print(f"Iris shape: {iris.shape}")
# Out:
# Datasets loaded:
# Tips shape: (244, 7)
# Flights shape: (144, 3)
# Titanic shape: (891, 15)
# Iris shape: (150, 5)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Apply single function to all numeric columns
numeric_cols = tips.select_dtypes(include=[np.number])

print("Mean of numeric columns:")
print(numeric_cols.apply(np.mean))
# Out:
# Mean of numeric columns:
# total_bill    19.785943
# tip            2.998279
# size           2.569672
# dtype: float64

# %%
print("\nStandard deviation of numeric columns:")
print(numeric_cols.apply(np.std))
# Out:
# Standard deviation of numeric columns:
# total_bill    8.884151
# tip           1.380800
# size          0.949149
# dtype: float64

# %%
# Apply custom function
def coefficient_of_variation(series):
    """Calculate coefficient of variation (CV = std/mean)"""
    return series.std() / series.mean()

print("\nCoefficient of Variation:")
print(numeric_cols.apply(coefficient_of_variation))
# Out:
# Coefficient of Variation:
# total_bill    0.449936
# tip           0.461478
# size          0.370125
# dtype: float64

# %%
# Apply lambda function
print("\nRange (max - min):")
print(numeric_cols.apply(lambda x: x.max() - x.min()))
# Out:
# Range (max - min):
# total_bill    47.74
# tip            9.00
# size           5.00
# dtype: float64

# %%
# Multiple functions at once
print("\nMultiple statistics:")
print(numeric_cols.apply(['mean', 'std', 'min', 'max']))
# Out:
# Multiple statistics:
#       total_bill        tip      size
# mean   19.785943   2.998279  2.569672
# std     8.902412   1.383638  0.951100
# min     3.070000   1.000000  1.000000
# max    50.810000  10.000000  6.000000

# %%
# Apply to each column
column_stats = titanic.apply(lambda x: x.nunique(), axis=0)
print("Unique values per column:")
print(column_stats)
# Out:
# Unique values per column:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
# Multiple functions at once
print("\nMultiple statistics:")
print(numeric_cols.apply(['mean', 'std', 'min', 'max']))
# Out:
# Multiple statistics:
#       total_bill        tip      size
# mean   19.785943   2.998279  2.569672
# std     8.902412   1.383638  0.951100
# min     3.070000   1.000000  1.000000
# max    50.810000  10.000000  6.000000

# %% [markdown]
# ### Work Sheet

# %%
file = r'/Users/teslim/TeslimWorkSpace/TheData/The_data_grp1.xlsx'

# %%
uk_pg4 = pd.read_excel(file, sheet_name='uk_polls', engine='openpyxl')
uk_pg4.head()
# Out:
#   Constituency code              Constituency  \
# 0         E14001063                 Aldershot
# 1         E14001064       Aldridge-Brownhills
# 2         E14001065  Altrincham and Sale West
# 3         E14001066              Amber Valley
# 4         E14001067   Arundel and South Downs
#
#                             Sub-region         Region  \
# 0     Berkshire, Hampshire, and Surrey     South East
# 1  Staffordshire and the Black Country  West Midlands
# 2                   Greater Manchester     North West
# 3                           Derbyshire  East Midlands
# 4          East Sussex and West Sussex     South East
#
#   GE2019 Implied results: MP name GE2019 Implied results: Party  \
# 0                  Leo Docherty                             CON
# 1                  Wendy Morton                             CON
# 2                  Graham Brady                             CON
# 3                   Nigel Mills                             CON
# 4               Andrew Griffith                             CON
#
#    GE2019 Implied results: Electorate  GE2019 Implied results: Majority  \
# 0                               77531                             18174
# 1                               72512                             22282
# 2                               73107                              6138
# 3                               70045                             16897
# 4                               76681                             22986
#
#    Poll: Environment/climate change important issues at next election (%)  \
# 0                                               0.71
# 1                                               0.61
# 2                                               0.64
# 3                                               0.66
# 4                                               0.77
#
#    Local green economy: GVA (£m)  ...  \
# 0                          152.4  ...
# 1                           54.3  ...
# 2                          150.1  ...
# 3                           53.1  ...
# 4                           58.6  ...
#
#    Tree canopy cover: Proportion of constituency (%)  \
# 0                                           0.313080
# 1                                           0.133292
# 2                                           0.135244
# 3                                           0.140897
# 4                                           0.281761
#
#    Tree canopy cover: Neighbourhoods with less than 10% tree canopy (No.)  \
# 0                                                7.0
# 1                                               28.0
# 2                                               22.0
# 3                                               18.0
# 4                                                6.0
#
#    Tree canopy cover: Neighbourhoods with less than 10% tree canopy (%)  \
# 0                                           0.101449
# 1                                           0.466667
# 2                                           0.372881
# 3                                           0.315789
# 4                                           0.101695
#
#    Households without access to private vehicles (No.)  \
# 0                                               7080
# 1                                               6663
# 2                                               6211
# 3                                               7478
# 4                                               4071
#
#    Households without access to private vehicles (%)  \
# 0                                           0.152219
# 1                                           0.163533
# 2                                           0.149217
# 3                                           0.181898
# 4                                           0.093275
#
#    Bus services: Frequency per hour (2010)  \
# 0                                    33.55
# 1                                    22.72
# 2                                    15.66
# 3                                    25.50
# 4                                     4.76
#
#    Bus services: Frequency per hour (2023)  \
# 0                                     9.09
# 1                                    14.66
# 2                                     9.55
# 3                                     9.97
# 4                                     2.56
#
#    Bus services: Change in frequency of service 2010-2023 (%)  \
# 0                                            -0.7291
# 1                                            -0.3547
# 2                                            -0.3901
# 3                                            -0.6090
# 4                                            -0.4641
#
#    Sewage overflows: Total number of spills within constituency  \
# 0                                                 64
# 1                                                 96
# 2                                               1053
# 3                                               2322
# 4                                               2282
#
#    Sewage overflows: Total duration of spills within constituency (hrs)
# 0                                             366.75
# 1                                             299.62
# 2                                            5740.32
# 3                                           15596.86
# 4                                           34098.61
#
# [5 rows x 48 columns]

# %%
import sys 

# Step 1: View Python's default module search paths
print("🔍 Current Python Module Search Paths:")
for path in sys.path:
    print(path)
 
# Step 2: Add your custom module directory to sys.path  
custom_module_path = '/Users/teslim/MyModules/teslim_data_utils'

# Check to avoid adding duplicates
if custom_module_path not in sys.path:
    sys.path.append(custom_module_path)
    print(f"\n✅ Custom module path added: {custom_module_path}")
else:
    print(f"\n⚠️ Path already exists: {custom_module_path}")
# Out:
# 🔍 Current Python Module Search Paths:
# /Users/teslim/anaconda3/envs/machine-learning-env/lib/python310.zip
# /Users/teslim/anaconda3/envs/machine-learning-env/lib/python3.10
# /Users/teslim/anaconda3/envs/machine-learning-env/lib/python3.10/lib-dynload
#
# /Users/teslim/anaconda3/envs/machine-learning-env/lib/python3.10/site-packages
# /Users/teslim/anaconda3/envs/machine-learning-env/lib/python3.10/site-packages/setuptools/_vendor
#
# ✅ Custom module path added: /Users/teslim/MyModules/teslim_data_utils

# %%
import sys
sys.path.append('/Users/teslim/MyModules')

# Now try importing
from teslim_data_utils import (
    clean_column_headers,
    clean_numeric_column, 
    remove_duplicates,
    fill_missing,
    remove_outliers_iqr,
    clean_text_column
)

# %%
# Clean messy column names (removes spaces, special chars, etc.)
df_clean = clean_column_headers(uk_pg4)
df_clean.columns.tolist()
# Out:
# ['constituency_code',
#  'constituency',
#  'subregion',
#  'region',
#  'ge2019_implied_results_mp_name',
#  'ge2019_implied_results_party',
#  'ge2019_implied_results_electorate',
#  'ge2019_implied_results_majority',
#  'poll_environmentclimate_change_important_issues_at_next_election',
#  'local_green_economy_gva_m',
#  'local_green_economy_of_total_gva',
#  'local_green_economy_fte_jobs',
#  'local_green_economy_fte_jobs_1',
#  'energy_crisis_hotspots_neighbourhoods_no',
#  'energy_crisis_hotspots_neighbourhoods',
#  'energy_crisis_hotspots_average_energy_bill',
#  'epcs_homes_in_bands_abc',
#  'epcs_homes_in_bands_defg',
#  'epcs_homes_in_bands_abc_no',
#  'epcs_homes_in_bands_defg_no',
#  'epcs_loft_insulation_recommendations',
#  'epcs_cavity_wall_insulation_recommendations',
#  'epcs_solid_wall_insulation_recommendations',
#  'epcs_loft_insulation_recommendations_no',
#  'epcs_cavity_insulation_recommendations_no',
#  'epcs_solid_insulation_recommendations_no',
#  'respiratory_disease_prevalence',
#  'air_pollution_neighbourhoods_where_no2_above_who_guidelines_no',
#  'air_pollution_neighbourhoods_where_pm25_above_who_guidelines_no',
#  'air_pollution_neighbourhoods_where_no2_above_who_guidelines',
#  'air_pollution_neighbourhoods_where_pm25_above_who_guidelines',
#  'extreme_heat_neighbourhoods_at_risk_no',
#  'extreme_heat_neighbourhoods_at_risk',
#  'flooding_neighbourhoods_at_risk_no',
#  'flooding_neighbourhoods_at_risk',
#  'accessible_green_space_m2_per_person',
#  'accessible_green_space_rating_compared_across_all_constituencies',
#  'tree_canopy_cover_hectares',
#  'tree_canopy_cover_proportion_of_constituency',
#  'tree_canopy_cover_neighbourhoods_with_less_than_10_tree_canopy_no',
#  'tree_canopy_cover_neighbourhoods_with_less_than_10_tree_canopy',
#  'households_without_access_to_private_vehicles_no',
#  'households_without_access_to_private_vehicles',
#  'bus_services_frequency_per_hour_2010',
#  'bus_services_frequency_per_hour_2023',
#  'bus_services_change_in_frequency_of_service_20102023',
#  'sewage_overflows_total_number_of_spills_within_constituency',
#  'sewage_overflows_total_duration_of_spills_within_constituency_hrs']

# %%
df_clean
# Out:
#     constituency_code              constituency  \
# 0           E14001063                 Aldershot
# 1           E14001064       Aldridge-Brownhills
# 2           E14001065  Altrincham and Sale West
# 3           E14001066              Amber Valley
# 4           E14001067   Arundel and South Downs
# ..                ...                       ...
# 570         W07000108              Swansea West
# 571         W07000109                   Torfaen
# 572         W07000110         Vale of Glamorgan
# 573         W07000111                   Wrexham
# 574         W07000112                  Ynys Môn
#
#                                subregion         region  \
# 0       Berkshire, Hampshire, and Surrey     South East
# 1    Staffordshire and the Black Country  West Midlands
# 2                     Greater Manchester     North West
# 3                             Derbyshire  East Midlands
# 4            East Sussex and West Sussex     South East
# ..                                   ...            ...
# 570                                Wales          Wales
# 571                                Wales          Wales
# 572                                Wales          Wales
# 573                                Wales          Wales
# 574                                Wales          Wales
#
#     ge2019_implied_results_mp_name ge2019_implied_results_party  \
# 0                   Leo Docherty                            CON
# 1                   Wendy Morton                            CON
# 2                   Graham Brady                            CON
# 3                    Nigel Mills                            CON
# 4                Andrew Griffith                            CON
# ..                             ...                          ...
# 570               Geraint Davies                            LAB
# 571          Nick Thomas-Symonds                            LAB
# 572                  Alun Cairns                            CON
# 573               Sarah Atherton                            CON
# 574             Virginia Crosbie                            CON
#
#      ge2019_implied_results_electorate  ge2019_implied_results_majority  \
# 0                                77531                            18174
# 1                                72512                            22282
# 2                                73107                             6138
# 3                                70045                            16897
# 4                                76681                            22986
# ..                                 ...                              ...
# 570                              73780                            11508
# 571                              70218                             3392
# 572                              70148                             2666
# 573                              70870                             4091
# 574                              51927                             1968
#
#      poll_environmentclimate_change_important_issues_at_next_election  \
# 0                                                 0.71
# 1                                                 0.61
# 2                                                 0.64
# 3                                                 0.66
# 4                                                 0.77
# ..                                                 ...
# 570                                               0.68
# 571                                               0.62
# 572                                               0.72
# 573                                               0.58
# 574                                               0.64
#
#      local_green_economy_gva_m  ...  \
# 0                        152.4  ...
# 1                         54.3  ...
# 2                        150.1  ...
# 3                         53.1  ...
# 4                         58.6  ...
# ..                         ...  ...
# 570                       79.4  ...
# 571                       72.3  ...
# 572                       37.6  ...
# 573                      143.0  ...
# 574                       40.4  ...
#
#      tree_canopy_cover_proportion_of_constituency  \
# 0                                        0.313080
# 1                                        0.133292
# 2                                        0.135244
# 3                                        0.140897
# 4                                        0.281761
# ..                                            ...
# 570                                           NaN
# 571                                           NaN
# 572                                           NaN
# 573                                           NaN
# 574                                           NaN
#
#      tree_canopy_cover_neighbourhoods_with_less_than_10_tree_canopy_no  \
# 0                                                  7.0
# 1                                                 28.0
# 2                                                 22.0
# 3                                                 18.0
# 4                                                  6.0
# ..                                                 ...
# 570                                                NaN
# 571                                                NaN
# 572                                                NaN
# 573                                                NaN
# 574                                                NaN
#
#      tree_canopy_cover_neighbourhoods_with_less_than_10_tree_canopy  \
# 0                                             0.101449
# 1                                             0.466667
# 2                                             0.372881
# 3                                             0.315789
# 4                                             0.101695
# ..                                                 ...
# 570                                                NaN
# 571                                                NaN
# 572                                                NaN
# 573                                                NaN
# 574                                                NaN
#
#      households_without_access_to_private_vehicles_no  \
# 0                                                7080
# 1                                                6663
# 2                                                6211
# 3                                                7478
# 4                                                4071
# ..                                                ...
# 570                                             14476
# 571                                              7897
# 572                                              7028
# 573                                              8035
# 574                                              4621
#
#      households_without_access_to_private_vehicles  \
# 0                                         0.152219
# 1                                         0.163533
# 2                                         0.149217
# 3                                         0.181898
# 4                                         0.093275
# ..                                             ...
# 570                                       0.312346
# 571                                       0.196248
# 572                                       0.171089
# 573                                       0.190016
# 574                                       0.149886
#
#      bus_services_frequency_per_hour_2010  \
# 0                                   33.55
# 1                                   22.72
# 2                                   15.66
# 3                                   25.50
# 4                                    4.76
# ..                                    ...
# 570                                 32.89
# 571                                 22.95
# 572                                 17.32
# 573                                 19.72
# 574                                  7.30
#
#      bus_services_frequency_per_hour_2023  \
# 0                                    9.09
# 1                                   14.66
# 2                                    9.55
# 3                                    9.97
# 4                                    2.56
# ..                                    ...
# 570                                 21.40
# 571                                 10.39
# 572                                  8.17
# 573                                 11.34
# 574                                  3.54
#
#      bus_services_change_in_frequency_of_service_20102023  \
# 0                                              -0.7291
# 1                                              -0.3547
# 2                                              -0.3901
# 3                                              -0.6090
# 4                                              -0.4641
# ..                                                 ...
# 570                                            -0.3493
# 571                                            -0.5469
# 572                                            -0.5284
# 573                                            -0.4250
# 574                                            -0.5153
#
#      sewage_overflows_total_number_of_spills_within_constituency  \
# 0                                                   64
# 1                                                   96
# 2                                                 1053
# 3                                                 2322
# 4                                                 2282
# ..                                                 ...
# 570                                                998
# 571                                               3182
# 572                                               2049
# 573                                               1665
# 574                                               2983
#
#      sewage_overflows_total_duration_of_spills_within_constituency_hrs
# 0                                               366.75
# 1                                               299.62
# 2                                              5740.32
# 3                                             15596.86
# 4                                             34098.61
# ..                                                 ...
# 570                                            4209.50
# 571                                           19765.50
# 572                                           25562.50
# 573                                           10547.75
# 574                                           27077.25
#
# [575 rows x 48 columns]

# %%
df_clean = clean_text_column(df_clean)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df_clean = clean_text_column(df_clean)
#
# TypeError: clean_text_column() missing 1 required positional argument: 'column_name'

# %%
def change_column_header(df):
    df.columns = df.columns.str.lower()
    df.columns = df.columns.str.replace(" ", "_")
    df.columns = df.columns.str.strip()
    return df


# calling the function 
change_column_header(uk_pg4)
# Out:
#     constituency_code  ... sewage_overflows:_total_duration_of_spills_within_constituency_(hrs)
# 0           E14001063  ...                                             366.75
# 1           E14001064  ...                                             299.62
# 2           E14001065  ...                                            5740.32
# 3           E14001066  ...                                           15596.86
# 4           E14001067  ...                                           34098.61
# ..                ...  ...                                                ...
# 570         W07000108  ...                                            4209.50
# 571         W07000109  ...                                           19765.50
# 572         W07000110  ...                                           25562.50
# 573         W07000111  ...                                           10547.75
# 574         W07000112  ...                                           27077.25
#
# [575 rows x 48 columns]

# %%
uk_pg4.columns.to_list()
# Out:
# ['constituency_code',
#  'constituency',
#  'sub-region',
#  'region',
#  'ge2019_implied_results:_mp_name',
#  'ge2019_implied_results:_party',
#  'ge2019_implied_results:_electorate',
#  'ge2019_implied_results:_majority',
#  'poll:_environment/climate_change_important_issues_at_next_election_(%)',
#  'local_green_economy:_gva_(£m)',
#  'local_green_economy:_%_of_total_gva',
#  'local_green_economy:_fte_jobs',
#  'local_green_economy:_fte_jobs_(%)',
#  'energy_crisis_hotspots:_neighbourhoods_(no.)',
#  'energy_crisis_hotspots:_neighbourhoods_(%)',
#  'energy_crisis_hotspots:_average_energy_bill_(£)',
#  'epcs:_homes_in_bands_a/b/c_(%)',
#  'epcs:_homes_in_bands_d/e/f/g_(%)',
#  'epcs:_homes_in_bands_a/b/c_(no.)',
#  'epcs:_homes_in_bands_d/e/f/g_(no.)',
#  'epcs:_loft_insulation_recommendations_(%)',
#  'epcs:_cavity_wall_insulation_recommendations_(%)',
#  'epcs:_solid_wall_insulation_recommendations_(%)',
#  'epcs:_loft_insulation_recommendations_(no.)',
#  'epcs:_cavity_insulation_recommendations_(no.)',
#  'epcs:_solid_insulation_recommendations_(no.)',
#  'respiratory_disease_prevalence_(%)',
#  'air_pollution:_neighbourhoods_where_no2_above_who_guidelines_(no.)',
#  'air_pollution:_neighbourhoods_where_pm2.5_above_who_guidelines_(no.)',
#  'air_pollution:_neighbourhoods_where_no2_above_who_guidelines_(%)',
#  'air_pollution:_neighbourhoods_where_pm2.5_above_who_guidelines_(%)',
#  'extreme_heat:_neighbourhoods_at_risk_(no.)',
#  'extreme_heat:_neighbourhoods_at_risk_(%)',
#  'flooding:_neighbourhoods_at_risk_(no.)',
#  'flooding:_neighbourhoods_at_risk_(%)',
#  'accessible_green_space:_m2_per_person',
#  'accessible_green_space:_rating_(compared_across_all_constituencies)',
#  'tree_canopy_cover:_hectares',
#  'tree_canopy_cover:_proportion_of_constituency_(%)',
#  'tree_canopy_cover:_neighbourhoods_with_less_than_10%_tree_canopy_(no.)',
#  'tree_canopy_cover:_neighbourhoods_with_less_than_10%_tree_canopy_(%)',
#  'households_without_access_to_private_vehicles_(no.)',
#  'households_without_access_to_private_vehicles_(%)',
#  'bus_services:_frequency_per_hour_(2010)',
#  'bus_services:_frequency_per_hour_(2023)',
#  'bus_services:_change_in_frequency_of_service_2010-2023_(%)',
#  'sewage_overflows:_total_number_of_spills_within_constituency',
#  'sewage_overflows:_total_duration_of_spills_within_constituency_(hrs)']

# %%
uk_pg4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 575 entries, 0 to 574
# Data columns (total 48 columns):
#  #   Column                                                                  Non-Null Count  Dtype
# ---  ------                                                                  --------------  -----
#  0   constituency_code                                                       575 non-null    object
#  1   constituency                                                            575 non-null    object
#  2   sub-region                                                              575 non-null    object
#  3   region                                                                  575 non-null    object
#  4   ge2019_implied_results:_mp_name                                         575 non-null    object
#  5   ge2019_implied_results:_party                                           575 non-null    object
#  6   ge2019_implied_results:_electorate                                      575 non-null    int64
#  7   ge2019_implied_results:_majority                                        575 non-null    int64
#  8   poll:_environment/climate_change_important_issues_at_next_election_(%)  575 non-null    float64
#  9   local_green_economy:_gva_(£m)                                           575 non-null    float64
#  10  local_green_economy:_%_of_total_gva                                     575 non-null    float64
#  11  local_green_economy:_fte_jobs                                           575 non-null    float64
#  12  local_green_economy:_fte_jobs_(%)                                       575 non-null    float64
#  13  energy_crisis_hotspots:_neighbourhoods_(no.)                            575 non-null    int64
#  14  energy_crisis_hotspots:_neighbourhoods_(%)                              575 non-null    float64
#  15  energy_crisis_hotspots:_average_energy_bill_(£)                         573 non-null    float64
#  16  epcs:_homes_in_bands_a/b/c_(%)                                          575 non-null    float64
#  17  epcs:_homes_in_bands_d/e/f/g_(%)                                        575 non-null    float64
#  18  epcs:_homes_in_bands_a/b/c_(no.)                                        575 non-null    int64
#  19  epcs:_homes_in_bands_d/e/f/g_(no.)                                      575 non-null    int64
#  20  epcs:_loft_insulation_recommendations_(%)                               575 non-null    float64
#  21  epcs:_cavity_wall_insulation_recommendations_(%)                        575 non-null    float64
#  22  epcs:_solid_wall_insulation_recommendations_(%)                         575 non-null    float64
#  23  epcs:_loft_insulation_recommendations_(no.)                             575 non-null    int64
#  24  epcs:_cavity_insulation_recommendations_(no.)                           575 non-null    int64
#  25  epcs:_solid_insulation_recommendations_(no.)                            575 non-null    int64
#  26  respiratory_disease_prevalence_(%)                                      543 non-null    float64
#  27  air_pollution:_neighbourhoods_where_no2_above_who_guidelines_(no.)      575 non-null    int64
#  28  air_pollution:_neighbourhoods_where_pm2.5_above_who_guidelines_(no.)    575 non-null    int64
#  29  air_pollution:_neighbourhoods_where_no2_above_who_guidelines_(%)        575 non-null    float64
#  30  air_pollution:_neighbourhoods_where_pm2.5_above_who_guidelines_(%)      575 non-null    float64
#  31  extreme_heat:_neighbourhoods_at_risk_(no.)                              575 non-null    int64
#  32  extreme_heat:_neighbourhoods_at_risk_(%)                                575 non-null    float64
#  33  flooding:_neighbourhoods_at_risk_(no.)                                  575 non-null    int64
#  34  flooding:_neighbourhoods_at_risk_(%)                                    575 non-null    float64
#  35  accessible_green_space:_m2_per_person                                   543 non-null    float64
#  36  accessible_green_space:_rating_(compared_across_all_constituencies)     543 non-null    object
#  37  tree_canopy_cover:_hectares                                             543 non-null    float64
#  38  tree_canopy_cover:_proportion_of_constituency_(%)                       543 non-null    float64
#  39  tree_canopy_cover:_neighbourhoods_with_less_than_10%_tree_canopy_(no.)  543 non-null    float64
#  40  tree_canopy_cover:_neighbourhoods_with_less_than_10%_tree_canopy_(%)    543 non-null    float64
#  41  households_without_access_to_private_vehicles_(no.)                     575 non-null    int64
#  42  households_without_access_to_private_vehicles_(%)                       575 non-null    float64
#  43  bus_services:_frequency_per_hour_(2010)                                 575 non-null    float64
#  44  bus_services:_frequency_per_hour_(2023)                                 575 non-null    float64
#  45  bus_services:_change_in_frequency_of_service_2010-2023_(%)              575 non-null    float64
#  46  sewage_overflows:_total_number_of_spills_within_constituency            575 non-null    int64
#  47  sewage_overflows:_total_duration_of_spills_within_constituency_(hrs)    575 non-null    float64
# dtypes: float64(27), int64(14), object(7)
# memory usage: 215.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 575 entries, 0 to 574
# Data columns (total 48 columns):
#  #   Column                                                                  Non-Null Count  Dtype
# ---  ------                                                                  --------------  -----
#  0   constituency_code                                                       575 non-null    object
#  1   constituency                                                            575 non-null    object
#  2   sub-region                                                              575 non-null    object
#  3   region                                                                  575 non-null    object
#  4   ge2019_implied_results:_mp_name                                         575 non-null    object
#  5   ge2019_implied_results:_party                                           575 non-null    object
#  6   ge2019_implied_results:_electorate                                      575 non-null    int64
#  7   ge2019_implied_results:_majority                                        575 non-null    int64
#  8   poll:_environment/climate_change_important_issues_at_next_election_(%)  575 non-null    float64
#  9   local_green_economy:_gva_(£m)                                           575 non-null    float64
#  10  local_green_economy:_%_of_total_gva                                     575 non-null    float64
#  11  local_green_economy:_fte_jobs                                           575 non-null    float64
#  12  local_green_economy:_fte_jobs_(%)                                       575 non-null    float64
#  13  energy_crisis_hotspots:_neighbourhoods_(no.)                            575 non-null    int64
#  14  energy_crisis_hotspots:_neighbourhoods_(%)                              575 non-null    float64
#  15  energy_crisis_hotspots:_average_energy_bill_(£)                         573 non-null    float64
#  16  epcs:_homes_in_bands_a/b/c_(%)                                          575 non-null    float64
#  17  epcs:_homes_in_bands_d/e/f/g_(%)                                        575 non-null    float64
#  18  epcs:_homes_in_bands_a/b/c_(no.)                                        575 non-null    int64
#  19  epcs:_homes_in_bands_d/e/f/g_(no.)                                      575 non-null    int64
#  20  epcs:_loft_insulation_recommendations_(%)                               575 non-null    float64
#  21  epcs:_cavity_wall_insulation_recommendations_(%)                        575 non-null    float64
#  22  epcs:_solid_wall_insulation_recommendations_(%)                         575 non-null    float64
#  23  epcs:_loft_insulation_recommendations_(no.)                             575 non-null    int64
#  24  epcs:_cavity_insulation_recommendations_(no.)                           575 non-null    int64
#  25  epcs:_solid_insulation_recommendations_(no.)                            575 non-null    int64
#  26  respiratory_disease_prevalence_(%)                                      543 non-null    float64
#  27  air_pollution:_neighbourhoods_where_no2_above_who_guidelines_(no.)      575 non-null    int64
#  28  air_pollution:_neighbourhoods_where_pm2.5_above_who_guidelines_(no.)    575 non-null    int64
#  29  air_pollution:_neighbourhoods_where_no2_above_who_guidelines_(%)        575 non-null    float64
#  30  air_pollution:_neighbourhoods_where_pm2.5_above_who_guidelines_(%)      575 non-null    float64
#  31  extreme_heat:_neighbourhoods_at_risk_(no.)                              575 non-null    int64
#  32  extreme_heat:_neighbourhoods_at_risk_(%)                                575 non-null    float64
#  33  flooding:_neighbourhoods_at_risk_(no.)                                  575 non-null    int64
#  34  flooding:_neighbourhoods_at_risk_(%)                                    575 non-null    float64
#  35  accessible_green_space:_m2_per_person                                   543 non-null    float64
#  36  accessible_green_space:_rating_(compared_across_all_constituencies)     543 non-null    object
#  37  tree_canopy_cover:_hectares                                             543 non-null    float64
#  38  tree_canopy_cover:_proportion_of_constituency_(%)                       543 non-null    float64
#  39  tree_canopy_cover:_neighbourhoods_with_less_than_10%_tree_canopy_(no.)  543 non-null    float64
#  40  tree_canopy_cover:_neighbourhoods_with_less_than_10%_tree_canopy_(%)    543 non-null    float64
#  41  households_without_access_to_private_vehicles_(no.)                     575 non-null    int64
#  42  households_without_access_to_private_vehicles_(%)                       575 non-null    float64
#  43  bus_services:_frequency_per_hour_(2010)                                 575 non-null    float64
#  44  bus_services:_frequency_per_hour_(2023)                                 575 non-null    float64
#  45  bus_services:_change_in_frequency_of_service_2010-2023_(%)              575 non-null    float64
#  46  sewage_overflows:_total_number_of_spills_within_constituency            575 non-null    int64
#  47  sewage_overflows:_total_duration_of_spills_within_constituency_(hrs)    575 non-null    float64
# dtypes: float64(27), int64(14), object(7)
# memory usage: 215.8+ KB

# %%
numerical_columns = uk_pg4.select_dtypes(include=['float64', 'int64'])
categorical_columns = uk_pg4.select_dtypes(exclude=['float64', 'int64'])

# %%
numerical_columns
# Out:
#      ge2019_implied_results:_electorate  ...  sewage_overflows:_total_duration_of_spills_within_constituency_(hrs)
# 0                                 77531  ...                                             366.75
# 1                                 72512  ...                                             299.62
# 2                                 73107  ...                                            5740.32
# 3                                 70045  ...                                           15596.86
# 4                                 76681  ...                                           34098.61
# ..                                  ...  ...                                                ...
# 570                               73780  ...                                            4209.50
# 571                               70218  ...                                           19765.50
# 572                               70148  ...                                           25562.50
# 573                               70870  ...                                           10547.75
# 574                               51927  ...                                           27077.25
#
# [575 rows x 41 columns]

# %%
numerical_columns.apply([max, min], axis=0).T
# Out:
#                                                               max           min
# ge2019_implied_results:_electorate                   92578.000000  51927.000000
# ge2019_implied_results:_majority                     34557.000000     27.000000
# poll:_environment/climate_change_important_issu...       0.840000      0.520000
# local_green_economy:_gva_(£m)                         3095.900000     23.100000
# local_green_economy:_%_of_total_gva                      0.158600      0.012400
# local_green_economy:_fte_jobs                        29257.800000    404.000000
# local_green_economy:_fte_jobs_(%)                        0.059900      0.016200
# energy_crisis_hotspots:_neighbourhoods_(no.)            69.000000      0.000000
# energy_crisis_hotspots:_neighbourhoods_(%)               0.884615      0.000000
# energy_crisis_hotspots:_average_energy_bill_(£)       2920.000000   2270.000000
# epcs:_homes_in_bands_a/b/c_(%)                           0.822592      0.204969
# epcs:_homes_in_bands_d/e/f/g_(%)                         0.795031      0.177408
# epcs:_homes_in_bands_a/b/c_(no.)                     55414.000000   8411.000000
# epcs:_homes_in_bands_d/e/f/g_(no.)                   42816.000000  11951.000000
# epcs:_loft_insulation_recommendations_(%)                0.319259      0.044810
# epcs:_cavity_wall_insulation_recommendations_(%)         0.443585      0.051242
# epcs:_solid_wall_insulation_recommendations_(%)          0.679896      0.014613
# epcs:_loft_insulation_recommendations_(no.)          14080.000000   3020.000000
# epcs:_cavity_insulation_recommendations_(no.)        21520.000000   2180.000000
# epcs:_solid_insulation_recommendations_(no.)         51150.000000    730.000000
# respiratory_disease_prevalence_(%)                       0.119135      0.044739
# air_pollution:_neighbourhoods_where_no2_above_w...      94.000000      0.000000
# air_pollution:_neighbourhoods_where_pm2.5_above...      94.000000      0.000000
# air_pollution:_neighbourhoods_where_no2_above_w...       1.000000      0.000000
# air_pollution:_neighbourhoods_where_pm2.5_above...       1.000000      0.000000
# extreme_heat:_neighbourhoods_at_risk_(no.)              94.000000      0.000000
# extreme_heat:_neighbourhoods_at_risk_(%)                 1.000000      0.000000
# flooding:_neighbourhoods_at_risk_(no.)                  91.000000      0.000000
# flooding:_neighbourhoods_at_risk_(%)                     1.000000      0.000000
# accessible_green_space:_m2_per_person                10583.600000      3.000000
# tree_canopy_cover:_hectares                          39287.345709     83.504810
# tree_canopy_cover:_proportion_of_constituency_(%)        0.382821      0.019634
# tree_canopy_cover:_neighbourhoods_with_less_tha...      65.000000      0.000000
# tree_canopy_cover:_neighbourhoods_with_less_tha...       0.984848      0.000000
# households_without_access_to_private_vehicles_(...   41009.000000   3172.000000
# households_without_access_to_private_vehicles_(%)        0.698442      0.075865
# bus_services:_frequency_per_hour_(2010)                288.790000      3.080000
# bus_services:_frequency_per_hour_(2023)                199.510000      1.450000
# bus_services:_change_in_frequency_of_service_20...       0.703700     -0.818100
# sewage_overflows:_total_number_of_spills_within...   12124.000000      0.000000
# sewage_overflows:_total_duration_of_spills_with...  114775.500000      0.000000

# %%
numerical_columns.apply(np.std, axis=0)
# Out:
# ge2019_implied_results:_electorate                                         3075.604101
# ge2019_implied_results:_majority                                           7987.052680
# poll:_environment/climate_change_important_issues_at_next_election_(%)        0.052248
# local_green_economy:_gva_(£m)                                               138.540602
# local_green_economy:_%_of_total_gva                                           0.016613
# local_green_economy:_fte_jobs                                              1282.375263
# local_green_economy:_fte_jobs_(%)                                             0.005648
# energy_crisis_hotspots:_neighbourhoods_(no.)                                 12.559046
# energy_crisis_hotspots:_neighbourhoods_(%)                                    0.180597
# energy_crisis_hotspots:_average_energy_bill_(£)                             109.306441
# epcs:_homes_in_bands_a/b/c_(%)                                                0.077742
# epcs:_homes_in_bands_d/e/f/g_(%)                                              0.077742
# epcs:_homes_in_bands_a/b/c_(no.)                                           4904.120629
# epcs:_homes_in_bands_d/e/f/g_(no.)                                         3761.513346
# epcs:_loft_insulation_recommendations_(%)                                     0.034478
# epcs:_cavity_wall_insulation_recommendations_(%)                              0.059039
# epcs:_solid_wall_insulation_recommendations_(%)                               0.128752
# epcs:_loft_insulation_recommendations_(no.)                                1462.471199
# epcs:_cavity_insulation_recommendations_(no.)                              2601.951772
# epcs:_solid_insulation_recommendations_(no.)                               6604.644280
# respiratory_disease_prevalence_(%)                                            0.014761
# air_pollution:_neighbourhoods_where_no2_above_who_guidelines_(no.)           27.181154
# air_pollution:_neighbourhoods_where_pm2.5_above_who_guidelines_(no.)         10.393768
# air_pollution:_neighbourhoods_where_no2_above_who_guidelines_(%)              0.425854
# air_pollution:_neighbourhoods_where_pm2.5_above_who_guidelines_(%)            0.147912
# extreme_heat:_neighbourhoods_at_risk_(no.)                                   29.479217
# extreme_heat:_neighbourhoods_at_risk_(%)                                      0.477754
# flooding:_neighbourhoods_at_risk_(no.)                                       11.075059
# flooding:_neighbourhoods_at_risk_(%)                                          0.163983
# accessible_green_space:_m2_per_person                                       910.597265
# tree_canopy_cover:_hectares                                                4660.078410
# tree_canopy_cover:_proportion_of_constituency_(%)                             0.061241
# tree_canopy_cover:_neighbourhoods_with_less_than_10%_tree_canopy_(no.)       15.100546
# tree_canopy_cover:_neighbourhoods_with_less_than_10%_tree_canopy_(%)          0.241275
# households_without_access_to_private_vehicles_(no.)                        6352.922723
# households_without_access_to_private_vehicles_(%)                             0.117586
# bus_services:_frequency_per_hour_(2010)                                      31.344590
# bus_services:_frequency_per_hour_(2023)                                      30.076713
# bus_services:_change_in_frequency_of_service_2010-2023_(%)                    0.269974
# sewage_overflows:_total_number_of_spills_within_constituency               1401.517578
# sewage_overflows:_total_duration_of_spills_within_constituency_(hrs)      13442.454860
# dtype: float64

# %%
column_stats = categorical_columns.apply(lambda x: x.nunique(), axis=0)
column_stats
# Out:
# constituency_code                                                      575
# constituency                                                           575
# sub-region                                                              40
# region                                                                  10
# ge2019_implied_results:_mp_name                                        541
# ge2019_implied_results:_party                                            9
# accessible_green_space:_rating_(compared_across_all_constituencies)      3
# dtype: int64

# %%
def coefficient_of_variation(col):
    result = col.std() / col.mean()
    return col.std(), col.mean(), result

# %%
numerical_columns.apply(coefficient_of_variation, axis=0).T.head()
# Out:
#                                                               0  ...         2
# ge2019_implied_results:_electorate                  3078.282033  ...  0.041946
# ge2019_implied_results:_majority                    7994.007015  ...  0.608689
# poll:_environment/climate_change_important_issu...     0.052293  ...  0.074812
# local_green_economy:_gva_(£m)                        138.661230  ...  1.373787
# local_green_economy:_%_of_total_gva                    0.016627  ...  0.476991
#
# [5 rows x 3 columns]

# %%
numerical_columns
# Out:
#      ge2019_implied_results:_electorate  ...  sewage_overflows:_total_duration_of_spills_within_constituency_(hrs)
# 0                                 77531  ...                                             366.75
# 1                                 72512  ...                                             299.62
# 2                                 73107  ...                                            5740.32
# 3                                 70045  ...                                           15596.86
# 4                                 76681  ...                                           34098.61
# ..                                  ...  ...                                                ...
# 570                               73780  ...                                            4209.50
# 571                               70218  ...                                           19765.50
# 572                               70148  ...                                           25562.50
# 573                               70870  ...                                           10547.75
# 574                               51927  ...                                           27077.25
#
# [575 rows x 41 columns]

# %%
def change_columns(col):
    a = col.nlargest(5)
    b = col.nsmallest(6)
    
    return a, b

# %%
ratio  = numerical_columns.apply(change_columns, axis=0)
ratio.T
# Out:
#                                                                                                     0                                                  1
# ge2019_implied_results:_electorate                  296    92578
# 335    82314
# 36     81511
# 196    ...  574    51927
# 241    55555
# 42     56696
# 240    ...
# ge2019_implied_results:_majority                    50     34557
# 275    34511
# 276    33052
# 254    ...  502     27
# 523     64
# 545    151
# 118    207
# 12...
# poll:_environment/climate_change_important_issu...  233    0.84
# 88     0.81
# 346    0.81
# 544    0.8...  192    0.52
# 511    0.53
# 79     0.54
# 399    0.5...
# local_green_economy:_gva_(£m)                       109    3095.9
# 372     553.9
# 503     464.7
# 227 ...  269    23.1
# 268    23.5
# 91     27.5
# 189    31....
# local_green_economy:_%_of_total_gva                 95     0.1586
# 214    0.1586
# 454    0.1586
# 225 ...  493    0.0124
# 382    0.0130
# 167    0.0137
# 249 ...
# local_green_economy:_fte_jobs                       109    29257.8
# 372     6030.9
# 247     4326.2
# 2...  269    404.0
# 268    410.0
# 91     431.6
# 189    ...
# local_green_economy:_fte_jobs_(%)                   95     0.0599
# 214    0.0599
# 454    0.0599
# 212 ...  42     0.0162
# 268    0.0190
# 269    0.0190
# 314 ...
# energy_crisis_hotspots:_neighbourhoods_(no.)        30     69
# 35     69
# 32     65
# 37     62
# 569   ...  427    0
# 471    0
# 22     1
# 68     1
# 157    1
# 5...
# energy_crisis_hotspots:_neighbourhoods_(%)          30     0.884615
# 35     0.884615
# 37     0.86111...  427    0.000000
# 471    0.000000
# 542    0.01587...
# energy_crisis_hotspots:_average_energy_bill_(£)     426    2920.0
# 434    2920.0
# 152    2910.0
# 342 ...  22     2270.0
# 519    2270.0
# 169    2290.0
# 297 ...
# epcs:_homes_in_bands_a/b/c_(%)                      367    0.822592
# 22     0.720357
# 396    0.71329...  37     0.204969
# 558    0.213454
# 31     0.25398...
# epcs:_homes_in_bands_d/e/f/g_(%)                    37     0.795031
# 558    0.786546
# 31     0.74601...  367    0.177408
# 22     0.279643
# 396    0.28670...
# epcs:_homes_in_bands_a/b/c_(no.)                    367    55414
# 109    50716
# 396    44263
# 289    ...  37      8411
# 91      9987
# 31     10078
# 574    ...
# epcs:_homes_in_bands_d/e/f/g_(no.)                  247    42816
# 558    41883
# 42     36887
# 109    ...  367    11951
# 22     15044
# 254    15747
# 306    ...
# epcs:_loft_insulation_recommendations_(%)           91     0.319259
# 155    0.291265
# 111    0.27587...  367    0.044810
# 22     0.063378
# 289    0.06869...
# epcs:_cavity_wall_insulation_recommendations_(%)    369    0.443585
# 368    0.424223
# 42     0.41183...  68     0.051242
# 487    0.052413
# 201    0.05814...
# epcs:_solid_wall_insulation_recommendations_(%)     150    0.679896
# 247    0.634747
# 569    0.63271...  306    0.014613
# 157    0.018925
# 200    0.02652...
# epcs:_loft_insulation_recommendations_(no.)         558    14080
# 111    13480
# 155    12780
# 448    ...  367    3020
# 22     3410
# 290    4100
# 289    414...
# epcs:_cavity_insulation_recommendations_(no.)       369    21520
# 42     21310
# 368    18090
# 441    ...  68     2180
# 487    2400
# 404    2460
# 194    314...
# epcs:_solid_insulation_recommendations_(no.)        247    51150
# 109    40560
# 97     39240
# 202    ...  306     730
# 157     770
# 200    1180
# 54     151...
# respiratory_disease_prevalence_(%)                  64     0.119135
# 42     0.116392
# 148    0.11609...  109    0.044739
# 247    0.046462
# 60     0.04895...
# air_pollution:_neighbourhoods_where_no2_above_w...  247    94
# 97     80
# 109    80
# 158    74
# 166   ...  4     0
# 25    0
# 27    0
# 38    0
# 41    0
# 44    ...
# air_pollution:_neighbourhoods_where_pm2.5_above...  247    94
# 97     80
# 109    80
# 192    76
# 42    ...  334    0
# 520    0
# 545    0
# 558    0
# 574    1
# 8...
# air_pollution:_neighbourhoods_where_no2_above_w...  1     1.0
# 7     1.0
# 10    1.0
# 18    1.0
# 20    ...  4     0.0
# 25    0.0
# 27    0.0
# 38    0.0
# 41    ...
# air_pollution:_neighbourhoods_where_pm2.5_above...  0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# N...  334    0.000000
# 520    0.000000
# 545    0.00000...
# extreme_heat:_neighbourhoods_at_risk_(no.)          247    94
# 109    80
# 97     79
# 202    74
# 158   ...  2     0
# 7     0
# 11    0
# 12    0
# 13    0
# 17    ...
# extreme_heat:_neighbourhoods_at_risk_(%)            0     1.0
# 8     1.0
# 9     1.0
# 10    1.0
# 14    ...  2     0.0
# 7     0.0
# 11    0.0
# 12    0.0
# 13    ...
# flooding:_neighbourhoods_at_risk_(no.)              247    91
# 192    76
# 33     75
# 314    75
# 202   ...  22     0
# 250    2
# 518    3
# 63     6
# 251    7
# 2...
# flooding:_neighbourhoods_at_risk_(%)                0    1.0
# 1    1.0
# 3    1.0
# 4    1.0
# 5    1.0
# N...  22     0.000000
# 250    0.029412
# 518    0.05000...
# accessible_green_space:_m2_per_person               517    10583.6
# 222     9797.2
# 412     7468.2
# 3...  242    3.0
# 243    3.0
# 372    3.2
# 23     3.3
# 49...
# tree_canopy_cover:_hectares                         222    39287.345709
# 481    28247.632789
# 92    ...  23      83.504810
# 112     90.519233
# 22      96...
# tree_canopy_cover:_proportion_of_constituency_(%)   171    0.382821
# 54     0.381908
# 469    0.36259...  438    0.019634
# 424    0.020405
# 327    0.02340...
# tree_canopy_cover:_neighbourhoods_with_less_tha...  234    65.0
# 42     64.0
# 55     64.0
# 117    64....  54     0.0
# 186    0.0
# 469    0.0
# 106    1.0
# 14...
# tree_canopy_cover:_neighbourhoods_with_less_tha...  234    0.984848
# 443    0.983051
# 55     0.96969...  54     0.000000
# 186    0.000000
# 469    0.00000...
# households_without_access_to_private_vehicles_(...  109    41009
# 247    40566
# 367    39113
# 243    ...  297    3172
# 329    3188
# 530    3398
# 427    362...
# households_without_access_to_private_vehicles_(%)   227    0.698442
# 243    0.692527
# 197    0.68818...  329    0.075865
# 297    0.078026
# 427    0.08599...
# bus_services:_frequency_per_hour_(2010)             109    288.79
# 227    203.57
# 347    186.75
# 496 ...  507    3.08
# 325    3.76
# 322    3.90
# 161    3.9...
# bus_services:_frequency_per_hour_(2023)             109    199.51
# 496    176.20
# 358    165.26
# 227 ...  63     1.45
# 325    1.51
# 184    1.75
# 516    1.7...
# bus_services:_change_in_frequency_of_service_20...  134    0.7037
# 74     0.6620
# 160    0.6462
# 10  ...  329   -0.8181
# 63    -0.8108
# 451   -0.7835
# 458 ...
# sewage_overflows:_total_number_of_spills_within...  558    12124
# 549    11679
# 361     8635
# 555    ...  15    0
# 20    0
# 23    0
# 26    0
# 54    0
# 67    ...
# sewage_overflows:_total_duration_of_spills_with...  549    114775.500000
# 558    112510.500000
# 555 ...  15    0.0
# 20    0.0
# 23    0.0
# 26    0.0
# 54    ...
