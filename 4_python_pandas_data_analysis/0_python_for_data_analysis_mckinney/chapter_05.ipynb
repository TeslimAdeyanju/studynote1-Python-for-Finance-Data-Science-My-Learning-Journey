# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import dotenv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[35], line 4
#       1 import pandas as pd
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 import dotenv
#
# ModuleNotFoundError: No module named 'dotenv'

# %%
obj = pd.Series([4, 7, -5, 3])
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
obj.array
# Out:
# <NumpyExtensionArray>
# [4, 7, -5, 3]
# Length: 4, dtype: int64

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
obj.values
# Out:
# array([ 4,  7, -5,  3])

# %%
obj2 = pd.Series([4, 7, -5, 3], index=['d', 'b', 'a', 'c'])
obj2
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
obj2['a']
# Out:
# np.int64(-5)

# %%
obj2['c'] = 0

# %%
obj2
# Out:
# d    4
# b    7
# a   -5
# c    0
# dtype: int64

# %%
obj2[obj2>0]
# Out:
# d    4
# b    7
# dtype: int64

# %%
import sys

# %%
print("🔍 Current Python Module Search Paths:")
for path in sys.path:
    print(path)
# Out:
# 🔍 Current Python Module Search Paths:
# /Users/teslim/.local/share/uv/python/cpython-3.11.15-macos-aarch64-none/lib/python311.zip
# /Users/teslim/.local/share/uv/python/cpython-3.11.15-macos-aarch64-none/lib/python3.11
# /Users/teslim/.local/share/uv/python/cpython-3.11-macos-aarch64-none/lib/python3.11/lib-dynload
#
# /Users/teslim/TeslimWorkSpace/MainClass/1-Modules-Python/.venv/lib/python3.11/site-packages
# /Users/teslim/OneDriveFileLoader

# %%
Onedrive_module_path = "/Users/teslim/OneDriveFileLoader"

# %%
if Onedrive_module_path not in sys.path:
    sys.path.append(Onedrive_module_path)
    print(f"✅ Added '{Onedrive_module_path}' to sys.path")
# Out:
# ✅ Added '/Users/teslim/OneDriveFileLoader' to sys.path

# %%
from dotenv import load_dotenv

# %%
import onedrive_loader
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 import onedrive_loader
#
# File ~/OneDriveFileLoader/onedrive_loader.py:23
#      21 from typing import Optional
#      22 from dotenv import load_dotenv
# ---> 23 from azure.identity import ClientSecretCredential
#      26 # ============================================================================
#      27 # CONFIGURATION - Edit these for your OneDrive setup
#      28 # ============================================================================
#      30 USER_EMAIL = "info@adeyanjuteslim.co.uk"
#
# ModuleNotFoundError: No module named 'azure'

# %%
/Users/teslim/OneDriveFileLoader/onedrive_loader.py
