# %% [markdown]
# # **RELATIONAL PLOT VISUALISATION**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# The focus of this note on the three main types of relational plots in seaborn:
# 1. Scatter Plot
# 2. Line Plot
# 3. Relational Plot (relplot)

# %% [markdown]
# Data source: https://raw.githubusercontent.com/mwaskom/seaborn-data/master/gapminder.csv

# %% [markdown]
# ## **SCATTER PLOT**

# %%
sns.scatterplot(
    data=None,
    x=None,
    y=None,
    hue=None,
    style=None,
    size=None,
    palette=None,
    hue_order=None,
    size_order=None,
    sizes=None,
    legend="auto",
    ax=None,
    **kwargs,
)

# %% [markdown]
# ### Dataset preparation

# %%
df= pd.read_excel('data.xlsx', sheet_name= '7')

# %%
df
# Out:
#           country  year       pop continent  lifeExp   gdpPercap
# 0     Afghanistan  1952   8425333      Asia   28.801  779.445314
# 1     Afghanistan  1957   9240934      Asia   30.332  820.853030
# 2     Afghanistan  1962  10267083      Asia   31.997  853.100710
# 3     Afghanistan  1967  11537966      Asia   34.020  836.197138
# 4     Afghanistan  1972  13079460      Asia   36.088  739.981106
# ...           ...   ...       ...       ...      ...         ...
# 1699     Zimbabwe  1987   9216418    Africa   62.351  706.157306
# 1700     Zimbabwe  1992  10704340    Africa   60.377  693.420786
# 1701     Zimbabwe  1997  11404948    Africa   46.809  792.449960
# 1702     Zimbabwe  2002  11926563    Africa   39.989  672.038623
# 1703     Zimbabwe  2007  12311143    Africa   43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.columns.to_list()
# Out:
# ['country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap']

# %% [markdown]
# ### 1. Basic Scatter Plot

# %%
sns.scatterplot(
    data=df,
    x='lifeExp',
    y='gdpPercap')
plt.show()

# %% [markdown]
# ### 2. Scatter Plot with hue

# %%
sns.scatterplot(
    data=df,
    x='lifeExp',
    y='gdpPercap',
    hue='continent')
plt.show()

# %% [markdown]
# ### 3. Scatter Plot with style

# %%
sns.scatterplot(
    data=df,
    x='lifeExp',
    y='gdpPercap',
    hue='continent', 
    style='continent')
plt.show()

# %% [markdown]
# ### 4. Scatter Plot with size

# %%
sns.scatterplot(
    data=df,
    x='lifeExp',
    y='gdpPercap',
    size='pop')
plt.show()

# %% [markdown]
# ### 5. Using palette for Custom Colors

# %%
sns.scatterplot(
    data=df,
    x='lifeExp',
    y='gdpPercap',
    size='pop', 
     hue='continent', 
    palette='dark')
plt.show()

# %% [markdown]
# ### 6. Ordering Categories with hue_order

# %% [markdown]
# ### 7. Combining hue, style, and size

# %% [markdown]
# ### 8. Scatter Plot with Transparency

# %% [markdown]
# ### 9. Scatter Plot with Custom Marker Sizes (sizes)

# %% [markdown]
# ### 10. Scatter Plot with a Specific Axis

# %% [markdown]
# # **lineplot**

# %%
# Load example dataset
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
print(flights)
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.lineplot(data=flights, x='year', y='passengers')
plt.title("Basic Line Plot")
plt.show()

# %% [markdown]
# ### 2️⃣ Line Plot with hue

# %%
sns.lineplot(data=flights, x='year', y='passengers', hue='month')
plt.title("Line Plot with Hue")
plt.show()

# %% [markdown]
# ### 3️⃣ Line Plot with style

# %%
sns.lineplot(data=flights, x='year', y='passengers', hue='month', style='month')
plt.title("Line Plot with Hue and Style")
plt.show()

# %%
sns.lineplot(data=flights, x='year', y='passengers', hue='month', size='month', sizes=(1, 5))
plt.title("Line Plot with Variable Line Widths")
plt.show()

# %%
sns.lineplot(data=flights, x='year', y='passengers', hue='month', palette='tab10')
plt.title("Line Plot with Custom Palette")
plt.show()

# %%
months_order = ['January', 'February', 'March', 'April', 'May', 'June',
                'July', 'August', 'September', 'October', 'November', 'December']

sns.lineplot(
    data=flights,
    x='year',
    y='passengers',
    hue='month',
    hue_order=months_order,
    palette='tab10'
)
plt.title("Line Plot with Ordered Hue")
plt.show()

# %%
sns.lineplot(
    data=flights,
    x='year',
    y='passengers',
    hue='month',
    style='month',
    markers=True
)
plt.title("Line Plot with Markers")
plt.show()

# %%
sns.lineplot(
    data=flights,
    x='year',
    y='passengers',
    hue='month',
    style='month',
    dashes=False  # Use solid lines only
)
plt.title("Line Plot with Solid Lines")
plt.show()

# %%
sns.lineplot(
    data=flights,
    x='year',
    y='passengers',
    hue='month',
    style='month',
    size='passengers',
    sizes=(1, 5),
    markers=True,
    dashes=True
)
plt.title("Comprehensive Line Plot")
plt.show()

# %%
sns.lineplot(data=flights, x='year', y='passengers', hue='month', alpha=0.7)
plt.title("Line Plot with Transparency")
plt.show()

# %% [markdown]
# ## Rel plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load datasets
tips = sns.load_dataset('tips')
fmri = sns.load_dataset('fmri')
penguins = sns.load_dataset('penguins')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  ...  flipper_length_mm  body_mass_g     sex
# 0  Adelie  Torgersen            39.1  ...              181.0       3750.0    Male
# 1  Adelie  Torgersen            39.5  ...              186.0       3800.0  Female
# 2  Adelie  Torgersen            40.3  ...              195.0       3250.0  Female
# 3  Adelie  Torgersen             NaN  ...                NaN          NaN     NaN
# 4  Adelie  Torgersen            36.7  ...              193.0       3450.0  Female
#
# [5 rows x 7 columns]

# %%
sns.relplot(data=tips, x='total_bill', y='tip', kind='scatter')
plt.show()

# %%
sns.relplot(data=fmri, x='timepoint', y='signal', kind='line', errorbar='sd')
plt.show()

# %%
sns.relplot(data=fmri, x='timepoint', y='signal', kind='line', errorbar=None)
plt.show()

# %%
sns.relplot(data=tips,
            x='total_bill', y='tip',
            hue='sex', style='smoker',
            size='size', 
            kind='line')

plt.show()

# %%
uk_election = pd.read_excel('uk_election.xlsx', sheet_name=5)
uk_election
# Out:
#               CONSTITUENCY                    REGION  ... TURNOUT % SHARE %
# 0             Amber Valley             East Midlands  ...      60.3    37.0
# 1                 Ashfield             East Midlands  ...      58.6    42.8
# 2                Bassetlaw             East Midlands  ...      57.4    41.2
# 3                 Bolsover             East Midlands  ...      56.5    40.5
# 4        Boston & Skegness             East Midlands  ...      53.4    38.4
# ..                     ...                       ...  ...       ...     ...
# 645        Thirsk & Malton  Yorkshire and the Humber  ...      63.5    39.3
# 646   Wakefield & Rothwell  Yorkshire and the Humber  ...      54.2    43.7
# 647  Wetherby & Easingwold  Yorkshire and the Humber  ...      70.3    39.4
# 648           York Central  Yorkshire and the Humber  ...      54.5    56.6
# 649             York Outer  Yorkshire and the Humber  ...      67.0    45.3
#
# [650 rows x 6 columns]

# %%
def clean_column_names(df):
    df.columns = (df.columns
                  .str.strip()
                  .str.lower()
                  .str.replace(' ', '_')
                  .str.replace('(', '')
                  .str.replace(')', '')
                 )
    return df


uk_election = clean_column_names(uk_election)
uk_election.columns.to_list()
# Out:
# ['constituency', 'region', nan, nan, 'turnout_%', 'share_%']

# %%
uk_election.columns.values[2] = 'year_2019'
uk_election.columns.values[3] = 'year_2024'
uk_election.columns.to_list()
# Out:
# ['constituency', 'region', 'year_2019', 'year_2024', 'turnout_%', 'share_%']

# %%
ax, fig = plt.subplots(figsize=(10, 6))
sns.relplot(data= uk_election,
            y='year_2019', x='region',
            kind='scatter', ax=ax)
# Out:
# /Users/teslim/anaconda3/envs/machine-learning-env/lib/python3.10/site-packages/seaborn/relational.py:733: UserWarning: relplot is a figure-level function and does not accept the `ax` parameter. You may wish to try scatterplot
#   warnings.warn(msg, UserWarning)
