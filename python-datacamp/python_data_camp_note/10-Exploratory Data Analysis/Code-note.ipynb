# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('data1.csv')
df2 = pd.read_csv('data2.csv', sep=';')
df3= pd.read_csv('data3.csv', sep=';')

# %%
df1
# Out:
#       TransactionID            Timestamp  CustomerID       Name   Surname  \
# 0            113255  2016-12-13 18:05:37   200000663    Leonard   Jackson
# 1            113254  2016-12-13 18:05:22   200000661      Lucas   Abraham
# 2            113253  2016-12-13 18:03:57   200000662     Trevor   Skinner
# 3            113252  2016-12-13 18:01:45   100000007    Dorothy   Thomson
# 4            113251  2016-12-13 18:01:22   400000180       Eric     Bower
# ...             ...                  ...         ...        ...       ...
# 3450         109805  2016-12-10 18:08:49   200000662     Trevor   Skinner
# 3451         109804  2016-12-10 18:08:36   100000854       Carl     Clark
# 3452         109803  2016-12-10 18:08:24   200000793    Charles  McDonald
# 3453         109802  2016-12-10 18:08:03   200000263  Gabrielle  Marshall
# 3454         109801  2016-12-10 18:07:25   200000670    Richard      Carr
#
#      Shipping_State        Item       Description  Retail_Price  \
# ...

# %%
df1.columns
# Out:
# Index(['TransactionID', 'Timestamp', 'CustomerID', 'Name', 'Surname',
#        'Shipping_State', 'Item', 'Description', 'Retail_Price',
#        'Loyalty_Discount'],
#       dtype='object')

# %%
df1[['TransactionID', 'Name', 'Retail_Price' ]]
# Out:
#       TransactionID       Name  Retail_Price
# 0            113255    Leonard         18.96
# 1            113254      Lucas         23.10
# 2            113253     Trevor         29.90
# 3            113252    Dorothy        159.80
# 4            113251       Eric        159.80
# ...             ...        ...           ...
# 3450         109805     Trevor         69.75
# 3451         109804       Carl         43.96
# 3452         109803    Charles         43.89
# 3453         109802  Gabrielle         51.66
# 3454         109801    Richard         35.14
#
# [3455 rows x 3 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3455 entries, 0 to 3454
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   TransactionID     3455 non-null   int64
#  1   Timestamp         3455 non-null   object
#  2   CustomerID        3455 non-null   int64
#  3   Name              3455 non-null   object
#  4   Surname           3455 non-null   object
#  5   Shipping_State    3455 non-null   object
#  6   Item              3455 non-null   int64
#  7   Description       3455 non-null   object
#  8   Retail_Price      3455 non-null   float64
#  9   Loyalty_Discount  3455 non-null   float64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 270.0+ KB

# %%
df1.nunique()
# Out:
# TransactionID       3455
# Timestamp           3434
# CustomerID           942
# Name                 165
# Surname              150
# Shipping_State        50
# Item                 126
# Description           68
# Retail_Price         110
# Loyalty_Discount      11
# dtype: int64

# %%
df1['retail_mean'] = df1.groupby('Description')['Retail_Price'].transform('mean')

# %%
df1
# Out:
#       TransactionID            Timestamp  CustomerID       Name   Surname  \
# 0            113255  2016-12-13 18:05:37   200000663    Leonard   Jackson
# 1            113254  2016-12-13 18:05:22   200000661      Lucas   Abraham
# 2            113253  2016-12-13 18:03:57   200000662     Trevor   Skinner
# 3            113252  2016-12-13 18:01:45   100000007    Dorothy   Thomson
# 4            113251  2016-12-13 18:01:22   400000180       Eric     Bower
# ...             ...                  ...         ...        ...       ...
# 3450         109805  2016-12-10 18:08:49   200000662     Trevor   Skinner
# 3451         109804  2016-12-10 18:08:36   100000854       Carl     Clark
# 3452         109803  2016-12-10 18:08:24   200000793    Charles  McDonald
# 3453         109802  2016-12-10 18:08:03   200000263  Gabrielle  Marshall
# 3454         109801  2016-12-10 18:07:25   200000670    Richard      Carr
#
#      Shipping_State        Item       Description  Retail_Price  \
# ...

# %%
pd.crosstab(df1['Description'], df1['Retail_Price'])
# Out:
# Retail_Price        5.60    5.88    6.00    7.84    8.82    9.48    9.90    \
# Description
# Apron                    0       0       0       0       0      21       0
# Baby Blanket             0       0       0       0       0       0       0
# Baby Quilt               0       0       0       0       0       0       0
# Bath Mat                26       0       0       0       0       0       0
# Belt                     0       0       0       0       0       0       0
# ...                    ...     ...     ...     ...     ...     ...     ...
# Underwear & Boxers       0       0       0       0       0       0       0
# Valance                  0       0       0       0       0       0       0
# Wallet                   0       0       0       0       0       0       0
# Washcloth                0       0       0       0       0       0       0
# Waterbed Sheet           0       0       0       0       0       0       0
#
# ...

# %%
df1
# Out:
#       TransactionID            Timestamp  CustomerID       Name   Surname  \
# 0            113255  2016-12-13 18:05:37   200000663    Leonard   Jackson
# 1            113254  2016-12-13 18:05:22   200000661      Lucas   Abraham
# 2            113253  2016-12-13 18:03:57   200000662     Trevor   Skinner
# 3            113252  2016-12-13 18:01:45   100000007    Dorothy   Thomson
# 4            113251  2016-12-13 18:01:22   400000180       Eric     Bower
# ...             ...                  ...         ...        ...       ...
# 3450         109805  2016-12-10 18:08:49   200000662     Trevor   Skinner
# 3451         109804  2016-12-10 18:08:36   100000854       Carl     Clark
# 3452         109803  2016-12-10 18:08:24   200000793    Charles  McDonald
# 3453         109802  2016-12-10 18:08:03   200000263  Gabrielle  Marshall
# 3454         109801  2016-12-10 18:07:25   200000670    Richard      Carr
#
#      Shipping_State        Item       Description  Retail_Price  \
# ...

# %% [markdown]
# Class
#
# 1. Economy
# 2. Premium Economy
# 3. Business Class
# 4. First class

# %%
twenty_fifth = df1['Retail_Price'].quantile(0.25)
median = df1['Retail_Price'].quantile(0.5)
seventy_fifth = df1['Retail_Price'].quantile(0.75)
maximum = df1['Retail_Price'].max()

# %%
label = ["Economy", "Premium Economy", "Business Class", "First class"]

# %%
bins = [0,twenty_fifth, median, seventy_fifth, maximum]

# %%
df1['info'] = pd.cut(df1['Retail_Price'], bins=bins, labels=label)
df1['info'].value_counts()
# Out:
# info
# Economy            883
# Business Class     880
# Premium Economy    846
# First class        846
# Name: count, dtype: int64

# %%
sns.countplot(data= dfi, x='info', data=df1, palette='Set2')
# Out:
# /var/folders/v9/v9j8bf6j2r5cr97thvfgxxyh0000gn/T/ipykernel_72558/1524132546.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='info', data=df1, palette='Set2')
# <Axes: xlabel='info', ylabel='count'>
