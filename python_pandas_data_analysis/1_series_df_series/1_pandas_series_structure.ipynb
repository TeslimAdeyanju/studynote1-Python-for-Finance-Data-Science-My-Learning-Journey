# %% [markdown]
# # Series df[series]

# %%
import pandas as pd
import numpy as np
from onedrive_loader import files, load

# %%
files()
# Out:
# ['financial_transactions_dataset_analytics_kaggle',
#  'nhs-waiting-list-analytics_data',
#  'portfolio-01-nhs-financial-analytics',
#  'Portfolio-22-Financial-Performance-Analytics-Model',
#  'region_electric_hourly_time_series',
#  'SalesForecast',
#  'sundry_data_sources']

# %%
dataset = 'sundry_data_sources'
files(dataset)
# Out:
# ['22025_qs_world_university_rankings.csv',
#  'adidas_us_sales_datasets.xlsx',
#  'apple_amazon_google_microsoft_daily_stock_returns_10years.xlsx',
#  'country_economy_indicator_1950_2022.xlsx',
#  'country_gdp_per_capital_1952_2007.xlsx',
#  'end_of_month_retail_inventories_and_inventories1992_2024.xlsx',
#  'financial_sample_data.xlsx',
#  'job_roles_opening_analyst.xlsx',
#  'monthly_retail_and_food_services_sales_by_kind_of_business1992_2025.xlsx',
#  'motor_fuel_efficiency_mpg.xlsx',
#  'pivot_data_example.xlsx',
#  'retail_transaction_loyalty_discount_report.xlsx',
#  'skilled_worker_employer_sponsorship_list.xlsx',
#  'time_series_data.xlsx',
#  'uk_constituency_election_result_2019_and_2024.xlsx',
#  'uk_election_result_poll.xlsx',
#  'uk_house_of_commons_general_election_2024_results_by_constituency.xlsx',
#  'uk_smoking_data.csv']

# %%
df = load(dataset,'financial_sample_data.xlsx')
df
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera           NaN
# 1          Government                   Germany  Carretera           NaN
# 2           Midmarket                    France  Carretera           NaN
# 3           Midmarket                   Germany  Carretera           NaN
# 4           Midmarket                    Mexico  Carretera           NaN
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %% [markdown]
# ____

# %%
df.columns.to_list()
# Out:
# ['Segment',
#  'Country',
#  'Product',
#  'Discount Band',
#  'Units Sold',
#  'Manufacturing Price',
#  'Sale Price',
#  'Gross Sales',
#  'Discounts',
#  ' Sales',
#  'COGS',
#  'Profit',
#  'Date',
#  'Month Number',
#  'Month Name',
#  'Year',
#  'Unnamed: 16',
#  'Unnamed: 17']

# %%
def clean_columns_header(df):
    df.columns = df.columns.str.strip().str.lower()
    df.columns = df.columns.str.replace(' ', '_')
    return df

# %%
df = clean_columns_header(df)
df.columns.to_list()
# Out:
# ['segment',
#  'country',
#  'product',
#  'discount_band',
#  'units_sold',
#  'manufacturing_price',
#  'sale_price',
#  'gross_sales',
#  'discounts',
#  'sales',
#  'cogs',
#  'profit',
#  'date',
#  'month_number',
#  'month_name',
#  'year',
#  'unnamed:_16',
#  'unnamed:_17']

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   segment              700 non-null    str
#  1   country              700 non-null    str
#  2   product              700 non-null    str
#  3   discount_band        647 non-null    str
#  4   units_sold           700 non-null    float64
#  5   manufacturing_price  700 non-null    int64
#  6   sale_price           700 non-null    int64
#  7   gross_sales          700 non-null    float64
#  8   discounts            700 non-null    float64
#  9   sales                700 non-null    float64
#  10  cogs                 700 non-null    float64
#  11  profit               700 non-null    float64
#  12  date                 700 non-null    datetime64[us]
#  13  month_number         700 non-null    int64
#  14  month_name           700 non-null    str
# ...

# %%
df
# Out:
#               segment                   country    product discount_band  \
# 0          Government                    Canada  Carretera           NaN
# 1          Government                   Germany  Carretera           NaN
# 2           Midmarket                    France  Carretera           NaN
# 3           Midmarket                   Germany  Carretera           NaN
# 4           Midmarket                    Mexico  Carretera           NaN
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      units_sold  manufacturing_price  sale_price  gross_sales  discounts  \
# ...

# %%
df['product'].index
# Out:
# RangeIndex(start=0, stop=700, step=1)

# %%
df['country'].index
# Out:
# RangeIndex(start=0, stop=700, step=1)

# %%
df['country'].dtypes
# Out:
# <StringDtype(na_value=nan)>

# %%
df['product'].size
# Out:
# 700

# %%
df['country'].values[:5].tolist()
# Out:
# ['Canada', 'Germany', 'France', 'Germany', 'Mexico']

# %%
df['gross_sales'].values[:10].tolist()
# Out:
# [32370.0,
#  26420.0,
#  32670.0,
#  13320.0,
#  37050.0,
#  529550.0,
#  13815.0,
#  30216.0,
#  37980.0,
#  18540.0]

# %%
df['discount_band'].hasnans
# Out:
# True

# %%
df['discount_band'].isnull().sum()
# Out:
# np.int64(53)

# %%
df['discount_band'].attrs = {'description': 'Discount band for the product', 'source': 'Financial Sample Data', 'last_updated': '2024-06-01'}

# %%
print(df['discount_band'].attrs)
# Out:
# {}
