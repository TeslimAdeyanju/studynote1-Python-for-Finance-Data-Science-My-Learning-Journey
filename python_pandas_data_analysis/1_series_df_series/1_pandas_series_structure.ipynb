# %% [markdown]
# # Series df[series]

# %%
from onedrive_loader import files, load
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from onedrive_loader import files, load
#
# ModuleNotFoundError: No module named 'onedrive_loader'

# %%
files()
# Out:
# ['financial_transactions_dataset_analytics_kaggle',
#  'nhs-waiting-list-analytics_data',
#  'portfolio-01-nhs-financial-analytics',
#  'Portfolio-22-Financial-Performance-Analytics-Model',
#  'region_electric_hourly_time_series',
#  'SalesForecast',
#  'sundry_data_sources']

# %%
dataset_folder1 = 'sundry_data_sources'
dataset_folder2 = 'nhs-waiting-list-analytics_data'
dataset_folder3 = 'Portfolio-22-Financial-Performance-Analytics-Model'

# %%
files(dataset_folder3)
# Out:
# ['Financial Sample.xlsx']

# %%
df = load(dataset_folder,"uk_smoking_data.csv")

# %%
df
# Out:
#       gender  age marital_status highest_qualification nationality ethnicity  \
# 0       Male   38       Divorced      No Qualification     British     White
# 1     Female   42         Single      No Qualification     British     White
# 2       Male   40        Married                Degree     English     White
# 3     Female   40        Married                Degree     English     White
# 4     Female   39        Married          GCSE/O Level     British     White
# ...      ...  ...            ...                   ...         ...       ...
# 1686    Male   22         Single      No Qualification    Scottish     White
# 1687  Female   49       Divorced      Other/Sub Degree     English     White
# 1688    Male   45        Married      Other/Sub Degree    Scottish     White
# 1689  Female   51        Married      No Qualification     English     White
# 1690    Male   31        Married                Degree    Scottish     White
#
# ...

# %%
nhs = 'portfolio-01-nhs-financial-analytics'
files(nhs)
# Out:
# ['dim_financial_year.csv',
#  'dim_trust.csv',
#  'expenditure_breakdown.csv',
#  'expenditure_detail.csv',
#  'ie_summary.csv',
#  'income_detail.csv',
#  'kpis.csv',
#  'sector_benchmarks.csv',
#  'workforce.csv']

# %%
files('portfolio-01-nhs-financial-analytics')
# Out:
# ['dim_financial_year.csv',
#  'dim_trust.csv',
#  'expenditure_breakdown.csv',
#  'expenditure_detail.csv',
#  'ie_summary.csv',
#  'income_detail.csv',
#  'kpis.csv',
#  'sector_benchmarks.csv',
#  'workforce.csv']

# %%
df = load(file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df = load(file)
#
# File ~/onedriveloader/onedrive_loader.py:119, in load(path, filename, **kwargs)
#     116 if filename is not None:
#     117     path = _legacy_path(path, filename)
# --> 119 content = BytesIO(_request(path, "content").content)
#     120 extension = Path(path).suffix.lower()
#     122 if extension in {".csv", ".txt"}:
#
# File ~/onedriveloader/onedrive_loader.py:90, in _request(relative_path, operation)
#      88     except ValueError:
#      89         detail = response.text
# ---> 90     raise FileNotFoundError(
#      91         f"OneDrive could not open '{_onedrive_path(relative_path)}' "
#      92         f"(HTTP {response.status_code}): {detail}"
#      93     )
#      94 return response
#
# ...

# %%
import pandas as pd

# %% [markdown]
# ## 1. Pandas Series: Structure

# %%
import pandas as pd
import seaborn as sns

# Load dataset
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ### 1. Basic Series Properties

# %%
df['age'].index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df['age'].name
# Out:
# 'age'

# %%
df['age'].dtype
# Out:
# dtype('float64')

# %%
df['age'].dtypes
# Out:
# dtype('float64')

# %%
df['age'].shape
# Out:
# (891,)

# %%
df['age'].ndim
# Out:
# 1

# %%
df['age'].size
# Out:
# 891

# %%
df['age'].values[:5]
# Out:
# array([22., 38., 26., 35., 35.])

# %%
df['age'].array[:5]
# Out:
# <NumpyExtensionArray>
# [22.0, 38.0, 26.0, 35.0, 35.0]
# Length: 5, dtype: float64

# %% [markdown]
# ### 2. Boolean Checks

# %%
df['age'].empty
# Out:
# False

# %%
df['age'].hasnans
# Out:
# True

# %%
df['age'].isna().sum()
# Out:
# np.int64(177)

# %% [markdown]
# ### 3. Advanced Attributes (Less Common)

# %%
df['age'].flags
# Out:
# <Flags(allows_duplicate_labels=True)>

# %%
df['age'].set_flags(allows_duplicate_labels=False)
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
df['age'].attrs
# Out:
# {}
