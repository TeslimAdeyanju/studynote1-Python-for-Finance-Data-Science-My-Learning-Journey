# %% [markdown]
# # DataFrames I

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
pip install pandas

# %% [markdown]
# ## Methods and Attributes between Series and DataFrames
# - A **DataFrame** is a 2-dimensional table consisting of rows and columns.
# - Pandas uses a `NaN` designation for cells that have a missing value. It is short for "not a number". Most operations on `NaN` values will produce `NaN` values.
# - Like with a **Series**, Pandas assigns an index position/label to each **DataFrame** row.
# - The **DataFrame** and **Series** have common and exclusive methods/attributes.
# - The `hasnans` attribute exists only a **Series**. The `columns` attribute exists only on a **DataFrame**.
# - Some methods/attributes will return different types of data.
# - The `info` method returns a summary of the pandas object.

# %%
nba = pd.read_csv("nba.csv")
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# 4         Maryland   2581522.0
# ..             ...         ...
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 589    Real Madrid         NaN
# 590           Utah   8195122.0
# 591            NaN         NaN
#
# [592 rows x 7 columns]

# %%
nba.isna().sum()
# Out:
# Name          1
# Team          1
# Position      8
# Height        7
# Weight        8
# College      14
# Salary      104
# dtype: int64

# %%
nba.values
# Out:
# array([['Saddiq Bey', 'Atlanta Hawks', 'F', ..., 215.0, 'Villanova',
#         4556983.0],
#        ['Bogdan Bogdanovic', 'Atlanta Hawks', 'G', ..., 225.0,
#         'Fenerbahce', 18700000.0],
#        ['Kobe Bufkin', 'Atlanta Hawks', 'G', ..., 195.0, 'Michigan',
#         4094244.0],
#        ...,
#        ['Tristan Vukcevic', 'Washington Wizards', 'F', ..., 220.0,
#         'Real Madrid', nan],
#        ['Delon Wright', 'Washington Wizards', 'G', ..., 185.0, 'Utah',
#         8195122.0],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=592, step=1)

# %%
nba.shape
# Out:
# (592, 7)

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Position     object
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba.axes
# Out:
# [RangeIndex(start=0, stop=592, step=1),
#  Index(['Name', 'Team', 'Position', 'Height', 'Weight', 'College', 'Salary'], dtype='object')]

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 592 entries, 0 to 591
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      591 non-null    object
#  1   Team      591 non-null    object
#  2   Position  584 non-null    object
#  3   Height    585 non-null    object
#  4   Weight    584 non-null    float64
#  5   College   578 non-null    object
#  6   Salary    488 non-null    float64
# dtypes: float64(2), object(5)
# memory usage: 32.5+ KB

# %% [markdown]
# ## Differences between Shared Methods
# - The `sum` method adds a **Series's** values.
# - On a **DataFrame**, the `sum` method defaults to adding the values by traversing the index (row values).
# - The `axis` parameter customizes the direction that we add across. Pass `"columns"` or `1` to add "across" the columns.

# %%
revenue=pd.read_csv("revenue.csv", index_col = "Date")
revenue
# Out:
#          New York  Los Angeles  Miami
# Date
# 1/1/26        985          122    499
# 1/2/26        738          788    534
# 1/3/26         14           20    933
# 1/4/26        730          904    885
# 1/5/26        114           71    253
# 1/6/26        936          502    497
# 1/7/26        123          996    115
# 1/8/26        935          492    886
# 1/9/26        846          954    823
# 1/10/26        54          285    216

# %%
revenue.sum()
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
revenue.sum(axis=1)
# Out:
# Date
# 1/1/26     1606
# 1/2/26     2060
# 1/3/26      967
# 1/4/26     2519
# 1/5/26      438
# 1/6/26     1935
# 1/7/26     1234
# 1/8/26     2313
# 1/9/26     2623
# 1/10/26     555
# dtype: int64

# %%
revenue.sum(axis=0)
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %% [markdown]
# ## Select One Column from a DataFrame
# - We can use attribute syntax (`df.column_name`) to select a column from a **DataFrame**. The syntax will not work if the column name has spaces.
# - We can also use square bracket syntax (`df["column name"]`) which will work for any column name.
# - Pandas extracts a column from a **DataFrame** as a **Series**.
# - The **Series** is a view, so changes to the **Series** *will* affect the **DataFrame**.
# - Pandas will display a warning if you mutate the **Series**. Use the `copy` method to create a duplicate.

# %%
df =pd.read_csv("nba.csv")
df
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# 4         Maryland   2581522.0
# ..             ...         ...
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 589    Real Madrid         NaN
# 590           Utah   8195122.0
# 591            NaN         NaN
#
# [592 rows x 7 columns]

# %%
Name = df["Name"].copy()
Name
# Out:
# 0             Saddiq Bey
# 1      Bogdan Bogdanovic
# 2            Kobe Bufkin
# 3           Clint Capela
# 4         Bruno Fernando
#              ...
# 587         Ryan Rollins
# 588        Landry Shamet
# 589     Tristan Vukcevic
# 590         Delon Wright
# 591                  NaN
# Name: Name, Length: 592, dtype: object

# %%
Name.iloc[0] = "TESLIM"

# %%
Name
# Out:
# 0                 TESLIM
# 1      Bogdan Bogdanovic
# 2            Kobe Bufkin
# 3           Clint Capela
# 4         Bruno Fernando
#              ...
# 587         Ryan Rollins
# 588        Landry Shamet
# 589     Tristan Vukcevic
# 590         Delon Wright
# 591                  NaN
# Name: Name, Length: 592, dtype: object

# %%
df.head()
# Out:
#                 Name           Team Position Height  Weight      College  \
# 0         Saddiq Bey  Atlanta Hawks        F    6-7   215.0    Villanova
# 1  Bogdan Bogdanovic  Atlanta Hawks        G    6-5   225.0   Fenerbahce
# 2        Kobe Bufkin  Atlanta Hawks        G    6-5   195.0     Michigan
# 3       Clint Capela  Atlanta Hawks        C   6-10   256.0  Elan Chalon
# 4     Bruno Fernando  Atlanta Hawks      F-C   6-10   240.0     Maryland
#
#        Salary
# 0   4556983.0
# 1  18700000.0
# 2   4094244.0
# 3  20616000.0
# 4   2581522.0

# %%
nba.Team
# Out:
# 0           Atlanta Hawks
# 1           Atlanta Hawks
# 2           Atlanta Hawks
# 3           Atlanta Hawks
# 4           Atlanta Hawks
#               ...
# 587    Washington Wizards
# 588    Washington Wizards
# 589    Washington Wizards
# 590    Washington Wizards
# 591                   NaN
# Name: Team, Length: 592, dtype: object

# %% [markdown]
# ## Select Multiple Columns from a DataFrame
# - Use square brackets with a list of names to extract multiple **DataFrame** columns.
# - Pandas stores the result in a new **DataFrame** (a copy).

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# 4         Maryland   2581522.0
# ..             ...         ...
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 589    Real Madrid         NaN
# 590           Utah   8195122.0
# 591            NaN         NaN
#
# [592 rows x 7 columns]

# %%
nba[['Name', 'Team', 'Position']]
# Out:
#                   Name                Team Position
# 0           Saddiq Bey       Atlanta Hawks        F
# 1    Bogdan Bogdanovic       Atlanta Hawks        G
# 2          Kobe Bufkin       Atlanta Hawks        G
# 3         Clint Capela       Atlanta Hawks        C
# 4       Bruno Fernando       Atlanta Hawks      F-C
# ..                 ...                 ...      ...
# 587       Ryan Rollins  Washington Wizards        G
# 588      Landry Shamet  Washington Wizards        G
# 589   Tristan Vukcevic  Washington Wizards        F
# 590       Delon Wright  Washington Wizards        G
# 591                NaN                 NaN      NaN
#
# [592 rows x 3 columns]

# %% [markdown]
# ## Add New Column to DataFrame
# - Use square bracket extraction syntax with an equal sign to add a new **Series** to a **DataFrame**.
# - The `insert` method allows us to insert an element at a specific column index.
# - On the right-hand side, we can reference an existing **DataFrame** column and perform a broadcasting operation on it to create the new **Series**.

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# 4         Maryland   2581522.0
# ..             ...         ...
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 589    Real Madrid         NaN
# 590           Utah   8195122.0
# 591            NaN         NaN
#
# [592 rows x 7 columns]

# %%
nba["locaiion"] = "USA"

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary locaiion
# 0        Villanova   4556983.0      USA
# 1       Fenerbahce  18700000.0      USA
# 2         Michigan   4094244.0      USA
# 3      Elan Chalon  20616000.0      USA
# 4         Maryland   2581522.0      USA
# ..             ...         ...      ...
# 587         Toledo   1719864.0      USA
# 588  Wichita State  10250000.0      USA
# 589    Real Madrid         NaN      USA
# 590           Utah   8195122.0      USA
# 591            NaN         NaN      USA
#
# [592 rows x 8 columns]

# %%
nba.insert(loc=3, column="Sport", value="Home Basketball", allow_duplicates=True)
nba
# Out:
#                   Name                Team Position            Sport Height  \
# 0           Saddiq Bey       Atlanta Hawks        F  Home Basketball    6-7
# 1    Bogdan Bogdanovic       Atlanta Hawks        G  Home Basketball    6-5
# 2          Kobe Bufkin       Atlanta Hawks        G  Home Basketball    6-5
# 3         Clint Capela       Atlanta Hawks        C  Home Basketball   6-10
# 4       Bruno Fernando       Atlanta Hawks      F-C  Home Basketball   6-10
# ..                 ...                 ...      ...              ...    ...
# 587       Ryan Rollins  Washington Wizards        G  Home Basketball    6-3
# 588      Landry Shamet  Washington Wizards        G  Home Basketball    6-4
# 589   Tristan Vukcevic  Washington Wizards        F  Home Basketball   6-10
# 590       Delon Wright  Washington Wizards        G  Home Basketball    6-5
# 591                NaN                 NaN      NaN  Home Basketball    NaN
#
#      Weight        College      Salary locaiion
# 0     215.0      Villanova   4556983.0      USA
# 1     225.0     Fenerbahce  18700000.0      USA
# 2     195.0       Michigan   4094244.0      USA
# 3     256.0    Elan Chalon  20616000.0      USA
# 4     240.0       Maryland   2581522.0      USA
# ..      ...            ...         ...      ...
# 587   180.0         Toledo   1719864.0      USA
# 588   190.0  Wichita State  10250000.0      USA
# 589   220.0    Real Madrid         NaN      USA
# 590   185.0           Utah   8195122.0      USA
# 591     NaN            NaN         NaN      USA
#
# [592 rows x 9 columns]

# %%
nba["Double Weight"] = nba["Weight"] * 2
nba
# Out:
#                   Name                Team Position            Sport Height  \
# 0           Saddiq Bey       Atlanta Hawks        F  Home Basketball    6-7
# 1    Bogdan Bogdanovic       Atlanta Hawks        G  Home Basketball    6-5
# 2          Kobe Bufkin       Atlanta Hawks        G  Home Basketball    6-5
# 3         Clint Capela       Atlanta Hawks        C  Home Basketball   6-10
# 4       Bruno Fernando       Atlanta Hawks      F-C  Home Basketball   6-10
# ..                 ...                 ...      ...              ...    ...
# 587       Ryan Rollins  Washington Wizards        G  Home Basketball    6-3
# 588      Landry Shamet  Washington Wizards        G  Home Basketball    6-4
# 589   Tristan Vukcevic  Washington Wizards        F  Home Basketball   6-10
# 590       Delon Wright  Washington Wizards        G  Home Basketball    6-5
# 591                NaN                 NaN      NaN  Home Basketball    NaN
#
#      Weight        College      Salary locaiion  Double Weight
# 0     215.0      Villanova   4556983.0      USA          430.0
# 1     225.0     Fenerbahce  18700000.0      USA          450.0
# 2     195.0       Michigan   4094244.0      USA          390.0
# 3     256.0    Elan Chalon  20616000.0      USA          512.0
# 4     240.0       Maryland   2581522.0      USA          480.0
# ..      ...            ...         ...      ...            ...
# 587   180.0         Toledo   1719864.0      USA          360.0
# 588   190.0  Wichita State  10250000.0      USA          380.0
# 589   220.0    Real Madrid         NaN      USA          440.0
# 590   185.0           Utah   8195122.0      USA          370.0
# 591     NaN            NaN         NaN      USA            NaN
#
# [592 rows x 10 columns]

# %%
print(nba["Salary"].add)
# Out:
# <bound method Series.add of 0       4556983.0
# 1      18700000.0
# 2       4094244.0
# 3      20616000.0
# 4       2581522.0
#           ...
# 587     1719864.0
# 588    10250000.0
# 589           NaN
# 590     8195122.0
# 591           NaN
# Name: Salary, Length: 592, dtype: float64>

# %%
nba
# Out:
#                   Name                Team Position            Sport Height  \
# 0           Saddiq Bey       Atlanta Hawks        F  Home Basketball    6-7
# 1    Bogdan Bogdanovic       Atlanta Hawks        G  Home Basketball    6-5
# 2          Kobe Bufkin       Atlanta Hawks        G  Home Basketball    6-5
# 3         Clint Capela       Atlanta Hawks        C  Home Basketball   6-10
# 4       Bruno Fernando       Atlanta Hawks      F-C  Home Basketball   6-10
# ..                 ...                 ...      ...              ...    ...
# 587       Ryan Rollins  Washington Wizards        G  Home Basketball    6-3
# 588      Landry Shamet  Washington Wizards        G  Home Basketball    6-4
# 589   Tristan Vukcevic  Washington Wizards        F  Home Basketball   6-10
# 590       Delon Wright  Washington Wizards        G  Home Basketball    6-5
# 591                NaN                 NaN      NaN  Home Basketball    NaN
#
#      Weight        College      Salary locaiion  Double Weight
# 0     215.0      Villanova   4556983.0      USA          430.0
# 1     225.0     Fenerbahce  18700000.0      USA          450.0
# 2     195.0       Michigan   4094244.0      USA          390.0
# 3     256.0    Elan Chalon  20616000.0      USA          512.0
# 4     240.0       Maryland   2581522.0      USA          480.0
# ..      ...            ...         ...      ...            ...
# 587   180.0         Toledo   1719864.0      USA          360.0
# 588   190.0  Wichita State  10250000.0      USA          380.0
# 589   220.0    Real Madrid         NaN      USA          440.0
# 590   185.0           Utah   8195122.0      USA          370.0
# 591     NaN            NaN         NaN      USA            NaN
#
# [592 rows x 10 columns]

# %%
info_columns = ["Weight", "Salary"]
info = nba[info_columns]*4
info
# Out:
#      Weight      Salary
# 0     860.0  18227932.0
# 1     900.0  74800000.0
# 2     780.0  16376976.0
# 3    1024.0  82464000.0
# 4     960.0  10326088.0
# ..      ...         ...
# 587   720.0   6879456.0
# 588   760.0  41000000.0
# 589   880.0         NaN
# 590   740.0  32780488.0
# 591     NaN         NaN
#
# [592 rows x 2 columns]

# %%
nba[["info_1", "info_2"]] = info
nba
# Out:
#                   Name                Team Position            Sport Height  \
# 0           Saddiq Bey       Atlanta Hawks        F  Home Basketball    6-7
# 1    Bogdan Bogdanovic       Atlanta Hawks        G  Home Basketball    6-5
# 2          Kobe Bufkin       Atlanta Hawks        G  Home Basketball    6-5
# 3         Clint Capela       Atlanta Hawks        C  Home Basketball   6-10
# 4       Bruno Fernando       Atlanta Hawks      F-C  Home Basketball   6-10
# ..                 ...                 ...      ...              ...    ...
# 587       Ryan Rollins  Washington Wizards        G  Home Basketball    6-3
# 588      Landry Shamet  Washington Wizards        G  Home Basketball    6-4
# 589   Tristan Vukcevic  Washington Wizards        F  Home Basketball   6-10
# 590       Delon Wright  Washington Wizards        G  Home Basketball    6-5
# 591                NaN                 NaN      NaN  Home Basketball    NaN
#
#      Weight        College      Salary locaiion  Double Weight  info_1  \
# 0     215.0      Villanova   4556983.0      USA          430.0   860.0
# 1     225.0     Fenerbahce  18700000.0      USA          450.0   900.0
# 2     195.0       Michigan   4094244.0      USA          390.0   780.0
# 3     256.0    Elan Chalon  20616000.0      USA          512.0  1024.0
# 4     240.0       Maryland   2581522.0      USA          480.0   960.0
# ..      ...            ...         ...      ...            ...     ...
# 587   180.0         Toledo   1719864.0      USA          360.0   720.0
# 588   190.0  Wichita State  10250000.0      USA          380.0   760.0
# 589   220.0    Real Madrid         NaN      USA          440.0   880.0
# 590   185.0           Utah   8195122.0      USA          370.0   740.0
# 591     NaN            NaN         NaN      USA            NaN     NaN
#
#          info_2
# 0    18227932.0
# 1    74800000.0
# 2    16376976.0
# 3    82464000.0
# 4    10326088.0
# ..          ...
# 587   6879456.0
# 588  41000000.0
# 589         NaN
# 590  32780488.0
# 591         NaN
#
# [592 rows x 12 columns]

# %% [markdown]
# ## A Review of the value_counts Method
# - The `value_counts` method counts the number of times that each unique value occurs in a **Series**.

# %%
nba["Team"].value_counts(normalize=True)*100
# Out:
# Team
# Dallas Mavericks          3.891709
# Miami Heat                3.722504
# Denver Nuggets            3.722504
# Milwaukee Bucks           3.722504
# Memphis Grizzlies         3.722504
# Indiana Pacers            3.553299
# Utah Jazz                 3.553299
# Toronto Raptors           3.553299
# Philadelphia 76ers        3.553299
# Oklahoma City Thunder     3.553299
# New York Knicks           3.553299
# Washington Wizards        3.553299
# Phoenix Suns              3.384095
# Houston Rockets           3.384095
# Charlotte Hornets         3.384095
# San Antonio Spurs         3.384095
# Los Angeles Clippers      3.214890
# Minnesota Timberwolves    3.214890
# Detroit Pistons           3.214890
# Cleveland Cavaliers       3.214890
# Los Angeles Lakers        3.214890
# Chicago Bulls             3.214890
# Sacramento Kings          3.045685
# Orlando Magic             3.045685
# Boston Celtics            3.045685
# Atlanta Hawks             3.045685
# Portland Trail Blazers    2.876481
# Golden State Warriors     2.876481
# Brooklyn Nets             2.876481
# New Orleans Pelicans      2.707276
# Name: proportion, dtype: float64

# %%
data = pd.read_csv(r'/Users/teslim/OneDrive/adult_WS2.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 data = pd.read_csv(r'/Users/teslim/OneDrive/adult_WS2.csv')
#
# File ~/Library/CloudStorage/OneDrive-TeslimUthmanAdeyanju/Teslim_data_science_study/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/Library/CloudStorage/OneDrive-TeslimUthmanAdeyanju/Teslim_data_science_study/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/Library/CloudStorage/OneDrive-TeslimUthmanAdeyanju/Teslim_data_science_study/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/Library/CloudStorage/OneDrive-TeslimUthmanAdeyanju/Teslim_data_science_study/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/Library/CloudStorage/OneDrive-TeslimUthmanAdeyanju/Teslim_data_science_study/.venv/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/teslim/OneDrive/adult_WS2.csv'

# %%
data["education"].value_counts()
# Out:
# education
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: count, dtype: int64

# %% [markdown]
# ## Drop Rows with Missing Values
# - Pandas uses a `NaN` designation for cells that have a missing value.
# - The `dropna` method deletes rows with missing values. Its default behavior is to remove a row if it has *any* missing values.
# - Pass the `how` parameter an argument of "all" to delete rows where all the values are `NaN`.
# - The `subset` parameters customizes/limits the columns that pandas will use to drop rows with missing values.

# %%
nba.dropna(how="any")
# Out:
#                   Name                Team Position            Sport Height  \
# 0           Saddiq Bey       Atlanta Hawks        F  Home Basketball    6-7
# 1    Bogdan Bogdanovic       Atlanta Hawks        G  Home Basketball    6-5
# 2          Kobe Bufkin       Atlanta Hawks        G  Home Basketball    6-5
# 3         Clint Capela       Atlanta Hawks        C  Home Basketball   6-10
# 4       Bruno Fernando       Atlanta Hawks      F-C  Home Basketball   6-10
# ..                 ...                 ...      ...              ...    ...
# 585     Eugene Omoruyi  Washington Wizards        F  Home Basketball    6-6
# 586       Jordan Poole  Washington Wizards        G  Home Basketball    6-4
# 587       Ryan Rollins  Washington Wizards        G  Home Basketball    6-3
# 588      Landry Shamet  Washington Wizards        G  Home Basketball    6-4
# 590       Delon Wright  Washington Wizards        G  Home Basketball    6-5
#
#      Weight        College      Salary locaiion  Double Weight  info_1  \
# 0     215.0      Villanova   4556983.0      USA          430.0   860.0
# 1     225.0     Fenerbahce  18700000.0      USA          450.0   900.0
# 2     195.0       Michigan   4094244.0      USA          390.0   780.0
# 3     256.0    Elan Chalon  20616000.0      USA          512.0  1024.0
# 4     240.0       Maryland   2581522.0      USA          480.0   960.0
# ..      ...            ...         ...      ...            ...     ...
# 585   235.0         Oregon    559782.0      USA          470.0   940.0
# 586   194.0       Michigan  27955357.0      USA          388.0   776.0
# 587   180.0         Toledo   1719864.0      USA          360.0   720.0
# 588   190.0  Wichita State  10250000.0      USA          380.0   760.0
# 590   185.0           Utah   8195122.0      USA          370.0   740.0
#
#           info_2
# 0     18227932.0
# 1     74800000.0
# 2     16376976.0
# 3     82464000.0
# 4     10326088.0
# ..           ...
# 585    2239128.0
# 586  111821428.0
# 587    6879456.0
# 588   41000000.0
# 590   32780488.0
#
# [475 rows x 12 columns]

# %%
nba.dropa(subset)

# %% [markdown]
# ## Fill in Missing Values with the fillna Method
# - The `fillna` method replaces missing `NaN` values with its argument.
# - The `fillna` method is available on both **DataFrames** and **Series**.
# - An extracted **Series** is a view on the original **DataFrame**, but the `fillna` method returns a copy.

# %%
import pandas as pd
nba = pd.read_csv("nba.csv")
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# 4         Maryland   2581522.0
# ..             ...         ...
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 589    Real Madrid         NaN
# 590           Utah   8195122.0
# 591            NaN         NaN
#
# [592 rows x 7 columns]

# %%
nba.fillna(0)
# Out:
#                   Name                Team Position Height  Weight        College      Salary
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0      Villanova   4556983.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0     Fenerbahce  18700000.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0       Michigan   4094244.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0    Elan Chalon  20616000.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0       Maryland   2581522.0
# ..                 ...                 ...      ...    ...     ...            ...         ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0         Toledo   1719864.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0  Wichita State  10250000.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0    Real Madrid         0.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0           Utah   8195122.0
# 591                  0                   0        0      0     0.0              0         0.0
#
# [592 rows x 7 columns]

# %%
nba["Salary"].fillna(100)
# Out:
# 0       4556983.0
# 1      18700000.0
# 2       4094244.0
# 3      20616000.0
# 4       2581522.0
#           ...
# 587     1719864.0
# 588    10250000.0
# 589         100.0
# 590     8195122.0
# 591         100.0
# Name: Salary, Length: 592, dtype: float64

# %%
nba["Salary"] = nba["Salary"].fillna(100)

# %%
nba
# Out:
#                   Name                Team Position Height  Weight        College      Salary
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0      Villanova   4556983.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0     Fenerbahce  18700000.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0       Michigan   4094244.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0    Elan Chalon  20616000.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0       Maryland   2581522.0
# ..                 ...                 ...      ...    ...     ...            ...         ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0         Toledo   1719864.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0  Wichita State  10250000.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0    Real Madrid       100.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0           Utah   8195122.0
# 591                NaN                 NaN      NaN    NaN     NaN            NaN       100.0
#
# [592 rows x 7 columns]

# %%
nba["College"] = nba.College.fillna(value="unknown")

# %%
nba
# Out:
#                   Name                Team Position Height  Weight        College      Salary
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0      Villanova   4556983.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0     Fenerbahce  18700000.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0       Michigan   4094244.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0    Elan Chalon  20616000.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0       Maryland   2581522.0
# ..                 ...                 ...      ...    ...     ...            ...         ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0         Toledo   1719864.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0  Wichita State  10250000.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0    Real Madrid       100.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0           Utah   8195122.0
# 591                NaN                 NaN      NaN    NaN     NaN        unknown       100.0
#
# [592 rows x 7 columns]

# %% [markdown]
# ## The astype Method I
# - The `astype` method converts a **Series's** values to a specified type.
# - Pass in the specified type as either a string or the core Python data type.
# - Pandas cannot convert `NaN` values to numeric types, so we need to eliminate/replace them before we perform the conversion.
# - The `dtypes` attribute returns a **Series** with the **DataFrame's** columns and their types.

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# 4         Maryland   2581522.0
# ..             ...         ...
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 589    Real Madrid         NaN
# 590           Utah   8195122.0
# 591            NaN         NaN
#
# [592 rows x 7 columns]

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Position     object
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
# remove the naa first before the convertng of the column to int. 
nba["Salary"] = nba["Salary"].fillna(0)
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# 4         Maryland   2581522.0
# ..             ...         ...
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 589    Real Madrid         0.0
# 590           Utah   8195122.0
# 591            NaN         0.0
#
# [592 rows x 7 columns]

# %%
# converting the salary column to int and re-assigned it back to the column. 
nba["Salary"]=nba["Salary"].astype(int)

# %%
# checking the column to confirm the changes. 
nba.dtypes
# Out:
# Name         object
# Team         object
# Position     object
# Height       object
# Weight      float64
# College      object
# Salary        int64
# dtype: object

# %%
# Applying the same princples to weight column 

# fill any missing row in the columns with the zero
nba["Weight"] = nba["Weight"].fillna(0)

# Change the column data types to int
nba["Weight"] = nba["Weight"].astype(int)

# %%
# checking the column to confirm the changes. 
nba.dtypes
# Out:
# Name        object
# Team        object
# Position    object
# Height      object
# Weight       int64
# College     object
# Salary       int64
# dtype: object

# %% [markdown]
# ## The astype Method II
# - The `category` type is ideal for columns with a limited number of unique values.
# - The `nunique` method will return a **Series** with the number of unique values in each column.
# - With categories, pandas does not create a separate value in memory for each "cell". Rather, the cells point to a single copy for each unique value.

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7     215
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5     225
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5     195
# 3         Clint Capela       Atlanta Hawks        C   6-10     256
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10     240
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3     180
# 588      Landry Shamet  Washington Wizards        G    6-4     190
# 589   Tristan Vukcevic  Washington Wizards        F   6-10     220
# 590       Delon Wright  Washington Wizards        G    6-5     185
# 591                NaN                 NaN      NaN    NaN       0
#
#            College    Salary
# 0        Villanova   4556983
# 1       Fenerbahce  18700000
# 2         Michigan   4094244
# 3      Elan Chalon  20616000
# 4         Maryland   2581522
# ..             ...       ...
# 587         Toledo   1719864
# 588  Wichita State  10250000
# 589    Real Madrid         0
# 590           Utah   8195122
# 591            NaN         0
#
# [592 rows x 7 columns]

# %%
# this is a long way to code, and this can be achieve with the nunique
nba["Team"].value_counts().count()
# Out:
# 30

# %%
# this is checking the unique value in a column
nba["Team"].nunique()
# Out:
# 30

# %%
# checking the data frame unique values 
nba.nunique()
# Out:
# Name        591
# Team         30
# Position      7
# Height       20
# Weight       94
# College     182
# Salary      299
# dtype: int64

# %%
 # checking the memory before grouping the data 
 nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 592 entries, 0 to 591
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      591 non-null    object
#  1   Team      591 non-null    category
#  2   Position  584 non-null    object
#  3   Height    585 non-null    object
#  4   Weight    592 non-null    int64
#  5   College   578 non-null    object
#  6   Salary    592 non-null    int64
# dtypes: category(1), int64(2), object(4)
# memory usage: 29.7+ KB

# %%
nba["Team"] = nba["Team"].astype("category")

# %%
nba["Position"]=nba["Position"].astype("category")

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 592 entries, 0 to 591
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      591 non-null    object
#  1   Team      591 non-null    category
#  2   Position  584 non-null    category
#  3   Height    585 non-null    object
#  4   Weight    592 non-null    int64
#  5   College   578 non-null    object
#  6   Salary    592 non-null    int64
# dtypes: category(2), int64(2), object(3)
# memory usage: 26.0+ KB

# %%
# importing a new data to test what I am doing 
file = r'/Users/teslim/OneDrive/12_console_dca.xlsx'
dca = pd.read_excel(file)
dca.head()
# Out:
#    systemloanId         DCA 2 Assignment_Date Assignment_Type  \
# 0  305401649499           NaN    Jul 13, 2020           61-90
# 1  305919711003  Stephen Udoh     Oct 7, 2020          91-120
# 2  305380284878           NaN     Jul 6, 2020          91-120
# 3  305380284878           NaN     Jul 6, 2020          91-120
# 4  305996407259           NaN     Oct 7, 2020          91-120
#
#    Amount_Delinquent  Repayment_Amount   mobilePhone1  \
# 0                NaN           38000.0  2348023133719
# 1           14983.33            2300.0  2348186023049
# 2                NaN           10500.0  2348062507954
# 3                NaN            7000.0  2348062507954
# 4           30693.40            3000.0  2348050295205
#
#                    emailAddress     BankName  loanAmount   Value_Date  \
# 0     ajibolaibrahim2@gmail.com   First Bank   153333.34  Aug 1, 2021
# 1         peresinde68@gmail.com      GT Bank    23000.00  Aug 1, 2021
# 2  oghenekarojeremiah@gmail.com  Zenith Bank    61000.00  Aug 1, 2021
# 3  oghenekarojeremiah@gmail.com  Zenith Bank    61000.00  Aug 1, 2021
# 4     ajohnsonadewumi@gmail.com      GT Bank    41500.00  Aug 1, 2021
#
#    Posting_Date  transactionId  BalanceOutstanding
# 0         44409       24999906            25426.66
# 1         44409       25011145             4683.33
# 2         44409       24998061            19497.24
# 3         44409       24998528            19497.24
# 4         44409       25001640            21693.40

# %%
# confirming the status ofthe missing 
dca.isna().sum()
# Out:
# systemloanId            0
# DCA 2                 205
# Assignment_Date         0
# Assignment_Type         0
# Amount_Delinquent     298
# Repayment_Amount        0
# mobilePhone1            0
# emailAddress            0
# BankName                1
# loanAmount              0
# Value_Date              0
# Posting_Date            0
# transactionId           0
# BalanceOutstanding      0
# dtype: int64

# %%
dca["DCA 2"]=wd["DCA 2"].fillna(value="un-assigned agent")
dca
# Out:
#      systemloanId              DCA 2 Assignment_Date Assignment_Type  \
# 0    305401649499  un-assigned agent    Jul 13, 2020           61-90
# 1    305919711003       Stephen Udoh     Oct 7, 2020          91-120
# 2    305380284878  un-assigned agent     Jul 6, 2020          91-120
# 3    305380284878  un-assigned agent     Jul 6, 2020          91-120
# 4    305996407259  un-assigned agent     Oct 7, 2020          91-120
# ..            ...                ...             ...             ...
# 445  306757417283  un-assigned agent    Jan 12, 2021          91-120
# 446  306636404787   Olalekan Olaokun    Jan 12, 2021          91-120
# 447  305645708159   Olalekan Olaokun     Jul 6, 2020          91-120
# 448  305785433039       Ridwan Akeeb     Oct 7, 2020          91-120
# 449  305710458073  un-assigned agent     Oct 7, 2020          91-120
#
#      Amount_Delinquent  Repayment_Amount   mobilePhone1  \
# 0                  NaN          38000.00  2348023133719
# 1             14983.33           2300.00  2348186023049
# 2                  NaN          10500.00  2348062507954
# 3                  NaN           7000.00  2348062507954
# 4             30693.40           3000.00  2348050295205
# ..                 ...               ...            ...
# 445                NaN           5000.00  2348178124314
# 446                NaN             50.00  2348143758790
# 447                NaN          50064.34  2348027181436
# 448            8051.38           2528.25  2348023253702
# 449           53496.00           3000.00  2348069820607
#
#                        emailAddress      BankName  loanAmount    Value_Date  \
# 0         ajibolaibrahim2@gmail.com    First Bank   153333.34   Aug 1, 2021
# 1             peresinde68@gmail.com       GT Bank    23000.00   Aug 1, 2021
# 2      oghenekarojeremiah@gmail.com   Zenith Bank    61000.00   Aug 1, 2021
# 3      oghenekarojeremiah@gmail.com   Zenith Bank    61000.00   Aug 1, 2021
# 4         ajohnsonadewumi@gmail.com       GT Bank    41500.00   Aug 1, 2021
# ..                              ...           ...         ...           ...
# 445  samvelsirseunayobams@gmail.com    First Bank    20000.00  Jul 31, 2021
# 446       ezughaalexander@gmail.com  Diamond Bank    20000.00  Jul 31, 2021
# 447          rebeccaotaru@gmail.com       EcoBank    80000.00  Jul 31, 2021
# 448              elderags@yahoo.com  Stanbic IBTC    24500.00  Jul 31, 2021
# 449        olaoyekehinde1@gmail.com       EcoBank    61500.00  Jul 31, 2021
#
#      Posting_Date  transactionId  BalanceOutstanding
# 0           44409       24999906            25426.66
# 1           44409       25011145             4683.33
# 2           44409       24998061            19497.24
# 3           44409       24998528            19497.24
# 4           44409       25001640            21693.40
# ..            ...            ...                 ...
# 445         44408       24967687             9329.37
# 446         44408       24974774            22858.16
# 447         44408       24968763                0.00
# 448         44408       24967669             2000.00
# 449         44408       24975575            15996.00
#
# [450 rows x 14 columns]

# %%
dca.nunique()
# Out:
# systemloanId          309
# DCA 2                  11
# Assignment_Date         7
# Assignment_Type         3
# Amount_Delinquent     105
# Repayment_Amount      228
# mobilePhone1          309
# emailAddress          309
# BankName               17
# loanAmount            176
# Value_Date             52
# Posting_Date           31
# transactionId         450
# BalanceOutstanding    270
# dtype: int64

# %%
dca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   systemloanId        450 non-null    object
#  1   DCA 2               450 non-null    object
#  2   Assignment_Date     450 non-null    object
#  3   Assignment_Type     450 non-null    object
#  4   Amount_Delinquent   152 non-null    float64
#  5   Repayment_Amount    450 non-null    float64
#  6   mobilePhone1        450 non-null    int64
#  7   emailAddress        450 non-null    object
#  8   BankName            449 non-null    object
#  9   loanAmount          450 non-null    float64
#  10  Value_Date          450 non-null    object
#  11  Posting_Date        450 non-null    int64
#  12  transactionId       450 non-null    int64
#  13  BalanceOutstanding  450 non-null    float64
# dtypes: float64(4), int64(3), object(7)
# memory usage: 49.3+ KB

# %%
dca['BankName']=dca['BankName'].astype('category')

# %% [markdown]
# ## Sort a DataFrame with the sort_values Method I
# - The `sort_values` method sorts a **DataFrame** by the values in one or more columns. The default sort is an ascending one (alphabetical for strings).
# - The first parameter (`by`) expects the column(s) to sort by.
# - If sorting by a single column, pass a string with its name.
# - The `ascending` parameter customizes the sort order.
# - The `na_position` parameter customizes where pandas places `NaN` values.

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7     215
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5     225
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5     195
# 3         Clint Capela       Atlanta Hawks        C   6-10     256
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10     240
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3     180
# 588      Landry Shamet  Washington Wizards        G    6-4     190
# 589   Tristan Vukcevic  Washington Wizards        F   6-10     220
# 590       Delon Wright  Washington Wizards        G    6-5     185
# 591                NaN                 NaN      NaN    NaN       0
#
#            College    Salary
# 0        Villanova   4556983
# 1       Fenerbahce  18700000
# 2         Michigan   4094244
# 3      Elan Chalon  20616000
# 4         Maryland   2581522
# ..             ...       ...
# 587         Toledo   1719864
# 588  Wichita State  10250000
# 589    Real Madrid         0
# 590           Utah   8195122
# 591            NaN         0
#
# [592 rows x 7 columns]

# %%
# use the sort values to arrange your data 
nba.sort_values("Salary", ascending=True)
# Out:
#                    Name                   Team Position Height  Weight  \
# 591                 NaN                    NaN      NaN    NaN       0
# 441          Louis King     Philadelphia 76ers        F    6-7     205
# 440    Danuel House Jr.     Philadelphia 76ers      F-G    6-6     220
# 132      Christian Wood       Dallas Mavericks        F    6-9     214
# 133  McKinley Wright IV       Dallas Mavericks        G   5-11     192
# ..                  ...                    ...      ...    ...     ...
# 145        Nikola Jokic         Denver Nuggets        C   6-11     284
# 261        LeBron James     Los Angeles Lakers        F    6-9     250
# 436         Joel Embiid     Philadelphia 76ers      C-F    7-0     280
# 461        Kevin Durant           Phoenix Suns        F   6-10     240
# 175       Stephen Curry  Golden State Warriors        G    6-2     185
#
#                           College    Salary
# 591                           NaN         0
# 441                        Oregon         0
# 440                     Texas A&M         0
# 132                          UNLV         0
# 133                      Colorado         0
# ..                            ...       ...
# 145                   Mega Basket  47607350
# 261  St. Vincent-St. Mary HS (OH)  47607350
# 436                        Kansas  47607350
# 461                         Texas  47649433
# 175                      Davidson  51915615
#
# [592 rows x 7 columns]

# %%
wd.isna().sum()
# Out:
# systemloanId            0
# DCA 2                   0
# Assignment_Date         0
# Assignment_Type         0
# Amount_Delinquent     298
# Repayment_Amount        0
# mobilePhone1            0
# emailAddress            0
# BankName                1
# loanAmount              0
# Value_Date              0
# Posting_Date            0
# transactionId           0
# BalanceOutstanding      0
# dtype: int64

# %%
wd.sort_values("Amount_Delinquent", na_position=)
# Out:
#   Cell In[1], line 1
#     wd.sort_values("Amount_Delinquent", na_position=)
#                                         ^
# SyntaxError: expected argument value expression

# %% [markdown]
# ## Sort a DataFrame with the sort_values Method II
# - To sort by multiple columns, pass the `by` parameter a list of column names. Pandas will sort in the specified column order (first to last).
# - Pass the `ascending` parameter a Boolean to sort all columns in a consistent order (all ascending or all descending).
# - Pass `ascending` a list to customize the sort order *per* column. The `ascending` list length must match the `by` list.

# %%
dca.sort_values(by='Repayment_Amount', ascending=True)
# Out:
#      systemloanId              DCA 2 Assignment_Date Assignment_Type  \
# 90   306199059397      Pelumi Fatoki     Oct 7, 2020          91-120
# 303  305415063205  un-assigned agent     Oct 7, 2020          91-120
# 347  305029882099    Kehinde Abraham    Jun 24, 2020          91-120
# 311  305415063205  un-assigned agent     Oct 7, 2020          91-120
# 297  305415063205  un-assigned agent     Oct 7, 2020          91-120
# ..            ...                ...             ...             ...
# 235  306555065356       Ridwan Akeeb    Aug 11, 2021            120+
# 183     303208867  un-assigned agent     Oct 7, 2020          91-120
# 386  305848498565       Stephen Udoh     Jul 6, 2020           61-90
# 208  305114297293  un-assigned agent    Jul 13, 2020           61-90
# 128  305754667042  un-assigned agent     May 8, 2020          91-120
#
#      Amount_Delinquent  Repayment_Amount   mobilePhone1  \
# 90                47.0         -62804.67  2348035324129
# 303               16.0         -60000.00  2348032632702
# 347                NaN         -40000.00  2348023176166
# 311               16.0         -20000.00  2348032632702
# 297               16.0         -15520.00  2348032632702
# ..                 ...               ...            ...
# 235               42.0          72066.05  2348065325506
# 183               35.0          74500.00  2348125712809
# 386                NaN          76663.88  2347036088491
# 208                NaN          82180.00  2348092000006
# 128                1.0         351232.06  2347013778537
#
#                  emailAddress            BankName  loanAmount    Value_Date  \
# 90         madu2525@yahoo.com         Zenith Bank    60000.00   Aug 6, 2021
# 303        oolayode@gmail.com                 UBA   181500.00  Oct 22, 2020
# 347    peaceenikele@yahoo.com          First Bank   664000.00  Jul 23, 2021
# 311        oolayode@gmail.com                 UBA   181500.00  Nov 30, 2020
# 297        oolayode@gmail.com                 UBA   181500.00   Feb 1, 2021
# ..                        ...                 ...         ...           ...
# 235      joeaboh961@gmail.com  Standard Chartered   155500.00  Aug 19, 2021
# 183          segkaa@gmail.com         Zenith Bank    67500.00  Aug 15, 2021
# 386        panycool@yahoo.com          First Bank    76588.34  Jul 28, 2021
# 208      yemijewels@gmail.com       Sterling Bank   477000.00  Aug 18, 2021
# 128  danteonyirimba@yahoo.com         Zenith Bank   270500.00  Aug 10, 2021
#
#      Posting_Date  transactionId  BalanceOutstanding
# 90          44414       25123176            32804.67
# 303         44432       25451611                0.00
# 347         44403       24855076           126122.62
# 311         44432       25451610                0.00
# 297         44432       25451609                0.00
# ..            ...            ...                 ...
# 235         44427       25366028                0.00
# 183         44423       25289017                0.00
# 386         44405       24909724                0.00
# 208         44426       25346436                0.00
# 128         44418       25198690                0.00
#
# [450 rows x 14 columns]

# %%
dca.fillna(0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 dca.fillna(0)
#
# File ~/anaconda3/envs/data-science-env/lib/python3.12/site-packages/pandas/core/generic.py:7434, in NDFrame.fillna(self, value, method, axis, inplace, limit, downcast)
#    7432         new_data = result._mgr
#    7433     else:
# -> 7434         new_data = self._mgr.fillna(
#    7435             value=value, limit=limit, inplace=inplace, downcast=downcast
#    7436         )
#    7437 elif isinstance(value, ABCDataFrame) and self.ndim == 2:
#    7438     new_data = self.where(self.notna(), value)._mgr
#
# File ~/anaconda3/envs/data-science-env/lib/python3.12/site-packages/pandas/core/internals/base.py:186, in DataManager.fillna(self, value, limit, inplace, downcast)
#     182 if limit is not None:
#     183     # Do this validation even if we go through one of the no-op paths
#     184     limit = libalgos.validate_limit(None, limit=limit)
# --> 186 return self.apply_with_block(
#     187     "fillna",
#     188     value=value,
#     189     limit=limit,
#     190     inplace=inplace,
#     191     downcast=downcast,
#     192     using_cow=using_copy_on_write(),
#     193     already_warned=_AlreadyWarned(),
#     194 )
#
# File ~/anaconda3/envs/data-science-env/lib/python3.12/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/anaconda3/envs/data-science-env/lib/python3.12/site-packages/pandas/core/internals/blocks.py:2334, in ExtensionBlock.fillna(self, value, limit, inplace, downcast, using_cow, already_warned)
#    2331 except TypeError:
#    2332     # 3rd party EA that has not implemented copy keyword yet
#    2333     refs = None
# -> 2334     new_values = self.values.fillna(value=value, method=None, limit=limit)
#    2335     # issue the warning *after* retrying, in case the TypeError
#    2336     #  was caused by an invalid fill_value
#    2337     warnings.warn(
#    2338         # GH#53278
#    2339         "ExtensionArray.fillna added a 'copy' keyword in pandas "
#    (...)
#    2345         stacklevel=find_stack_level(),
#    2346     )
#
# File ~/anaconda3/envs/data-science-env/lib/python3.12/site-packages/pandas/core/arrays/_mixins.py:372, in NDArrayBackedExtensionArray.fillna(self, value, method, limit, copy)
#     370         else:
#     371             new_values = self[:]
# --> 372         new_values[mask] = value
#     373 else:
#     374     # We validate the fill_value even if there is nothing to fill
#     375     if value is not None:
#
# File ~/anaconda3/envs/data-science-env/lib/python3.12/site-packages/pandas/core/arrays/_mixins.py:261, in NDArrayBackedExtensionArray.__setitem__(self, key, value)
#     259 def __setitem__(self, key, value) -> None:
#     260     key = check_array_indexer(self, key)
# --> 261     value = self._validate_setitem_value(value)
#     262     self._ndarray[key] = value
#
# File ~/anaconda3/envs/data-science-env/lib/python3.12/site-packages/pandas/core/arrays/categorical.py:1589, in Categorical._validate_setitem_value(self, value)
#    1587     return self._validate_listlike(value)
#    1588 else:
# -> 1589     return self._validate_scalar(value)
#
# File ~/anaconda3/envs/data-science-env/lib/python3.12/site-packages/pandas/core/arrays/categorical.py:1614, in Categorical._validate_scalar(self, fill_value)
#    1612     fill_value = self._unbox_scalar(fill_value)
#    1613 else:
# -> 1614     raise TypeError(
#    1615         "Cannot setitem on a Categorical with a new "
#    1616         f"category ({fill_value}), set the categories first"
#    1617     ) from None
#    1618 return fill_value
#
# TypeError: Cannot setitem on a Categorical with a new category (0), set the categories first

# %%
dca['Amount_Delinquent']= dca['Amount_Delinquent'].rank(ascending=False).astype(int)
dca
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 dca['Amount_Delinquent']= dca['Amount_Delinquent'].rank(ascending=False).astype(int)
#       2 dca
#
# File ~/anaconda3/envs/data-science-env/lib/python3.12/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~/anaconda3/envs/data-science-env/lib/python3.12/site-packages/pandas/core/internals/managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File ~/anaconda3/envs/data-science-env/lib/python3.12/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/anaconda3/envs/data-science-env/lib/python3.12/site-packages/pandas/core/internals/blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     755         raise ValueError("Can not squeeze with more than one column.")
#     756     values = values[0, :]  # type: ignore[call-overload]
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#
# File ~/anaconda3/envs/data-science-env/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File ~/anaconda3/envs/data-science-env/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/anaconda3/envs/data-science-env/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:101, in _astype_nansafe(arr, dtype, copy, skipna)
#      96     return lib.ensure_string_array(
#      97         arr, skipna=skipna, convert_na_value=False
#      98     ).reshape(shape)
#     100 elif np.issubdtype(arr.dtype, np.floating) and dtype.kind in "iu":
# --> 101     return _astype_float_to_int_nansafe(arr, dtype, copy)
#     103 elif arr.dtype == object:
#     104     # if we have a datetime/timedelta array of objects
#     105     # then coerce to datetime64[ns] and use DatetimeArray.astype
#     107     if lib.is_np_dtype(dtype, "M"):
#
# File ~/anaconda3/envs/data-science-env/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:145, in _astype_float_to_int_nansafe(values, dtype, copy)
#     141 """
#     142 astype with a check preventing converting NaN to an meaningless integer value.
#     143 """
#     144 if not np.isfinite(values).all():
# --> 145     raise IntCastingNaNError(
#     146         "Cannot convert non-finite values (NA or inf) to integer"
#     147     )
#     148 if dtype.kind == "u":
#     149     # GH#45151
#     150     if not (values >= 0).all():
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %%
nba.sort_values(['Salary', 'Weight'], ascending=[True, False])
nba.sort_values()
# Out:
#                    Name                   Team Position Height  Weight  \
# 284  Kenneth Lofton Jr.      Memphis Grizzlies        F    6-6     275
# 418  Wendell Carter Jr.          Orlando Magic      C-F   6-10     270
# 327      Meyers Leonard        Milwaukee Bucks      F-C    7-0     260
# 457     Bismack Biyombo           Phoenix Suns        C    6-8     255
# 268    Tristan Thompson     Los Angeles Lakers      C-F    6-9     254
# ..                  ...                    ...      ...    ...     ...
# 145        Nikola Jokic         Denver Nuggets        C   6-11     284
# 436         Joel Embiid     Philadelphia 76ers      C-F    7-0     280
# 261        LeBron James     Los Angeles Lakers        F    6-9     250
# 461        Kevin Durant           Phoenix Suns        F   6-10     240
# 175       Stephen Curry  Golden State Warriors        G    6-2     185
#
#                           College    Salary
# 284                Louisiana Tech         0
# 418                          Duke         0
# 327                      Illinois         0
# 457        Baloncesto Fuenlabrada         0
# 268                  Texas-Austin         0
# ..                            ...       ...
# 145                   Mega Basket  47607350
# 436                        Kansas  47607350
# 261  St. Vincent-St. Mary HS (OH)  47607350
# 461                         Texas  47649433
# 175                      Davidson  51915615
#
# [592 rows x 7 columns]

# %% [markdown]
# ## Sort a DataFrame by its Index
# - The `sort_index` method sorts the **DataFrame** by its index positions/labels.

# %% [markdown]
# ## Rank Values with the rank Method
# - The `rank` method assigns a numeric ranking to each **Series** value.
# - Pandas will assign the same rank to equal values and create a "gap" in the dataset for the ranks.

# %%
pca = pd.read_excel(file)

# %%
pca = pca.dropna()
pca.isnull().sum()
# Out:
# systemloanId          0
# DCA 2                 0
# Assignment_Date       0
# Assignment_Type       0
# Amount_Delinquent     0
# Repayment_Amount      0
# mobilePhone1          0
# emailAddress          0
# BankName              0
# loanAmount            0
# Value_Date            0
# Posting_Date          0
# transactionId         0
# BalanceOutstanding    0
# dtype: int64

# %%
pca['Amount_Delinquent'] = pca['Amount_Delinquent'].astype(int)
pca
# Out:
#      systemloanId             DCA 2 Assignment_Date Assignment_Type  \
# 1    305919711003      Stephen Udoh     Oct 7, 2020          91-120
# 5    305420813733      Stephen Udoh    Jun 24, 2020          91-120
# 6    305573486175      Stephen Udoh    Jun 24, 2020          91-120
# 8    305852396706   Kehinde Abraham     Jul 6, 2020           61-90
# 9    305831623826     Pelumi Fatoki     Jul 6, 2020           61-90
# ..            ...               ...             ...             ...
# 441  305580766309      Stephen Udoh    Jun 24, 2020          91-120
# 442  305935346782     Taiwo Abraham     Jul 6, 2020           61-90
# 446  306636404787  Olalekan Olaokun    Jan 12, 2021          91-120
# 447  305645708159  Olalekan Olaokun     Jul 6, 2020          91-120
# 448  305785433039      Ridwan Akeeb     Oct 7, 2020          91-120
#
#      Amount_Delinquent  Repayment_Amount   mobilePhone1  \
# 1                  182           2300.00  2348186023049
# 5                   81           1000.00  2348062411335
# 6                   81           2472.50  2348034914546
# 8                   81           2000.00  2348034381543
# 9                   81           2000.00  2348022159679
# ..                 ...               ...            ...
# 441                 81           1286.25  2348142961129
# 442                 81           2081.00  2348035323478
# 446                 81             50.00  2348143758790
# 447                 81          50064.34  2348027181436
# 448                172           2528.25  2348023253702
#
#                    emailAddress      BankName  loanAmount    Value_Date  \
# 1         peresinde68@gmail.com       GT Bank     23000.0   Aug 1, 2021
# 5       gracemercymfb@gmail.com    First Bank      8500.0   Aug 2, 2021
# 6    mytwinangels2014@yahoo.com           UBA      2500.0   Aug 2, 2021
# 8           enobong77@gmail.com           UBA     20000.0   Aug 2, 2021
# 9      masterchoice36@gmail.com       GT Bank     49500.0   Aug 2, 2021
# ..                          ...           ...         ...           ...
# 441  oshydamiagbolade@gmail.com          FCMB      4000.0  Jul 31, 2021
# 442        sjegede495@gmail.com       GT Bank      7000.0  Jul 31, 2021
# 446   ezughaalexander@gmail.com  Diamond Bank     20000.0  Jul 31, 2021
# 447      rebeccaotaru@gmail.com       EcoBank     80000.0  Jul 31, 2021
# 448          elderags@yahoo.com  Stanbic IBTC     24500.0  Jul 31, 2021
#
#      Posting_Date  transactionId  BalanceOutstanding
# 1           44409       25011145             4683.33
# 5           44410       25025917             4380.88
# 6           44410       25027496                0.00
# 8           44410       25023455            17490.66
# 9           44410       25028476            57624.86
# ..            ...            ...                 ...
# 441         44408       24972290                0.00
# 442         44408       24967787             2006.66
# 446         44408       24974774            22858.16
# 447         44408       24968763                0.00
# 448         44408       24967669             2000.00
#
# [244 rows x 14 columns]

# %%
pca['Repayment_Amount'].rank(ascending=False)
# Out:
# 1      161.5
# 5      205.0
# 6      157.0
# 8      176.0
# 9      176.0
#        ...
# 441    196.0
# 442    166.0
# 446    231.5
# 447      4.0
# 448    154.0
# Name: Repayment_Amount, Length: 244, dtype: float64

# %%
pca['Ranking'] = pca['Repayment_Amount'].rank(ascending=False).astype(int)
pca.sort_values('Repayment_Amount', ascending=False)
# Out:
#      systemloanId             DCA 2 Assignment_Date Assignment_Type  \
# 386  305848498565      Stephen Udoh     Jul 6, 2020           61-90
# 235  306555065356      Ridwan Akeeb    Aug 11, 2021            120+
# 88   306199059397     Pelumi Fatoki     Oct 7, 2020          91-120
# 447  305645708159  Olalekan Olaokun     Jul 6, 2020          91-120
# 153  306603605157   Michael Egwuatu    Aug 11, 2021            120+
# ..            ...               ...             ...             ...
# 414  304553375730   Michael Egwuatu     Jul 6, 2020           61-90
# 420  304553375730   Michael Egwuatu     Jul 6, 2020           61-90
# 410  304553375730   Michael Egwuatu     Jul 6, 2020           61-90
# 347  305029882099   Kehinde Abraham    Jun 24, 2020          91-120
# 90   306199059397     Pelumi Fatoki     Oct 7, 2020          91-120
#
#      Amount_Delinquent  Repayment_Amount   mobilePhone1  \
# 386                 81          76663.88  2347036088491
# 235                230          72066.05  2348065325506
# 88                 226          62804.67  2348035324129
# 447                 81          50064.34  2348027181436
# 153                242          50000.00  2348039410977
# ..                 ...               ...            ...
# 414                 81          -5000.00  2347038175188
# 420                 81          -6000.00  2347038175188
# 410                 81         -10000.00  2347038175188
# 347                 81         -40000.00  2348023176166
# 90                 226         -62804.67  2348035324129
#
#                   emailAddress            BankName  loanAmount    Value_Date  \
# 386         panycool@yahoo.com          First Bank    76588.34  Jul 28, 2021
# 235       joeaboh961@gmail.com  Standard Chartered   155500.00  Aug 19, 2021
# 88          madu2525@yahoo.com         Zenith Bank    60000.00   Aug 6, 2021
# 447     rebeccaotaru@gmail.com             EcoBank    80000.00  Jul 31, 2021
# 153  ogungbeifeoluwa@gmail.com             EcoBank   273000.00  Aug 12, 2021
# ..                         ...                 ...         ...           ...
# 414   kotilaadeyinka@yahoo.com             GT Bank   156000.00  Mar 19, 2021
# 420   kotilaadeyinka@yahoo.com             GT Bank   156000.00  May 13, 2021
# 410   kotilaadeyinka@yahoo.com             GT Bank   156000.00  Mar 22, 2021
# 347     peaceenikele@yahoo.com          First Bank   664000.00  Jul 23, 2021
# 90          madu2525@yahoo.com         Zenith Bank    60000.00   Aug 6, 2021
#
#      Posting_Date  transactionId  BalanceOutstanding  Ranking
# 386         44405       24909724                0.00        1
# 235         44427       25366028                0.00        2
# 88          44414       25123170            32804.67        3
# 447         44408       24968763                0.00        4
# 153         44420       25240931            66299.07        5
# ..            ...            ...                 ...      ...
# 414         44407       24948780             5000.00      239
# 420         44407       24948778             5000.00      241
# 410         44407       24948779             5000.00      242
# 347         44403       24855076           126122.62      243
# 90          44414       25123176            32804.67      244
#
# [244 rows x 15 columns]

# %%
pca.sort_values(by='Amount_Delinquent', ascending=True)
# Out:
#      systemloanId            DCA 2 Assignment_Date Assignment_Type  \
# 171  306603605157  Michael Egwuatu    Aug 11, 2021            120+
# 153  306603605157  Michael Egwuatu    Aug 11, 2021            120+
# 173  306603605157  Michael Egwuatu    Aug 11, 2021            120+
# 154  306603605157  Michael Egwuatu    Aug 11, 2021            120+
# 170  306603605157  Michael Egwuatu    Aug 11, 2021            120+
# ..            ...              ...             ...             ...
# 246  305702635922  Michael Egwuatu     Jul 6, 2020           61-90
# 247  305837670352  Kehinde Abraham     Jul 6, 2020           61-90
# 251  305903669625  Michael Egwuatu    Jul 13, 2020           61-90
# 80   305650928119    Pelumi Fatoki     Jul 6, 2020          91-120
# 218  305858923549     Ridwan Akeeb     Jul 6, 2020           61-90
#
#      Amount_Delinquent  Repayment_Amount   mobilePhone1  \
# 171                  3          36000.00  2348039410977
# 153                  3          50000.00  2348039410977
# 173                  3          18299.08  2348039410977
# 154                  3          35000.00  2348039410977
# 170                  3          12000.00  2348039410977
# ..                 ...               ...            ...
# 246                163            200.00  2347036668542
# 247                163           2180.00  2348063816356
# 251                163           5000.00  2347068497568
# 80                 163           5000.00  2348037036726
# 218                163           1500.00  2348075271768
#
#                            emailAddress    BankName  loanAmount    Value_Date  \
# 171           ogungbeifeoluwa@gmail.com     EcoBank    273000.0  Aug 13, 2021
# 153           ogungbeifeoluwa@gmail.com     EcoBank    273000.0  Aug 12, 2021
# 173           ogungbeifeoluwa@gmail.com     EcoBank    273000.0  Aug 13, 2021
# 154           ogungbeifeoluwa@gmail.com     EcoBank    273000.0  Aug 12, 2021
# 170           ogungbeifeoluwa@gmail.com     EcoBank    273000.0  Aug 13, 2021
# ..                                  ...         ...         ...           ...
# 246                 kanmare19@yahoo.com     GT Bank     50000.0  Aug 20, 2021
# 247  sundayoluwafemiomitowoju@gmail.com  First Bank     36500.0  Aug 20, 2021
# 251              rolandmario2@gmail.com  First Bank     27000.0  Aug 20, 2021
# 80                 afnanareef@gmail.com     GT Bank     75000.0   Aug 6, 2021
# 218                tionjaphet@gmail.com  First Bank     10500.0  Aug 19, 2021
#
#      Posting_Date  transactionId  BalanceOutstanding
# 171         44421       25251188                0.00
# 153         44420       25240931            66299.07
# 173         44421       25256796                0.00
# 154         44420       25240104            66299.07
# 170         44421       25255422                0.00
# ..            ...            ...                 ...
# 246         44428       25376799            49679.04
# 247         44428       25374811            28051.16
# 251         44428       25386851             7546.26
# 80          44414       25124613            72700.83
# 218         44427       25357761                0.00
#
# [244 rows x 14 columns]
