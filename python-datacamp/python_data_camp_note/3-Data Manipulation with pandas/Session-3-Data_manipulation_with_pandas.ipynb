# %% [markdown]
# ## Import Libary and Data

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### CleanAce Finishing (df_cl_finishing)
# ____

# %%
file_path = r'/Users/teslim/OneDrive/generaldata/8_data_finishing_dept.csv'
df_presser = pd.read_csv(file_path)
df_presser
# Out:
#        Name      Mode      Shop  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  \
# 0    ALIDU       Suit    Lekki    13   13   13   13   13   13   13   13  120
# 1   KAZEEM      Shirt    Lekki   124  124  124  124  124  124  124  124  110
# 2     AUDU     Native  Maryland  120  120  120  120  120  120  120  120  131
# 3    USOROH  Delicate    Festac  110  110  110  110  110  110  110  110  120
# 4    DOMINC     Buba     Lekki   131  131  131  131  131  131  131  131   77
# ..      ...       ...       ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 67   USOROH      Suit    Festac  131  131  131  131  120  131  133  131  131
# 68   USOROH  Delicate    Festac  120  120  120  120  118  120  133  120  131
# 69   DOMINC     Buba     Lekki   118  118  118  118   13  118  133  118  131
# 70     RAJI    Sokoto    Lekki    13   13   13   13  124  119   13   13  131
# 71     OKON   Machine  Maryland  124  124  124  124  120  120  124  124  131
#
#     Oct  Nov     date
# ...

# %%
# list all the columns in the dataframe
df_presser.columns
# Out:
# Index(['name', 'mode', 'shop', 'jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul',
#        'aug', 'sep', 'oct', 'nov', 'date'],
#       dtype='object')

# %%
# convert all the columns to lower case
df_presser.columns = df_presser.columns.str.lower()
df_presser.head()
# Out:
#       name      mode      shop  jan  feb  mar  apr  may  jun  jul  aug  sep  \
# 0   ALIDU       Suit    Lekki    13   13   13   13   13   13   13   13  120
# 1  KAZEEM      Shirt    Lekki   124  124  124  124  124  124  124  124  110
# 2    AUDU     Native  Maryland  120  120  120  120  120  120  120  120  131
# 3   USOROH  Delicate    Festac  110  110  110  110  110  110  110  110  120
# 4   DOMINC     Buba     Lekki   131  131  131  131  131  131  131  131   77
#
#    oct  nov     date
# 0  110  131  1/31/19
# 1  131  120   2/1/19
# 2  120  118   3/1/19
# 3   77   13   4/1/19
# 4  124  124   5/1/19

# %%
# collecting all the categorical columns to a dataframe
columns_to_convert = df_presser[["name", "mode", "shop"]]
columns_to_convert
# Out:
#        name      mode      shop
# 0    ALIDU       Suit    Lekki
# 1   KAZEEM      Shirt    Lekki
# 2     AUDU     Native  Maryland
# 3    USOROH  Delicate    Festac
# 4    DOMINC     Buba     Lekki
# ..      ...       ...       ...
# 67   USOROH      Suit    Festac
# 68   USOROH  Delicate    Festac
# 69   DOMINC     Buba     Lekki
# 70     RAJI    Sokoto    Lekki
# 71     OKON   Machine  Maryland
#
# [72 rows x 3 columns]

# %%
# Define the function to clean data
def clean_data(df, columns):
    for column in columns_to_convert:
        # Remove all spaces in the column
        df[column] = df[column].str.replace(' ', '')
        
        # Convert all entries in the column to lowercase
        df[column] = df[column].str.lower()
        
        # Remove leading and trailing spaces in the column
        df[column] = df[column].str.strip()

    
    return df

# Call the function to clean the data
df_cleaned = clean_data(df_presser, columns_to_convert)

# %%
df_presser
# Out:
#       name      mode      shop  jan  feb  mar  apr  may  jun  jul  aug  sep  \
# 0    alidu      suit     lekki   13   13   13   13   13   13   13   13  120
# 1   kazeem     shirt     lekki  124  124  124  124  124  124  124  124  110
# 2     audu    native  maryland  120  120  120  120  120  120  120  120  131
# 3   usoroh  delicate    festac  110  110  110  110  110  110  110  110  120
# 4   dominc      buba     lekki  131  131  131  131  131  131  131  131   77
# ..     ...       ...       ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 67  usoroh      suit    festac  131  131  131  131  120  131  133  131  131
# 68  usoroh  delicate    festac  120  120  120  120  118  120  133  120  131
# 69  dominc      buba     lekki  118  118  118  118   13  118  133  118  131
# 70    raji    sokoto     lekki   13   13   13   13  124  119   13   13  131
# 71    okon   machine  maryland  124  124  124  124  120  120  124  124  131
#
#     oct  nov     date
# 0   110  131  1/31/19
# ...

# %% [markdown]
# ### World Economy Data
# ____

# %%
df_eco_data = pd.read_excel(r'/Users/teslim/OneDrive/generaldata/13_world_gdp_data.xlsx')
df_eco_data = df_eco_data.rename(columns={"n": "continent"})
df_eco_data
# Out:
#            continent  ISO         COUNTRY                          INDICATOR  \
# 0             Africa  DZA         Algeria                           Real GDP
# 1             Africa  DZA         Algeria                        Nominal GDP
# 2             Africa  DZA         Algeria                         Employment
# 3             Africa  DZA         Algeria               Average Hours Worked
# 4             Africa  DZA         Algeria                        Total Hours
# ...              ...  ...             ...                                ...
# 2123  Western Europe  GBR  United Kingdom                 Total Hours growth
# 2124  Western Europe  GBR  United Kingdom                  Population growth
# 2125  Western Europe  GBR  United Kingdom  Output per Employed Person growth
# 2126  Western Europe  GBR  United Kingdom      Output per Hour Worked growth
# 2127  Western Europe  GBR  United Kingdom           Per Capita Income growth
#
# ...

# %%
df_eco_clean_data = df_eco_data.dropna()
df_eco_clean_data= df_eco_clean_data.set_index('continent')
df_eco_clean_data
# Out:
#                 ISO         COUNTRY                   INDICATOR     1950  \
# continent
# Africa          DZA         Algeria                    Real GDP  40781.7
# Africa          DZA         Algeria                 Nominal GDP   4508.7
# Africa          DZA         Algeria                  Employment   1744.0
# Africa          DZA         Algeria                  Population   8892.7
# Africa          DZA         Algeria  Output per Employed Person  23384.0
# ...             ...             ...                         ...      ...
# Western Europe  GBR  United Kingdom                 Total Hours  46912.0
# Western Europe  GBR  United Kingdom                  Population  50127.0
# Western Europe  GBR  United Kingdom  Output per Employed Person  27304.0
# Western Europe  GBR  United Kingdom      Output per Hour Worked     14.0
# Western Europe  GBR  United Kingdom           Per Capita Income  12662.0
#
#                    1951     1952     1953     1954     1955     1956  ...  \
# ...

# %% [markdown]
# ### CleanAce Financials (df_cl_financials)
# ____

# %%
df_financial =  pd.read_csv(r'/Users/teslim/OneDrive/generaldata/6_cleanace_financials_data.csv')
df_financial.head()
# Out:
#                Class         ACCT      LEDGER           Jan           Feb  \
# 0  Income  statement   Maryland     Revenue    8,215,560.47  6,219,423.82
# 1  Income  statement      Festac    Revenue    4,588,868.74  3,629,114.00
# 2  Income  statement       Ogudu    Revenue    3,435,556.75  2,862,071.00
# 3  Income  statement    Gbagada     Revenue      402,593.50    264,692.00
# 4  Income  statement    Surulere    Revenue      371,733.50    260,484.00
#
#             Mar           Apr           May           Jun           Jul  \
# 0  7,825,835.09  7,729,751.62  8,028,021.76  6,614,444.62  7,694,189.00
# 1  4,212,707.59  3,862,587.25  4,115,483.74  3,312,023.25  4,287,521.00
# 2  2,864,123.50  3,565,058.25  3,339,617.25  2,906,029.00  3,355,540.20
# 3    360,857.50    480,453.00    396,217.00    398,944.00    475,485.00
# 4    292,117.50    185,880.00    226,000.00    316,192.00      8,550.00
#
#             Aug           Sep           Oct           Nov           Dec
# ...

# %%
# list all the columns in the dataframe
df_financial.columns
# Out:
# Index(['Class', 'ACCT', 'LEDGER', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
#        'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
#       dtype='object')

# %%
# change all the columns to lower case
df_financial.columns = df_financial.columns.str.lower()
df_financial.head()
# Out:
#                class         acct      ledger           jan           feb  \
# 0  Income  statement   Maryland     Revenue    8,215,560.47  6,219,423.82
# 1  Income  statement      Festac    Revenue    4,588,868.74  3,629,114.00
# 2  Income  statement       Ogudu    Revenue    3,435,556.75  2,862,071.00
# 3  Income  statement    Gbagada     Revenue      402,593.50    264,692.00
# 4  Income  statement    Surulere    Revenue      371,733.50    260,484.00
#
#             mar           apr           may           jun           jul  \
# 0  7,825,835.09  7,729,751.62  8,028,021.76  6,614,444.62  7,694,189.00
# 1  4,212,707.59  3,862,587.25  4,115,483.74  3,312,023.25  4,287,521.00
# 2  2,864,123.50  3,565,058.25  3,339,617.25  2,906,029.00  3,355,540.20
# 3    360,857.50    480,453.00    396,217.00    398,944.00    475,485.00
# 4    292,117.50    185,880.00    226,000.00    316,192.00      8,550.00
#
#             aug           sep           oct           nov           dec
# ...

# %%
# chcecking the data types
df_financial.dtypes
# Out:
# class     object
# acct      object
# ledger    object
# jan       object
# feb       object
# mar       object
# apr       object
# may       object
# jun       object
# jul       object
# aug       object
# sep       object
# oct       object
# nov       object
# dec       object
# dtype: object

# %%
# Subset categorical data
df_financial_categorical = df_financial[["acct", "ledger", "class"]]
df_financial_categorical
# Out:
#                                        acct                    ledger  \
# 0                                Maryland                   Revenue
# 1                                   Festac                  Revenue
# 2                                    Ogudu                  Revenue
# 3                                 Gbagada                   Revenue
# 4                                 Surulere                  Revenue
# ..                                      ...                       ...
# 120               Witholding Tax_Rent_2019             Tax Liability
# 121                    VAT Payable Account             Tax Liability
# 122                           PAYE Account             Tax Liability
# 123   BOI Finance_Due More than 12 months     Non Current Liability
# 124       BOI Finance_Due Within 12 months    Current Term Liability
#
#                  class
# 0    Income  statement
# 1    Income  statement
# 2    Income  statement
# 3    Income  statement
# ...

# %%
# Assuming df_financial_categorical has been cleaned
df_financial[["acct", "ledger", "class"]] = df_financial_categorical

# Checking the first few rows to verify the changes
df_financial.head()
# Out:
#                class         acct      ledger           jan           feb  \
# 0  Income  statement   Maryland     Revenue    8,215,560.47  6,219,423.82
# 1  Income  statement      Festac    Revenue    4,588,868.74  3,629,114.00
# 2  Income  statement       Ogudu    Revenue    3,435,556.75  2,862,071.00
# 3  Income  statement    Gbagada     Revenue      402,593.50    264,692.00
# 4  Income  statement    Surulere    Revenue      371,733.50    260,484.00
#
#             mar           apr           may           jun           jul  \
# 0  7,825,835.09  7,729,751.62  8,028,021.76  6,614,444.62  7,694,189.00
# 1  4,212,707.59  3,862,587.25  4,115,483.74  3,312,023.25  4,287,521.00
# 2  2,864,123.50  3,565,058.25  3,339,617.25  2,906,029.00  3,355,540.20
# 3    360,857.50    480,453.00    396,217.00    398,944.00    475,485.00
# 4    292,117.50    185,880.00    226,000.00    316,192.00      8,550.00
#
#             aug           sep           oct           nov           dec
# ...

# %%
# # Subset numerica dat
df_financial_numerical = df_financial[["jan", "feb", "mar", "apr", "may", "jun", "jul", "aug", "sep", "oct", "nov", "dec"]]
df_financial_numerical.head()
# Out:
#             jan           feb           mar           apr           may  \
# 0  8,215,560.47  6,219,423.82  7,825,835.09  7,729,751.62  8,028,021.76
# 1  4,588,868.74  3,629,114.00  4,212,707.59  3,862,587.25  4,115,483.74
# 2  3,435,556.75  2,862,071.00  2,864,123.50  3,565,058.25  3,339,617.25
# 3    402,593.50    264,692.00    360,857.50    480,453.00    396,217.00
# 4    371,733.50    260,484.00    292,117.50    185,880.00    226,000.00
#
#             jun           jul           aug           sep           oct  \
# 0  6,614,444.62  7,694,189.00  8,930,779.50  7,968,584.00  7,713,938.00
# 1  3,312,023.25  4,287,521.00  4,046,863.75  3,333,375.00  3,772,280.00
# 2  2,906,029.00  3,355,540.20  3,479,803.25  2,975,709.10  3,334,714.00
# 3    398,944.00    475,485.00    560,414.00    497,833.00    667,439.50
# 4    316,192.00      8,550.00          Nil           Nil            NaN
#
#             nov           dec
# 0  8,126,173.50  8,750,062.00
# 1  3,635,478.00  4,196,635.00
# ...

# %%
# check the first few rows of the numerical data
df_financial_numerical.dtypes
# Out:
# jan    object
# feb    object
# mar    object
# apr    object
# may    object
# jun    object
# jul    object
# aug    object
# sep    object
# oct    object
# nov    object
# dec    object
# dtype: object

# %%
# Define a function to clean numeric data

def clean_numeric_data(df, column_name):
    # Convert the entire column to string first
    df[column_name] = df[column_name].astype(str)
    # Remove commas
    df[column_name] = df[column_name].str.replace(',', '', regex=False)
    # Strip leading and trailing spaces
    df[column_name] = df[column_name].str.strip()
    # Replace problematic strings with '0.0' (or use np.nan if you prefer)
    df[column_name] = df[column_name].replace(['#REF!', 'Nil', 'NIl', 'NIl!'], '0.0')
    # Convert the data into float, coercing errors to NaN
    df[column_name] = pd.to_numeric(df[column_name], errors='coerce')
    return df

# Assuming df_financial_numerical is defined and has numeric data with potential issues
# Convert the numerical data to float
for column in df_financial_numerical.columns:
    df_financial_numerical = clean_numeric_data(df_financial_numerical, column)

# Checking the first few rows to verify the changes
df_financial_numerical.head()
# Out:
# /var/folders/v9/v9j8bf6j2r5cr97thvfgxxyh0000gn/T/ipykernel_11308/3336215178.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[column_name].astype(str)
# /var/folders/v9/v9j8bf6j2r5cr97thvfgxxyh0000gn/T/ipykernel_11308/3336215178.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[column_name].str.replace(',', '', regex=False)
# /var/folders/v9/v9j8bf6j2r5cr97thvfgxxyh0000gn/T/ipykernel_11308/3336215178.py:9: SettingWithCopyWarning:
# ...

# %%
# confirm the data types
df_financial_numerical.dtypes
# Out:
# jan    float64
# feb    float64
# mar    float64
# apr    float64
# may    float64
# jun    float64
# jul    float64
# aug    float64
# sep    float64
# oct    float64
# nov    float64
# dec    float64
# dtype: object

# %%
df_financial[["jan", "feb", "mar", "apr", "may", "jun", "jul", "aug", "sep", "oct", "nov", "dec"]] = df_financial_numerical
df_financial.head()
# Out:
#                class         acct      ledger         jan         feb  \
# 0  Income  statement   Maryland     Revenue    8215560.47  6219423.82
# 1  Income  statement      Festac    Revenue    4588868.74  3629114.00
# 2  Income  statement       Ogudu    Revenue    3435556.75  2862071.00
# 3  Income  statement    Gbagada     Revenue     402593.50   264692.00
# 4  Income  statement    Surulere    Revenue     371733.50   260484.00
#
#           mar         apr         may         jun        jul         aug  \
# 0  7825835.09  7729751.62  8028021.76  6614444.62  7694189.0  8930779.50
# 1  4212707.59  3862587.25  4115483.74  3312023.25  4287521.0  4046863.75
# 2  2864123.50  3565058.25  3339617.25  2906029.00  3355540.2  3479803.25
# 3   360857.50   480453.00   396217.00   398944.00   475485.0   560414.00
# 4   292117.50   185880.00   226000.00   316192.00     8550.0        0.00
#
#          sep        oct        nov         dec
# 0  7968584.0  7713938.0  8126173.5  8750062.00
# ...

# %%
df_financial.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   class   125 non-null    object
#  1   acct    125 non-null    object
#  2   ledger  125 non-null    object
#  3   jan     113 non-null    float64
#  4   feb     113 non-null    float64
#  5   mar     113 non-null    float64
#  6   apr     113 non-null    float64
#  7   may     113 non-null    float64
#  8   jun     115 non-null    float64
#  9   jul     115 non-null    float64
#  10  aug     116 non-null    float64
#  11  sep     116 non-null    float64
#  12  oct     115 non-null    float64
#  13  nov     115 non-null    float64
#  14  dec     119 non-null    float64
# dtypes: float64(12), object(3)
# memory usage: 14.8+ KB

# %%
# check for missing values
df_financial.isnull().sum()
# Out:
# class      0
# acct       0
# ledger     0
# jan       12
# feb       12
# mar       12
# apr       12
# may       12
# jun       10
# jul       10
# aug        9
# sep        9
# oct       10
# nov       10
# dec        6
# dtype: int64

# %% [markdown]
# # CHAPTER 1: Subsetting and Sorting Data
# ____

# %% [markdown]
# # CHAPTER 2: Agrregating and Grouping Data
# ____

# %%
df_presser
# Out:
#        Name      Mode      Shop  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  \
# 0    ALIDU       Suit    Lekki    13   13   13   13   13   13   13   13  120
# 1   KAZEEM      Shirt    Lekki   124  124  124  124  124  124  124  124  110
# 2     AUDU     Native  Maryland  120  120  120  120  120  120  120  120  131
# 3    USOROH  Delicate    Festac  110  110  110  110  110  110  110  110  120
# 4    DOMINC     Buba     Lekki   131  131  131  131  131  131  131  131   77
# ..      ...       ...       ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 67   USOROH      Suit    Festac  131  131  131  131  120  131  133  131  131
# 68   USOROH  Delicate    Festac  120  120  120  120  118  120  133  120  131
# 69   DOMINC     Buba     Lekki   118  118  118  118   13  118  133  118  131
# 70     RAJI    Sokoto    Lekki    13   13   13   13  124  119   13   13  131
# 71     OKON   Machine  Maryland  124  124  124  124  120  120  124  124  131
#
#     Oct  Nov     date
# ...

# %%
# this is to demsontrate how to group data with the as_index parameter set to False
d1=df_presser.groupby(["Name", "Mode"]).sum()
d1.head()
# Out:
#                                Shop  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  \
# Name   Mode
# ALIDU  Delicate        Lekki Lekki   137  137  137  137  137  133  253  251
#        Shirt     Lekki Lekki Lekki   368  368  368  368  368  354  372  366
#        Suit      Lekki FestacFestac  150  150  150  150  150  146  146  153
# AUDU   Buba                  Lekki   120  120  120  120  120  120  118  120
#        Delicate  Lekki Lekki Lekki   365  365  365  365  365  350  387  379
#
#                  Sep  Oct  Nov                 date
# Name   Mode
# ALIDU  Delicate  144  137  262        2/1/2112/1/23
#        Shirt     386  372  275  8/1/2012/1/226/1/23
#        Suit      375  365  382  1/31/198/1/193/1/22
# AUDU   Buba      120  120  120               3/1/20
#        Delicate  372  358  382  10/1/202/1/238/1/23

# %%
d2=df_presser.groupby(["Name", "Mode"], as_index=False).sum()
d2.head()
# Out:
#      Name      Mode                Shop  Jan  Feb  Mar  Apr  May  Jun  Jul  \
# 0  ALIDU   Delicate        Lekki Lekki   137  137  137  137  137  133  253
# 1  ALIDU      Shirt  Lekki Lekki Lekki   368  368  368  368  368  354  372
# 2  ALIDU       Suit  Lekki FestacFestac  150  150  150  150  150  146  146
# 3   AUDU      Buba               Lekki   120  120  120  120  120  120  118
# 4   AUDU   Delicate  Lekki Lekki Lekki   365  365  365  365  365  350  387
#
#    Aug  Sep  Oct  Nov                 date
# 0  251  144  137  262        2/1/2112/1/23
# 1  366  386  372  275  8/1/2012/1/226/1/23
# 2  153  375  365  382  1/31/198/1/193/1/22
# 3  120  120  120  120               3/1/20
# 4  379  372  358  382  10/1/202/1/238/1/23

# %% [markdown]
# # CHAPTER 3: Explicit indexes
# ____

# %% [markdown]
# ### EXPLICIT INDEXES
# ____

# %% [markdown]
# #### 1. Data Cleaning
# _____

# %%
df_presser.head()
# Out:
#      name      mode      shop  jan  feb  mar  apr  may  jun  jul  aug  sep  \
# 0   alidu      suit     lekki   13   13   13   13   13   13   13   13  120
# 1  kazeem     shirt     lekki  124  124  124  124  124  124  124  124  110
# 2    audu    native  maryland  120  120  120  120  120  120  120  120  131
# 3  usoroh  delicate    festac  110  110  110  110  110  110  110  110  120
# 4  dominc      buba     lekki  131  131  131  131  131  131  131  131   77
#
#    oct  nov     date
# 0  110  131  1/31/19
# 1  131  120   2/1/19
# 2  120  118   3/1/19
# 3   77   13   4/1/19
# 4  124  124   5/1/19

# %% [markdown]
# #### 2. Setting a column as index
# ____

# %% [markdown]
# * use the `df.set_index()` method to set a column as the index of the DataFrame.

# %%
# Set the index of the dataframe to the 'oct' column
df_presser_note_1 = df_presser.set_index("jan")
df_presser_note_1.head()
# Out:
#        name      mode      shop  feb  mar  apr  may  jun  jul  aug  sep  oct  \
# jan
# 13    alidu      suit     lekki   13   13   13   13   13   13   13  120  110
# 124  kazeem     shirt     lekki  124  124  124  124  124  124  124  110  131
# 120    audu    native  maryland  120  120  120  120  120  120  120  131  120
# 110  usoroh  delicate    festac  110  110  110  110  110  110  110  120   77
# 131  dominc      buba     lekki  131  131  131  131  131  131  131   77  124
#
#      nov     date
# jan
# 13   131  1/31/19
# 124  120   2/1/19
# 120  118   3/1/19
# 110   13   4/1/19
# 131  124   5/1/19

# %% [markdown]
# #### 3. Setting a column as index  and Resetting the index
# ____

# %% [markdown]
# When we  `df.set_reset_index()`without the parameter `drop=True`, the index will reset, and while the column that was previously the index will be added to the DataFrame as a column.
#
# if parameter `drop=True` should be passed to the method, the index will reset, and the column that was previously the index will be removed from the DataFrame.

# %%
# reseting the index without the drop parameter
# Notice that the index is reset but the old index is kept as a column in the dataframe
df_presser_note_1.reset_index()
# Out:
#     jan    name      mode      shop  feb  mar  apr  may  jun  jul  aug  sep  \
# 0    13   alidu      suit     lekki   13   13   13   13   13   13   13  120
# 1   124  kazeem     shirt     lekki  124  124  124  124  124  124  124  110
# 2   120    audu    native  maryland  120  120  120  120  120  120  120  131
# 3   110  usoroh  delicate    festac  110  110  110  110  110  110  110  120
# 4   131  dominc      buba     lekki  131  131  131  131  131  131  131   77
# ..  ...     ...       ...       ...  ...  ...  ...  ...  ...  ...  ...  ...
# 67  131  usoroh      suit    festac  131  131  131  120  131  133  131  131
# 68  120  usoroh  delicate    festac  120  120  120  118  120  133  120  131
# 69  118  dominc      buba     lekki  118  118  118   13  118  133  118  131
# 70   13    raji    sokoto     lekki   13   13   13  124  119   13   13  131
# 71  124    okon   machine  maryland  124  124  124  120  120  124  124  131
#
#     oct  nov     date
# 0   110  131  1/31/19
# ...

# %%
# With the drop parameter set to True, the old index is removed from the dataframe
# the columnns are now 13 instead of 14
df_presser_note_1.reset_index(drop=True)
# Out:
#       name      mode      shop  feb  mar  apr  may  jun  jul  aug  sep  oct  \
# 0    alidu      suit     lekki   13   13   13   13   13   13   13  120  110
# 1   kazeem     shirt     lekki  124  124  124  124  124  124  124  110  131
# 2     audu    native  maryland  120  120  120  120  120  120  120  131  120
# 3   usoroh  delicate    festac  110  110  110  110  110  110  110  120   77
# 4   dominc      buba     lekki  131  131  131  131  131  131  131   77  124
# ..     ...       ...       ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 67  usoroh      suit    festac  131  131  131  120  131  133  131  131  124
# 68  usoroh  delicate    festac  120  120  120  118  120  133  120  131  124
# 69  dominc      buba     lekki  118  118  118   13  118  133  118  131  124
# 70    raji    sokoto     lekki   13   13   13  124  119   13   13  131  124
# 71    okon   machine  maryland  124  124  124  120  120  124  124  131  124
#
#     nov     date
# 0   131  1/31/19
# 1   120   2/1/19
# ...

# %% [markdown]
# #### 4. index make the subsetting simpler
# ____

# %% [markdown]
# With an index, we can use the `df.loc[]` method to subset the DataFrame. The `df.loc[]` method is used to subset the DataFrame based on labels.

# %%
# Set the index of the dataframe to the name column
df_presser_note_2 = df_presser.set_index("name")
df_presser_note_2.head()
# Out:
#             mode      shop  jan  feb  mar  apr  may  jun  jul  aug  sep  oct  \
# name
# alidu       suit     lekki   13   13   13   13   13   13   13   13  120  110
# kazeem     shirt     lekki  124  124  124  124  124  124  124  124  110  131
# audu      native  maryland  120  120  120  120  120  120  120  120  131  120
# usoroh  delicate    festac  110  110  110  110  110  110  110  110  120   77
# dominc      buba     lekki  131  131  131  131  131  131  131  131   77  124
#
#         nov     date
# name
# alidu   131  1/31/19
# kazeem  120   2/1/19
# audu    118   3/1/19
# usoroh   13   4/1/19
# dominc  124   5/1/19

# %%
# with the setting of index, it is easy to access the data
df_presser_note_2.loc["usoroh"]
# Out:
#             mode      shop  jan  feb  mar  apr  may  jun  jul  aug  sep  oct  \
# name
# usoroh  delicate    festac  110  110  110  110  110  110  110  110  120   77
# usoroh  delicate     lekki  124  124  124  124  124  124  120  124  124  124
# usoroh    sokoto     lekki  118  118  118  118  118  118   13  118  118  118
# usoroh      buba  maryland  131  131  131  131  131  131  120  125  131  131
# usoroh  delicate    festac  124  124  124  124  124  124  120  127  124  124
# usoroh      suit    festac  124  124  124  124  124  120   13  127  124  124
# usoroh  delicate    festac  131  131  131  131  131  120  131  127  131  124
# usoroh  delicate     lekki  120  120  120  120  120  110  123  120  120  124
# usoroh      buba  maryland  120  120  120  120  120  118  126  120  131  124
# usoroh  delicate    festac  120  120  120  120  120  110  132  120  131  124
# usoroh      suit    festac  131  131  131  131  120  131  133  131  131  124
# ...

# %%
# using the df.loc[] method to select more than one rows
df_presser_note_2.loc[["alidu", "audu", "usoroh"]]
# Out:
#             mode      shop  jan  feb  mar  apr  may  jun  jul  aug  sep  oct  \
# name
# alidu       suit     lekki   13   13   13   13   13   13   13   13  120  110
# alidu       suit    festac   13   13   13   13   13   13   13   13  131  131
# alidu      shirt     lekki  124  124  124  124  124  124  120  122  124  124
# alidu   delicate     lekki   13   13   13   13   13   13  124  127   13   13
# alidu       suit    festac  124  124  124  124  124  120  120  127  124  124
# alidu      shirt     lekki  124  124  124  124  124  120  129  124  131  124
# alidu      shirt     lekki  120  120  120  120  120  110  123  120  131  124
# alidu   delicate     lekki  124  124  124  124  124  120  129  124  131  124
# audu      native  maryland  120  120  120  120  120  120  120  120  131  120
# audu      native    festac  120  120  120  120  120  120  124  120  118  118
# audu        buba     lekki  120  120  120  120  120  120  118  120  120  120
# ...

# %% [markdown]
# #### 5. Multi-level indexes
# ____

# %% [markdown]
# We can create a multi-level index by passing a list of columns to the `set_index()` method.

# %%
# Reset the index first and reset it again for a multi-level index
# the name and mode is set an as index for the data frame. 

df_presser_muilti_index = df_presser.set_index(["name", "mode"])
df_presser_muilti_index.head(10)
# Out:
#                      shop  jan  feb  mar  apr  may  jun  jul  aug  sep  oct  \
# name   mode
# alidu  suit         lekki   13   13   13   13   13   13   13   13  120  110
# kazeem shirt        lekki  124  124  124  124  124  124  124  124  110  131
# audu   native    maryland  120  120  120  120  120  120  120  120  131  120
# usoroh delicate    festac  110  110  110  110  110  110  110  110  120   77
# dominc buba         lekki  131  131  131  131  131  131  131  131   77  124
# raji   sokoto       lekki  120  120  120  120  120  120  120  120  124  138
# okon   machine   maryland  118  118  118  118  118  118  118  118  118  118
# alidu  suit        festac   13   13   13   13   13   13   13   13  131  131
# kazeem shirt       ogiudu  124  124  124  124  124  124   13  124  120  120
# audu   native      festac  120  120  120  120  120  120  124  120  118  118
#
#                  nov     date
# name   mode
# alidu  suit      131  1/31/19
# kazeem shirt     120   2/1/19
# ...

# %% [markdown]
# #### 6. Subset the outter level of the index
# ___

# %%
# with the setting of index, it is easy to access the data
# compare the two results
df_presser_muilti_index.loc["usoroh"]
# Out:
#               shop  jan  feb  mar  apr  may  jun  jul  aug  sep  oct  nov  \
# mode
# delicate    festac  110  110  110  110  110  110  110  110  120   77   13
# delicate     lekki  124  124  124  124  124  124  120  124  124  124  120
# sokoto       lekki  118  118  118  118  118  118   13  118  118  118  110
# buba      maryland  131  131  131  131  131  131  120  125  131  131  124
# delicate    festac  124  124  124  124  124  124  120  127  124  124  131
# suit        festac  124  124  124  124  124  120   13  127  124  124  131
# delicate    festac  131  131  131  131  131  120  131  127  131  124  131
# delicate     lekki  120  120  120  120  120  110  123  120  120  124  131
# buba      maryland  120  120  120  120  120  118  126  120  131  124  131
# delicate    festac  120  120  120  120  120  110  132  120  131  124  131
# suit        festac  131  131  131  131  120  131  133  131  131  124  131
# delicate    festac  120  120  120  120  118  120  133  120  131  124  131
#
# ...

# %%
# This selection of data from a dataframe with multi-level index.
# comparing the data to the old one, it is seen that the head of the data frame is different

df_presser_muilti_index.loc[["alidu", "audu", "usoroh"]]
# Out:
#                      shop  jan  feb  mar  apr  may  jun  jul  aug  sep  oct  \
# name   mode
# alidu  suit         lekki   13   13   13   13   13   13   13   13  120  110
#        suit        festac   13   13   13   13   13   13   13   13  131  131
#        shirt        lekki  124  124  124  124  124  124  120  122  124  124
#        delicate     lekki   13   13   13   13   13   13  124  127   13   13
#        suit        festac  124  124  124  124  124  120  120  127  124  124
#        shirt        lekki  124  124  124  124  124  120  129  124  131  124
#        shirt        lekki  120  120  120  120  120  110  123  120  131  124
#        delicate     lekki  124  124  124  124  124  120  129  124  131  124
# audu   native    maryland  120  120  120  120  120  120  120  120  131  120
#        native      festac  120  120  120  120  120  120  124  120  118  118
#        buba         lekki  120  120  120  120  120  120  118  120  120  120
# ...

# %%
# selecting the same information but with the outter index this time. 
df_presser_muilti_index.loc[[("alidu", "suit"), ("audu", "native"), ("usoroh", "buba")]]
# Out:
#                    shop  jan  feb  mar  apr  may  jun  jul  aug  sep  oct  \
# name   mode
# alidu  suit       lekki   13   13   13   13   13   13   13   13  120  110
#        suit      festac   13   13   13   13   13   13   13   13  131  131
#        suit      festac  124  124  124  124  124  120  120  127  124  124
# audu   native  maryland  120  120  120  120  120  120  120  120  131  120
#        native    festac  120  120  120  120  120  120  124  120  118  118
#        native  maryland  120  120  120  120  120  120  124  127  120  120
#        native    festac  124  124  124  124  124  120  122  124  124  124
#        native  maryland  124  124  124  124  124  120  131  124  131  124
# usoroh buba    maryland  131  131  131  131  131  131  120  125  131  131
#        buba    maryland  120  120  120  120  120  118  126  120  131  124
#
#                nov     date
# name   mode
# alidu  suit    131  1/31/19
#        suit    120   8/1/19
#        suit    131   3/1/22
# ...

# %%
#### isolating a row together and selecting fom the data frame
rows_to_keep = [("okon","machine"), ("usoroh", "buba"), ("alidu", "suit"), ("audu", "native")]

df_presser_muilti_index.loc[rows_to_keep]
# Out:
#                     shop  jan  feb  mar  apr  may  jun  jul  aug  sep  oct  \
# name   mode
# okon   machine  maryland  118  118  118  118  118  118  118  118  118  118
#        machine     lekki  131  131  131  131  131  120  120  127  131  124
#        machine  maryland   13   13   13   13   13  124  119  127   13  124
#        machine     lekki  120  120  120  120  120  118  133  120  131  124
#        machine  maryland  124  124  124  124  120  120  124  124  131  124
# usoroh buba     maryland  131  131  131  131  131  131  120  125  131  131
#        buba     maryland  120  120  120  120  120  118  126  120  131  124
# alidu  suit        lekki   13   13   13   13   13   13   13   13  120  110
#        suit       festac   13   13   13   13   13   13   13   13  131  131
#        suit       festac  124  124  124  124  124  120  120  127  124  124
# audu   native   maryland  120  120  120  120  120  120  120  120  131  120
# ...

# %% [markdown]
# #### 7. Sorting index with sort_index()
# ____

# %%
# Recalling the data 
df_presser.head()
# Out:
#      name      mode      shop  jan  feb  mar  apr  may  jun  jul  aug  sep  \
# 0   alidu      suit     lekki   13   13   13   13   13   13   13   13  120
# 1  kazeem     shirt     lekki  124  124  124  124  124  124  124  124  110
# 2    audu    native  maryland  120  120  120  120  120  120  120  120  131
# 3  usoroh  delicate    festac  110  110  110  110  110  110  110  110  120
# 4  dominc      buba     lekki  131  131  131  131  131  131  131  131   77
#
#    oct  nov     date
# 0  110  131  1/31/19
# 1  131  120   2/1/19
# 2  120  118   3/1/19
# 3   77   13   4/1/19
# 4  124  124   5/1/19

# %%
# setting the index and contrilling the sothring of the data
df_presser_note_3 = df_presser.set_index("name").sort_index()
df_presser_note_3
# Out:
#             mode    shop  jan  feb  mar  apr  may  jun  jul  aug  sep  oct  \
# name
# alidu       suit   lekki   13   13   13   13   13   13   13   13  120  110
# alidu       suit  festac  124  124  124  124  124  120  120  127  124  124
# alidu      shirt   lekki  124  124  124  124  124  124  120  122  124  124
# alidu      shirt   lekki  124  124  124  124  124  120  129  124  131  124
# alidu      shirt   lekki  120  120  120  120  120  110  123  120  131  124
# ...          ...     ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# usoroh      suit  festac  131  131  131  131  120  131  133  131  131  124
# usoroh  delicate  festac  120  120  120  120  118  120  133  120  131  124
# usoroh  delicate  festac  124  124  124  124  124  124  120  127  124  124
# usoroh  delicate   lekki  124  124  124  124  124  124  120  124  124  124
# usoroh  delicate  festac  131  131  131  131  131  120  131  127  131  124
#
#         nov     date
# name
# alidu   131  1/31/19
# ...

# %% [markdown]
# ## SLICING AND SUBSETTING WITH .LOC & .ILOC
# ____

# %% [markdown]
# #### 1. Slicing the outer index level
# ____

# %%
df_presser
# Out:
#       name      mode      shop  jan  feb  mar  apr  may  jun  jul  aug  sep  \
# 0    alidu      suit     lekki   13   13   13   13   13   13   13   13  120
# 1   kazeem     shirt     lekki  124  124  124  124  124  124  124  124  110
# 2     audu    native  maryland  120  120  120  120  120  120  120  120  131
# 3   usoroh  delicate    festac  110  110  110  110  110  110  110  110  120
# 4   dominc      buba     lekki  131  131  131  131  131  131  131  131   77
# ..     ...       ...       ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 67  usoroh      suit    festac  131  131  131  131  120  131  133  131  131
# 68  usoroh  delicate    festac  120  120  120  120  118  120  133  120  131
# 69  dominc      buba     lekki  118  118  118  118   13  118  133  118  131
# 70    raji    sokoto     lekki   13   13   13   13  124  119   13   13  131
# 71    okon   machine  maryland  124  124  124  124  120  120  124  124  131
#
#     oct  nov     date
# 0   110  131  1/31/19
# ...

# %%
# Settig the date column as a datatype of datetime
df_presser['date'] = pd.to_datetime(df_presser['date'])
# Out:
# /var/folders/v9/v9j8bf6j2r5cr97thvfgxxyh0000gn/T/ipykernel_11308/2745293619.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_presser['date'] = pd.to_datetime(df_presser['date'])

# %% [markdown]
# it is important that we sort the index before we subset the DataFrame with the `df.loc[]` method. This is because the `df.loc[]` method requires that the index be sorted in order to work properly.
#
# In the data frame, the 'name' column is the outter index level, and the 'mode' column is the inner index level.

# %%
# Sorting the data and setting the index
df_presser_note_4 = df_presser.set_index(["name", "mode"]).sort_index()
df_presser_note_4
# Out:
#                    shop  jan  feb  mar  apr  may  jun  jul  aug  sep  oct  \
# name   mode
# alidu  delicate   lekki   13   13   13   13   13   13  124  127   13   13
#        delicate   lekki  124  124  124  124  124  120  129  124  131  124
#        shirt      lekki  124  124  124  124  124  124  120  122  124  124
#        shirt      lekki  124  124  124  124  124  120  129  124  131  124
#        shirt      lekki  120  120  120  120  120  110  123  120  131  124
# ...                 ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# usoroh delicate  festac  120  120  120  120  120  110  132  120  131  124
#        delicate  festac  120  120  120  120  118  120  133  120  131  124
#        sokoto     lekki  118  118  118  118  118  118   13  118  118  118
#        suit      festac  124  124  124  124  124  120   13  127  124  124
#        suit      festac  131  131  131  131  120  131  133  131  131  124
#
#                  nov       date
# name   mode
# ...

# %%
df_presser_note_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 72 entries, ('alidu', 'delicate') to ('usoroh', 'suit')
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   shop    72 non-null     object
#  1   jan     72 non-null     int64
#  2   feb     72 non-null     int64
#  3   mar     72 non-null     int64
#  4   apr     72 non-null     int64
#  5   may     72 non-null     int64
#  6   jun     72 non-null     int64
#  7   jul     72 non-null     int64
#  8   aug     72 non-null     int64
#  9   sep     72 non-null     int64
#  10  oct     72 non-null     int64
#  11  nov     72 non-null     int64
#  12  date    72 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(11), object(1)
# memory usage: 8.3+ KB

# %% [markdown]
# After sorting the index, we can subset the DataFrame using the `df.loc[]` method. The `df.loc[]` method is used to subset the DataFrame based on labels.

# %%
# slicing the outer index, the data is sliced from "alidu" to "okon". The outer index is the 'name' column
# Notice that the final value in the range is included in the selection.. in this case "okon"
df_presser_note_4.loc["alidu": "okon"].head(10)
# Out:
#                   shop  jan  feb  mar  apr  may  jun  jul  aug  sep  oct  nov  \
# name  mode
# alidu delicate   lekki   13   13   13   13   13   13  124  127   13   13  131
#       delicate   lekki  124  124  124  124  124  120  129  124  131  124  131
#       shirt      lekki  124  124  124  124  124  124  120  122  124  124   13
#       shirt      lekki  124  124  124  124  124  120  129  124  131  124  131
#       shirt      lekki  120  120  120  120  120  110  123  120  131  124  131
#       suit       lekki   13   13   13   13   13   13   13   13  120  110  131
#       suit      festac   13   13   13   13   13   13   13   13  131  131  120
#       suit      festac  124  124  124  124  124  120  120  127  124  124  131
# audu  buba       lekki  120  120  120  120  120  120  118  120  120  120  120
#       delicate   lekki  110  110  110  110  110  110  131  124  110  110  120
#
#                      date
# name  mode
# alidu delicate 2021-02-01
#       delicate 2023-12-01
# ...

# %% [markdown]
# #### 2. Slicing the inner index levels
# ____

# %% [markdown]
# To slice the inner index levels, we use the df.loc[] method with the following syntax:
#
# `df.loc[(outer_index, inner_index)]`
#
# The `df.loc[]` method is used to subset the DataFrame based on labels, and the entry is a tuple with the outer and inner index levels.

# %%
df_presser_note_4.loc[
    ("alidu", "suit"): ("okon", "machine")  
    ].head()

# alidu is a outter index and suit is an inner index
# Out:
#                   shop  jan  feb  mar  apr  may  jun  jul  aug  sep  oct  nov  \
# name  mode
# alidu suit       lekki   13   13   13   13   13   13   13   13  120  110  131
#       suit      festac   13   13   13   13   13   13   13   13  131  131  120
#       suit      festac  124  124  124  124  124  120  120  127  124  124  131
# audu  buba       lekki  120  120  120  120  120  120  118  120  120  120  120
#       delicate   lekki  110  110  110  110  110  110  131  124  110  110  120
#
#                      date
# name  mode
# alidu suit     2019-01-31
#       suit     2019-08-01
#       suit     2022-03-01
# audu  buba     2020-03-01
#       delicate 2020-10-01

# %% [markdown]
# #### 3. Slicing columns with .loc[] method
# ____

# %% [markdown]
# To subset a column but keeping all rows with the `df.loc[]` method, we pass a list of column names to the method. The `df.loc[]` method is used to subset the DataFrame based on labels. The entry is a list of column names. The `df.loc[]` method is used to subset the DataFrame based on labels. The syntax is as follows:
#
# `df.loc[:, "column_name1": "column_name2"]`

# %%
df_presser_note_4.loc[:,"jan" : "apr"]
# Out:
#                  jan  feb  mar  apr
# name   mode
# alidu  delicate   13   13   13   13
#        delicate  124  124  124  124
#        shirt     124  124  124  124
#        shirt     124  124  124  124
#        shirt     120  120  120  120
# ...              ...  ...  ...  ...
# usoroh delicate  120  120  120  120
#        delicate  120  120  120  120
#        sokoto    118  118  118  118
#        suit      124  124  124  124
#        suit      131  131  131  131
#
# [72 rows x 4 columns]

# %% [markdown]
# #### 4. Slice both row and column once
# ____

# %% [markdown]
# it is possible to slice both rows and columns with the `df.loc[]` method. The syntax is as follows:
#
# `df.loc[(outer_index1, inner_index1):(outer_index2, inner_index2), "column_name1" : "column_name2"]`

# %%
df_presser_note_4.loc[
    ("alidu", "suit"):("dominc", "buba"), "jan":"oct"]
# Out:
#                  jan  feb  mar  apr  may  jun  jul  aug  sep  oct
# name   mode
# alidu  suit       13   13   13   13   13   13   13   13  120  110
#        suit       13   13   13   13   13   13   13   13  131  131
#        suit      124  124  124  124  124  120  120  127  124  124
# audu   buba      120  120  120  120  120  120  118  120  120  120
#        delicate  110  110  110  110  110  110  131  124  110  110
#        delicate  124  124  124  124  124  120  131  124  131  124
#        delicate  131  131  131  131  131  120  125  131  131  124
#        native    120  120  120  120  120  120  120  120  131  120
#        native    120  120  120  120  120  120  124  120  118  118
#        native    120  120  120  120  120  120  124  127  120  120
#        native    124  124  124  124  124  120  122  124  124  124
#        native    124  124  124  124  124  120  131  124  131  124
#        suit      120  120  120  120  120  120  118  127  120  124
# ...

# %%
df_presser_note_4.loc["alidu":"dominc", "jan":"oct"].head(10)
# Out:
#                 jan  feb  mar  apr  may  jun  jul  aug  sep  oct
# name  mode
# alidu delicate   13   13   13   13   13   13  124  127   13   13
#       delicate  124  124  124  124  124  120  129  124  131  124
#       shirt     124  124  124  124  124  124  120  122  124  124
#       shirt     124  124  124  124  124  120  129  124  131  124
#       shirt     120  120  120  120  120  110  123  120  131  124
#       suit       13   13   13   13   13   13   13   13  120  110
#       suit       13   13   13   13   13   13   13   13  131  131
#       suit      124  124  124  124  124  120  120  127  124  124
# audu  buba      120  120  120  120  120  120  118  120  120  120
#       delicate  110  110  110  110  110  110  131  124  110  110

# %% [markdown]
# The two lines of code you provided use the [`loc`](command:_github.copilot.openSymbolFromReferences?%5B%22loc%22%2C%5B%7B%22uri%22%3A%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2FUsers%2Fteslim%2FLibrary%2FCloudStorage%2FOneDrive-TeslimUthmanAdeyanju%2FTeslim_data_science_study%2Fnote_3_python_language%2FTeslim_python_study_note%2FTeslim_python_DataCamp%2F2-Data_manipulation_with_pandas.ipynb%22%2C%22external%22%3A%22vscode-notebook-cell%3A%2FUsers%2Fteslim%2FLibrary%2FCloudStorage%2FOneDrive-TeslimUthmanAdeyanju%2FTeslim_data_science_study%2Fnote_3_python_language%2FTeslim_python_study_note%2FTeslim_python_DataCamp%2F2-Data_manipulation_with_pandas.ipynb%23Y153sZmlsZQ%253D%253D%22%2C%22path%22%3A%22%2FUsers%2Fteslim%2FLibrary%2FCloudStorage%2FOneDrive-TeslimUthmanAdeyanju%2FTeslim_data_science_study%2Fnote_3_python_language%2FTeslim_python_study_note%2FTeslim_python_DataCamp%2F2-Data_manipulation_with_pandas.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22Y153sZmlsZQ%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A0%2C%22character%22%3A18%7D%7D%5D%5D "Go to definition") accessor in pandas to select data from a DataFrame, but they differ in their selection criteria and implications:
#
# 1. **First Line:**
#    ```python
#    df_presser_note_4.loc[("alidu", "suit"):("dominc", "buba"), "jan":"oct"]
#    ```
#    - **Selection Criteria:** This line uses a tuple for the row index selection, implying that the DataFrame has a MultiIndex (hierarchical index) for its rows.
#    - **Implications:** It selects rows from the MultiIndex starting from the tuple `("alidu", "suit")` to the tuple `("dominc", "buba")` and columns from "jan" to "oct". This is useful when you have a DataFrame with multiple levels of indexing and you want to slice based on those levels.
#
# 2. **Second Line:**
#    ```python
#    df_presser_note_4.loc["alidu":"dominc", "jan":"oct"]
#    ```
#    - **Selection Criteria:** This line uses simple string labels for the row index selection, implying that the DataFrame has a single-level index for its rows.
#    - **Implications:** It selects rows starting from "alidu" to "dominc" and columns from "jan" to "oct". This is a straightforward slicing operation for a DataFrame with a single-level index.
#
# ### Summary of Differences and Implications:
# - **Index Type:** The first line assumes a MultiIndex, while the second line assumes a single-level index.
# - **Selection Range:** The first line selects a range of rows based on tuples in a MultiIndex, whereas the second line selects a range of rows based on single-level index labels.
# - **Use Case:** Use the first line when dealing with hierarchical indexing and the second line for simpler, single-level indexing.
#
# ### Example:
#
# Assume [`df_presser_note_4`](command:_github.copilot.openSymbolFromReferences?%5B%22df_presser_note_4%22%2C%5B%7B%22uri%22%3A%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2FUsers%2Fteslim%2FLibrary%2FCloudStorage%2FOneDrive-TeslimUthmanAdeyanju%2FTeslim_data_science_study%2Fnote_3_python_language%2FTeslim_python_study_note%2FTeslim_python_DataCamp%2F2-Data_manipulation_with_pandas.ipynb%22%2C%22external%22%3A%22vscode-notebook-cell%3A%2FUsers%2Fteslim%2FLibrary%2FCloudStorage%2FOneDrive-TeslimUthmanAdeyanju%2FTeslim_data_science_study%2Fnote_3_python_language%2FTeslim_python_study_note%2FTeslim_python_DataCamp%2F2-Data_manipulation_with_pandas.ipynb%23Y153sZmlsZQ%253D%253D%22%2C%22path%22%3A%22%2FUsers%2Fteslim%2FLibrary%2FCloudStorage%2FOneDrive-TeslimUthmanAdeyanju%2FTeslim_data_science_study%2Fnote_3_python_language%2FTeslim_python_study_note%2FTeslim_python_DataCamp%2F2-Data_manipulation_with_pandas.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22Y153sZmlsZQ%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A0%2C%22character%22%3A0%7D%7D%5D%5D "Go to definition") is a DataFrame with the following structure:
#
# #### MultiIndex Example:

# %%
import pandas as pd
import numpy as np

# Creating a MultiIndex DataFrame
index = pd.MultiIndex.from_tuples([('alidu', 'suit'), ('alidu', 'tie'), ('dominc', 'buba'), ('dominc', 'cap')])
columns = ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct']
data = np.random.randn(4, 10)
df_presser_note = pd.DataFrame(data, index=index, columns=columns)

# Selecting with MultiIndex
df_presser_note.loc[("alidu", "suit"):("dominc", "buba"), "jan":"oct"]
# Out:
#                   jan       feb       mar       apr       may       jun  \
# alidu  suit -0.192969  0.727485 -0.543545  1.126859 -0.466243 -0.292836
#        tie  -1.946069 -0.547319  0.837566 -0.283575  0.045045  0.763617
# dominc buba  1.014750  0.529538  1.167437 -2.062395 -0.153249 -0.073473
#
#                   jul       aug       sep       oct
# alidu  suit -0.256316 -1.698821 -0.156214 -0.071051
#        tie  -0.818619  1.561847 -0.252405  0.393873
# dominc buba -1.414101  0.338766 -1.575614  2.569696

# %% [markdown]
# #### Single-Level Index Example:

# %%
# Creating a single-level index DataFrame
index = ['alidu', 'buba', 'dominc', 'cap']
columns = ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct']
data = np.random.randn(4, 10)
df_presser_note = pd.DataFrame(data, index=index, columns=columns)

# Selecting with single-level index
print(df_presser_note.loc["alidu":"dominc", "jan":"oct"])
# Out:
#              jan       feb       mar       apr       may       jun       jul  \
# alidu  -0.551916 -0.325217  0.347327 -2.319121  0.266918  1.295010  0.769429
# buba   -1.073747 -0.691852 -0.638204 -0.976984  0.163425 -2.580267  0.836020
# dominc -0.526710  0.435458  0.691108  0.616877 -1.380582  0.586997 -0.096486
#
#              aug       sep       oct
# alidu   1.042687 -0.323784  1.724833
# buba    0.147952  1.236771  0.524214
# dominc  0.509474 -0.215013  0.013634

# %% [markdown]
# In summary, the choice between these two lines depends on the structure of your DataFrame's index.

# %% [markdown]
# #### 5. Slincing with date columns
# ____

# %%
# Reseting the index, and making the date the index of the data frame
df_presser_note_4.reset_index()
# Out:
#       name      mode    shop  jan  feb  mar  apr  may  jun  jul  aug  sep  \
# 0    alidu  delicate   lekki   13   13   13   13   13   13  124  127   13
# 1    alidu  delicate   lekki  124  124  124  124  124  120  129  124  131
# 2    alidu     shirt   lekki  124  124  124  124  124  124  120  122  124
# 3    alidu     shirt   lekki  124  124  124  124  124  120  129  124  131
# 4    alidu     shirt   lekki  120  120  120  120  120  110  123  120  131
# ..     ...       ...     ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 67  usoroh  delicate  festac  120  120  120  120  120  110  132  120  131
# 68  usoroh  delicate  festac  120  120  120  120  118  120  133  120  131
# 69  usoroh    sokoto   lekki  118  118  118  118  118  118   13  118  118
# 70  usoroh      suit  festac  124  124  124  124  124  120   13  127  124
# 71  usoroh      suit  festac  131  131  131  131  120  131  133  131  131
#
#     oct  nov       date
# 0    13  131 2021-02-01
# 1   124  131 2023-12-01
# ...

# %%
# make the date the index of the data frame
df_presser_note_5 = df_presser_note_4.set_index("date").sort_index()
df_presser_note_5.head()
# Out:
#                 shop  jan  feb  mar  apr  may  jun  jul  aug  sep  oct  nov
# date
# 2019-01-31     lekki  120  120  120  120  120  124  130  120  131  124  131
# 2019-01-31     lekki   13   13   13   13   13   13   13   13  120  110  131
# 2019-02-01     lekki  124  124  124  124  124  124  124  124  110  131  120
# 2019-02-01  maryland  124  124  124  124  124  120  131  124  131  124  131
# 2019-03-01    festac  120  120  120  120  120  110  132  120  131  124  131

# %%
# slicing with the date 
df_presser_note_5.loc["2019-01-01": "2023-12-31"]
# Out:
#                 shop  jan  feb  mar  apr  may  jun  jul  aug  sep  oct  nov
# date
# 2019-01-31     lekki  120  120  120  120  120  124  130  120  131  124  131
# 2019-01-31     lekki   13   13   13   13   13   13   13   13  120  110  131
# 2019-02-01     lekki  124  124  124  124  124  124  124  124  110  131  120
# 2019-02-01  maryland  124  124  124  124  124  120  131  124  131  124  131
# 2019-03-01    festac  120  120  120  120  120  110  132  120  131  124  131
# ...              ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 2023-08-01     lekki  131  131  131  131  131  120  125  131  131  124  131
# 2023-09-01  maryland  120  120  120  120  120  118  126  120  131  124  131
# 2023-10-01    festac  118  118  118  118  118   13  127  118  131  124  131
# 2023-11-01     lekki   13   13   13   13   13  124  128   13  131  124  131
# 2023-12-01     lekki  124  124  124  124  124  120  129  124  131  124  131
#
# [72 rows x 12 columns]

# %%
# Sllicing by partial dates 
df_presser_note_5.loc["2020": "2023"].head()
# Out:
#                 shop  jan  feb  mar  apr  may  jun  jul  aug  sep  oct  nov
# date
# 2020-01-01  maryland  110  110  110  110  110  110  131  110  110  110   13
# 2020-02-01    festac  131  131  131  131  131  131  120  131  131  131  124
# 2020-03-01     lekki  120  120  120  120  120  120  118  120  120  120  120
# 2020-04-01     lekki  118  118  118  118  118  118   13  118  118  118  110
# 2020-05-01     lekki   13   13   13   13   13   13  124  119   13   13  131

# %%
data_range = df_presser_note_4[(df_presser_note_4["date"] >= "2020-01-01") & (df_presser_note_4["date"] <= "2021-12-31")].sort_values("date")
data_range
# Out:
#                      shop  jan  feb  mar  apr  may  jun  jul  aug  sep  oct  \
# name   mode
# raji   native    maryland  110  110  110  110  110  110  131  110  110  110
# okon   delicate    festac  131  131  131  131  131  131  120  131  131  131
# audu   buba         lekki  120  120  120  120  120  120  118  120  120  120
# usoroh sokoto       lekki  118  118  118  118  118  118   13  118  118  118
# dominc machine      lekki   13   13   13   13   13   13  124  119   13   13
# raji   suit      maryland  124  124  124  124  124  124  120  120  124  124
# okon   suit        festac  120  120  120  120  120  120  124  121  120  120
# alidu  shirt        lekki  124  124  124  124  124  124  120  122  124  124
# kazeem native       lekki  120  120  120  120  120  120  110  123  120  120
# audu   delicate     lekki  110  110  110  110  110  110  131  124  110  110
# usoroh buba      maryland  131  131  131  131  131  131  120  125  131  131
# ...

# %% [markdown]
# #### 6. Subsetting with `.iloc[]` method
# ____

# %% [markdown]
# iloc[] is used to subset the DataFrame based on the index position. The entry is a list of index positions. The syntax is as follows:
#
# `df.iloc[row_position, column_position]`
#
# We can use the range of index positions to subset the DataFrame. The syntax is as follows:
#
# `df.iloc[row_position1:row_position2, column_position1:column_position2]`

# %%
df_presser_note_4.iloc[:10]
# Out:
#                   shop  jan  feb  mar  apr  may  jun  jul  aug  sep  oct  nov  \
# name  mode
# alidu delicate   lekki   13   13   13   13   13   13  124  127   13   13  131
#       delicate   lekki  124  124  124  124  124  120  129  124  131  124  131
#       shirt      lekki  124  124  124  124  124  124  120  122  124  124   13
#       shirt      lekki  124  124  124  124  124  120  129  124  131  124  131
#       shirt      lekki  120  120  120  120  120  110  123  120  131  124  131
#       suit       lekki   13   13   13   13   13   13   13   13  120  110  131
#       suit      festac   13   13   13   13   13   13   13   13  131  131  120
#       suit      festac  124  124  124  124  124  120  120  127  124  124  131
# audu  buba       lekki  120  120  120  120  120  120  118  120  120  120  120
#       delicate   lekki  110  110  110  110  110  110  131  124  110  110  120
#
#                      date
# name  mode
# alidu delicate 2021-02-01
#       delicate 2023-12-01
# ...

# %%
df_presser_note_4.iloc[2:10, 1:4]
# Out:
#                 jan  feb  mar
# name  mode
# alidu shirt     124  124  124
#       shirt     124  124  124
#       shirt     120  120  120
#       suit       13   13   13
#       suit       13   13   13
#       suit      124  124  124
# audu  buba      120  120  120
#       delicate  110  110  110

# %% [markdown]
# ## WORKING WITH PIVOT TABLES
# ____

# %%
df_presser
# Out:
#       name      mode      shop  jan  feb  mar  apr  may  jun  jul  aug  sep  \
# 0    alidu      suit     lekki   13   13   13   13   13   13   13   13  120
# 1   kazeem     shirt     lekki  124  124  124  124  124  124  124  124  110
# 2     audu    native  maryland  120  120  120  120  120  120  120  120  131
# 3   usoroh  delicate    festac  110  110  110  110  110  110  110  110  120
# 4   dominc      buba     lekki  131  131  131  131  131  131  131  131   77
# ..     ...       ...       ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 67  usoroh      suit    festac  131  131  131  131  120  131  133  131  131
# 68  usoroh  delicate    festac  120  120  120  120  118  120  133  120  131
# 69  dominc      buba     lekki  118  118  118  118   13  118  133  118  131
# 70    raji    sokoto     lekki   13   13   13   13  124  119   13   13  131
# 71    okon   machine  maryland  124  124  124  124  120  120  124  124  131
#
#     oct  nov       date
# 0   110  131 2019-01-31
# ...

# %% [markdown]
# #### 1. Creating a pivot table
# ____

# %% [markdown]
# The syntax for a creating a pivot table is as follows:
#
# `df.pivot_table(values='column_name1', index='column_name2', columns='column_name3', aggfunc='function')`
#
# where
# - `values` is the column to aggregate,
# - `index` is the column to group by,
# - `columns` is the column to pivot, and
# - `aggfunc` is the aggregation function to apply.

# %%
# Pivot the data the data frame
presser_pivot_jan = df_presser.pivot_table(values='jan', index='name', columns='mode', fill_value=0)
presser_pivot_jan
# Out:
# mode          buba    delicate     machine      native       shirt  sokoto  \
# name
# alidu     0.000000   68.500000    0.000000    0.000000  122.666667     0.0
# audu    120.000000  121.666667    0.000000  121.600000    0.000000     0.0
# dominc  118.428571    0.000000   85.666667  119.000000    0.000000     0.0
# kazeem  122.000000    0.000000    0.000000  116.666667  122.666667     0.0
# okon      0.000000   87.333333  101.200000    0.000000    0.000000     0.0
# raji      0.000000    0.000000    0.000000  120.500000    0.000000    98.4
# usoroh  125.500000  121.285714    0.000000    0.000000    0.000000   118.0
#
# mode          suit
# name
# alidu    50.000000
# audu    122.000000
# dominc    0.000000
# kazeem    0.000000
# okon     85.666667
# raji    120.666667
# usoroh  127.500000

# %%
presser_pivot_feb = df_presser.pivot_table(values='feb', index='name', columns='mode', fill_value=0)
presser_pivot_feb
# Out:
# mode          buba    delicate     machine      native       shirt  sokoto  \
# name
# alidu     0.000000   68.500000    0.000000    0.000000  122.666667     0.0
# audu    120.000000  121.666667    0.000000  121.600000    0.000000     0.0
# dominc  118.428571    0.000000   85.666667  119.000000    0.000000     0.0
# kazeem  122.000000    0.000000    0.000000  116.666667  122.666667     0.0
# okon      0.000000   87.333333  101.200000    0.000000    0.000000     0.0
# raji      0.000000    0.000000    0.000000  120.500000    0.000000    98.4
# usoroh  125.500000  121.285714    0.000000    0.000000    0.000000   118.0
#
# mode          suit
# name
# alidu    50.000000
# audu    122.000000
# dominc    0.000000
# kazeem    0.000000
# okon     85.666667
# raji    120.666667
# usoroh  127.500000

# %% [markdown]
# #### 2. Slingcing a pivot table with .loc[]
# ____

# %% [markdown]
# Just  like the dataframe, we cab combine the pivot table with the `df.loc[]` method to subset the pivot table. The syntax is as follows:
#
# `df.pivot_table(values='column_name1', index='column_name2', columns='column_name3', aggfunc='function').loc["row_name1":"row_name2", "column_name1":"column_name2"]`

# %%
presser_pivot_feb.loc["alidu":"okon"]
# Out:
# mode          buba    delicate     machine      native       shirt  sokoto  \
# name
# alidu     0.000000   68.500000    0.000000    0.000000  122.666667     0.0
# audu    120.000000  121.666667    0.000000  121.600000    0.000000     0.0
# dominc  118.428571    0.000000   85.666667  119.000000    0.000000     0.0
# kazeem  122.000000    0.000000    0.000000  116.666667  122.666667     0.0
# okon      0.000000   87.333333  101.200000    0.000000    0.000000     0.0
#
# mode          suit
# name
# alidu    50.000000
# audu    122.000000
# dominc    0.000000
# kazeem    0.000000
# okon     85.666667

# %% [markdown]
# ### 3. Axis parameter in pivot_table()
# ____

# %% [markdown]
# We can indicate the axis along which the pivot table should be created by passing the `axis` parameter to the `pivot_table()` method. The `axis` parameter can take the values `0` or `1`, where `0` indicates that the pivot table should be created along the index, and `1` indicates that the pivot table should be created along the columns.

# %%
presser_pivot_feb.sum(axis=1)
# Out:
# name
# alidu     241.166667
# audu      485.266667
# dominc    323.095238
# kazeem    361.333333
# okon      274.200000
# raji      339.566667
# usoroh    492.285714
# dtype: float64

# %%
presser_pivot_feb.sum(axis=0)
# Out:
# mode
# buba        485.928571
# delicate    398.785714
# machine     186.866667
# native      477.766667
# shirt       245.333333
# sokoto      216.400000
# suit        505.833333
# dtype: float64

# %%
presser_pivot_feb.mean(axis=1)
# Out:
# name
# alidu     34.452381
# audu      69.323810
# dominc    46.156463
# kazeem    51.619048
# okon      39.171429
# raji      48.509524
# usoroh    70.326531
# dtype: float64

# %%
import pandas as pd

# Sample data
data = {
    'date': ['2021-01-01', '2022-02-15', '2023-03-20']
}

# Create DataFrame
temperatures = pd.DataFrame(data)

# Convert 'date' column to datetime
temperatures['date'] = pd.to_datetime(temperatures['date'])

# Extract year
years = temperatures['date'].dt.year

print(data)

print(years)
# Out:
# {'date': ['2021-01-01', '2022-02-15', '2023-03-20']}
# 0    2021
# 1    2022
# 2    2023
# Name: date, dtype: int32

# %% [markdown]
# # CHAPTER 4: Visualizing your data
# ____

# %%
import matplotlib.pyplot as plt

# %%
df_eco_clean_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df_eco_clean_data
#
# NameError: name 'df_eco_clean_data' is not defined

# %%
df_eco_2022 = df_eco_clean_data.pivot_table(values=2022, index="COUNTRY", columns="INDICATOR")
df_eco_2022
# Out:
# INDICATOR  Average Hours Worked  Employment  Nominal GDP  \
# COUNTRY
# Albania                     NaN      1137.0      49486.0
# Algeria                     NaN     11252.6     579518.5
# Angola                      NaN     13360.3     240022.5
# Argentina                1641.0     21364.0    1177214.0
# Australia                1598.0     13287.0    1582271.0
# ...                         ...         ...          ...
# Venezuela                1889.0     13314.0     150392.0
# Vietnam                     NaN     52927.0    1279108.0
# Yemen                       NaN      6178.0      88738.0
# Zambia                      NaN      5720.0      73666.0
# Zimbabwe                    NaN      7250.0      50803.0
#
# INDICATOR  Output per Employed Person  Output per Hour Worked  \
# COUNTRY
# Albania                       41249.0                     NaN
# Algeria                       48813.6                     NaN
# Angola                        17027.9                     NaN
# ...

# %%
df_eco_2022.columns
# Out:
# Index(['Average Hours Worked', 'Employment', 'Nominal GDP',
#        'Output per Employed Person', 'Output per Hour Worked',
#        'Per Capita Income', 'Population', 'Real GDP', 'Total Hours'],
#       dtype='object', name='INDICATOR')

# %%
df_eco_2022.columns = df_eco_2022.columns.str.lower().str.replace(' ', '_')
df_eco_2022
# Out:
# INDICATOR  average_hours_worked  employment  nominal_gdp  \
# COUNTRY
# Albania                     NaN      1137.0      49486.0
# Algeria                     NaN     11252.6     579518.5
# Angola                      NaN     13360.3     240022.5
# Argentina                1641.0     21364.0    1177214.0
# Australia                1598.0     13287.0    1582271.0
# ...                         ...         ...          ...
# Venezuela                1889.0     13314.0     150392.0
# Vietnam                     NaN     52927.0    1279108.0
# Yemen                       NaN      6178.0      88738.0
# Zambia                      NaN      5720.0      73666.0
# Zimbabwe                    NaN      7250.0      50803.0
#
# INDICATOR  output_per_employed_person  output_per_hour_worked  \
# COUNTRY
# Albania                       41249.0                     NaN
# Algeria                       48813.6                     NaN
# Angola                        17027.9                     NaN
# ...

# %%
df_eco_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 111 entries, Albania to Zimbabwe
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   average_hours_worked        33 non-null     float64
#  1   employment                  111 non-null    float64
#  2   nominal_gdp                 111 non-null    float64
#  3   output_per_employed_person  111 non-null    float64
#  4   output_per_hour_worked      33 non-null     float64
#  5   per_capita_income           111 non-null    float64
#  6   population                  111 non-null    float64
#  7   real_gdp                    111 non-null    float64
#  8   total_hours                 33 non-null     float64
# dtypes: float64(9)
# memory usage: 8.7+ KB

# %% [markdown]
# ### Histogram

# %% [markdown]
# #### 1. Using [`plt.hist`] method:
# ____

# %% [markdown]
# This is the most straightforward way to plot a histogram using Matplotlib.
#
# The syntax for creating a histogram using Matplotlib is as follows:
#
# ``` python
#
# plt.hist(data, bins=number_of_bins, color='color', alpha=transparency)
# plt.xlabel('x-axis label')
# plt.ylabel('y-axis label')
# plt.title('Title')
# plt.show()
# ```

# %%
import matplotlib.pyplot as plt

# Basic histogram
plt.hist(df_eco_2022['output_per_employed_person'], bins=10, color='blue', edgecolor='black', alpha=0.7)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram using plt.hist')
plt.show()

# %% [markdown]
# #### 2. Using `ax.hist` with Object-Oriented API
# ____

# %% [markdown]
# This method provides more control over the plot, especially when creating subplots.
# The syntax for creating a histogram using the Object-Oriented API is as follows:
#
# ``` python
#
# fig, ax = plt.subplots()
# ax.hist(data, bins=number_of_bins, color='color', alpha=transparency, edgecolor='color')
# ax.set_xlabel('x-axis label')
# ax.set_ylabel('y-axis label')
# ax.set_title('Title')
# plt.show()
# ```

# %%
fig, ax = plt.subplots()
ax.hist(df_eco_2022['output_per_employed_person'], bins=10, color='blue', edgecolor='yellow', alpha=0.7)
ax.set_xlabel('Value')
ax.set_ylabel('Frequency')
ax.set_title('Histogram using ax.hist')
plt.show()

# %% [markdown]
# #### 3. Using `pandas.DataFrame.plot.hist` method
# ____

# %% [markdown]
# If you are working with a pandas DataFrame, you can use the built-in plotting method.
#
# The syntax for pandas built-in histogram plot is as follows:
#
# ``` python
#
# df['column_name'].plot.hist(bins=number_of_bins, color='color', alpha=transparency)
# plt.xlabel('x-axis label')
# plt.ylabel('y-axis label')
# plt.title('Title')
# plt.show()
# ```

# %%
df_eco_2022['output_per_employed_person'].plot.hist(bins=20, alpha=0.5)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram using pandas DataFrame.plot.hist')
plt.show()

# %% [markdown]
# #### 4. Using `seaborn.histplot`
# ____

# %% [markdown]
# Seaborn is built on top of Matplotlib and provides a high-level interface for drawing attractive statistical graphics.
#
# The syntax for creating a histogram using Seaborn is as follows:
#
# ``` python
#
# sns.histplot(data=df, x='column_name', bins=number_of_bins, color='color', alpha=transparency)
# plt.xlabel('x-axis label')
# plt.ylabel('y-axis label')
# plt.title('Title')
# plt.show()
# ```

# %%
import seaborn as sns

sns.histplot(df_eco_2022['output_per_employed_person'], bins=10, kde=True)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram using seaborn.histplot')
plt.show()

# %% [markdown]
# #### 5. Using `numpy.histogram` and [`plt.bar`]
# ____

# %% [markdown]
# You can manually compute the histogram and then plot it using [`plt.bar`]

# %%
import numpy as np

data = df_eco_2022['real_gdp']
hist, bins = np.histogram(data, bins=10)
width = 0.7 * (bins[1] - bins[0])
center = (bins[:-1] + bins[1:]) / 2

plt.bar(center, hist, align='center', width=width)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram using numpy.histogram and plt.bar')
plt.show()

# %% [markdown]
# #### Summary
# - **[`plt.hist`](command:_github.copilot.openSymbolFromReferences?%5B%22plt.hist%22%2C%5B%7B%22uri%22%3A%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2FUsers%2Fteslim%2FLibrary%2FCloudStorage%2FOneDrive-TeslimUthmanAdeyanju%2FTeslim_data_science_study%2Fnote_3_python_language%2FTeslim_python_study_note%2FTeslim_python_DataCamp%2F2-Data_manipulation_with_pandas.ipynb%22%2C%22external%22%3A%22vscode-notebook-cell%3A%2FUsers%2Fteslim%2FLibrary%2FCloudStorage%2FOneDrive-TeslimUthmanAdeyanju%2FTeslim_data_science_study%2Fnote_3_python_language%2FTeslim_python_study_note%2FTeslim_python_DataCamp%2F2-Data_manipulation_with_pandas.ipynb%23Y242sZmlsZQ%253D%253D%22%2C%22path%22%3A%22%2FUsers%2Fteslim%2FLibrary%2FCloudStorage%2FOneDrive-TeslimUthmanAdeyanju%2FTeslim_data_science_study%2Fnote_3_python_language%2FTeslim_python_study_note%2FTeslim_python_DataCamp%2F2-Data_manipulation_with_pandas.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22Y242sZmlsZQ%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A0%2C%22character%22%3A0%7D%7D%5D%5D "Go to definition")**: Simple and direct.
# - **`ax.hist`**: Object-oriented approach for more control.
# - **`pandas.DataFrame.plot.hist`**: Convenient for DataFrame objects.
# - **`seaborn.histplot`**: High-level interface with additional features like KDE.
# - **`numpy.histogram` and [`plt.bar`](command:_github.copilot.openSymbolFromReferences?%5B%22plt.bar%22%2C%5B%7B%22uri%22%3A%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2FUsers%2Fteslim%2FLibrary%2FCloudStorage%2FOneDrive-TeslimUthmanAdeyanju%2FTeslim_data_science_study%2Fnote_3_python_language%2FTeslim_python_study_note%2FTeslim_python_DataCamp%2F2-Data_manipulation_with_pandas.ipynb%22%2C%22external%22%3A%22vscode-notebook-cell%3A%2FUsers%2Fteslim%2FLibrary%2FCloudStorage%2FOneDrive-TeslimUthmanAdeyanju%2FTeslim_data_science_study%2Fnote_3_python_language%2FTeslim_python_study_note%2FTeslim_python_DataCamp%2F2-Data_manipulation_with_pandas.ipynb%23Y242sZmlsZQ%253D%253D%22%2C%22path%22%3A%22%2FUsers%2Fteslim%2FLibrary%2FCloudStorage%2FOneDrive-TeslimUthmanAdeyanju%2FTeslim_data_science_study%2Fnote_3_python_language%2FTeslim_python_study_note%2FTeslim_python_DataCamp%2F2-Data_manipulation_with_pandas.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22Y242sZmlsZQ%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A0%2C%22character%22%3A0%7D%7D%5D%5D "Go to definition")**: Full control over histogram computation and plotting.
#
# Choose the method that best fits your needs and the level of control you require over the plot.

# %% [markdown]
# _____

# %%
# create a histogram with 20 bins
df_eco_2022['output_per_employed_person'].hist()
plt.show()

# %%
# The bin size can be adjusted to 50
df_eco_2022['output_per_employed_person'].hist(bins=30)
plt.show()

# %%
df_eco_2022.hist(bins=30, figsize=(20, 10))
# Out:
# array([[<Axes: title={'center': 'average_hours_worked'}>,
#         <Axes: title={'center': 'employment'}>,
#         <Axes: title={'center': 'nominal_gdp'}>],
#        [<Axes: title={'center': 'output_per_employed_person'}>,
#         <Axes: title={'center': 'output_per_hour_worked'}>,
#         <Axes: title={'center': 'per_capita_income'}>],
#        [<Axes: title={'center': 'population'}>,
#         <Axes: title={'center': 'real_gdp'}>,
#         <Axes: title={'center': 'total_hours'}>]], dtype=object)

# %% [markdown]
# ### Bar plot

# %%
df_eco_clean_data_index_reset =df_eco_clean_data.reset_index()
df_eco_clean_data_index_reset
# Out:
#           continent  ISO         COUNTRY                   INDICATOR     1950  \
# 0            Africa  DZA         Algeria                    Real GDP  40781.7
# 1            Africa  DZA         Algeria                 Nominal GDP   4508.7
# 2            Africa  DZA         Algeria                  Employment   1744.0
# 3            Africa  DZA         Algeria                  Population   8892.7
# 4            Africa  DZA         Algeria  Output per Employed Person  23384.0
# ..              ...  ...             ...                         ...      ...
# 760  Western Europe  GBR  United Kingdom                 Total Hours  46912.0
# 761  Western Europe  GBR  United Kingdom                  Population  50127.0
# 762  Western Europe  GBR  United Kingdom  Output per Employed Person  27304.0
# 763  Western Europe  GBR  United Kingdom      Output per Hour Worked     14.0
# 764  Western Europe  GBR  United Kingdom           Per Capita Income  12662.0
#
# ...

# %% [markdown]
# bar plot is used to compare the values of a variable at a given point in time or across different categories. It is a common plot type used in data visualization to show the relationship between a categorical variable and a numerical variable.
#
# For a good insight to the data above, let me us group the data by continent and sum the population of each continent.

# %%
df_eco_clean_data_pivot = df_eco_clean_data_index_reset.pivot_table(values=2022, columns="INDICATOR", index="continent", fill_value=0)
df_eco_clean_data_pivot
# Out:
# INDICATOR                                    Average Hours Worked  \
# continent
# Africa                                                   0.000000
# Asia                                                  2130.333333
# Central and Eastern Europe and Central Asia              0.000000
# Latin America                                         1894.142857
# Middle East                                              0.000000
# North America                                         1756.000000
# Oceania                                               1598.000000
# Western Europe                                        1558.937500
#
# INDICATOR                                       Employment   Nominal GDP  \
# continent
# Africa                                        13648.351515  2.416504e+05
# Asia                                         107090.352941  3.757723e+06
# Central and Eastern Europe and Central Asia   19166.000000  1.529597e+06
# ...

# %%
df_eco_clean_data_pivot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, Africa to Western Europe
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Average Hours Worked        8 non-null      float64
#  1   Employment                  8 non-null      float64
#  2   Nominal GDP                 8 non-null      float64
#  3   Output per Employed Person  8 non-null      float64
#  4   Output per Hour Worked      8 non-null      float64
#  5   Per Capita Income           8 non-null      float64
#  6   Population                  8 non-null      float64
#  7   Real GDP                    8 non-null      float64
#  8   Total Hours                 8 non-null      float64
# dtypes: float64(9)
# memory usage: 940.0+ bytes

# %%
df_eco_clean_data_pivot[["Employment", "Population"]].plot(kind='bar', title="Continent data: Employement vs Population")
# Out:
# <Axes: title={'center': 'Continent data: Employement vs Population'}, xlabel='continent'>

# %%
df_eco_clean_data_pivot["Real GDP"].plot(kind='bar', title="Continent data: Real GDP", rot=90)
# Out:
# <Axes: title={'center': 'Continent data: Real GDP'}, xlabel='continent'>

# %% [markdown]
# ### Line plot

# %% [markdown]
# Line plot is used to visualize data points in a series and their trend over time. It is a common plot type used in data visualization to show the relationship between two or more variables.

# %%
collect_data_to_plot = ["Population", "Employment"]
data_plot = df_eco_clean_data_pivot[collect_data_to_plot]
data_plot
# Out:
# INDICATOR                                       Population     Employment
# continent
# Africa                                        39511.096970   13648.351515
# Asia                                         239875.705882  107090.352941
# Central and Eastern Europe and Central Asia   44238.000000   19166.000000
# Latin America                                 37156.437500   16870.000000
# Middle East                                   19962.538462    6367.000000
# North America                                235702.666667  113547.333333
# Oceania                                       15756.000000    8035.500000
# Western Europe                                21477.100000   10261.800000

# %%
data_plot.plot(x="Population", y="Employment", kind='line')
# Out:
# <Axes: xlabel='Population'>

# %% [markdown]
# ### Scatter Plot

# %%
data_scatter = data_plot.plot(x="Population", y="Employment", kind='scatter')

# %% [markdown]
# #### plot on each other

# %%
df_eco_clean_data_index_reset.head()
# Out:
#   continent  ISO  COUNTRY                   INDICATOR     1950     1951  \
# 0    Africa  DZA  Algeria                    Real GDP  40781.7  41067.2
# 1    Africa  DZA  Algeria                 Nominal GDP   4508.7   4862.1
# 2    Africa  DZA  Algeria                  Employment   1744.0   1758.3
# 3    Africa  DZA  Algeria                  Population   8892.7   9073.3
# 4    Africa  DZA  Algeria  Output per Employed Person  23384.0  23355.8
#
#       1952     1953     1954     1955  ...      2013      2014      2015  \
# 0  42902.4  43840.4  46409.6  47796.2  ...  473808.3  491813.0  510010.1
# 1   5167.2   5344.1   5709.6   5979.6  ...  407286.1  430668.2  451071.3
# 2   1776.7   1802.9   1795.5   1815.8  ...   10788.0   10239.0   10594.0
# 3   9279.5   9531.7   9611.1   9841.9  ...   37930.4   38650.3   39372.2
# 4  24146.8  24317.1  25847.2  26322.7  ...   43919.9   48033.3   48141.4
#
#        2016      2017      2018      2019      2020      2021      2022
# ...

# %%
d = df_eco_clean_data_index_reset[df_eco_clean_data_index_reset["continent"]=="Algeria"][1954]
d
# Out:
# Series([], Name: 1954, dtype: float64)

# %% [markdown]
# ### Missing Values
# ____

# %% [markdown]
# - It is often a pratice that the data we have have some missing values, and first, we need to check our data if it contains any missing values. In the pdandas dataframe, missing values are represented by `NaN` or `None`.
#
# - if we get our dataset, first use the df.isna().sum() to check for missing values in the dataset. This only returns True or False, and to get the sum of the missing values in each column, we can use the df.isna().sum() method.
#
# - Note that the `df.isna()` method returns a DataFrame of the same shape as the original DataFrame, where each entry is a boolean value indicating whether the corresponding entry in the original DataFrame is missing or not. The `sum()` method is then used to count the number of missing values in each column.
#
# -Note that df.isnull() is an alias for df.isna(), and both methods can be used interchangeably as df.isnull().sum() or df.isna().sum().

# %%
import pandas as pd
file_path = r'/Users/teslim/OneDrive/3_adult_ws_1.csv'

data = pd.read_csv(file_path)
data.head()
# Out:
#    age workclass  fnlwgt     education  education-num      marital-status  \
# 0   29   Private  216481       Masters             14  Married-civ-spouse
# 1   36   Private  280570  Some-college             10  Married-civ-spouse
# 2   25         ?  100903     Bachelors             13  Married-civ-spouse
# 3   47   Private  145636     Assoc-voc             11  Married-civ-spouse
# 4   33   Private  119422       HS-grad              9  Married-civ-spouse
#
#           occupation relationship   race     sex  capital-gain  capital-loss  \
# 0    Exec-managerial         Wife  White  Female             0             0
# 1       Craft-repair      Husband  White    Male             0             0
# 2                  ?         Wife  White  Female             0             0
# 3  Handlers-cleaners      Husband  White    Male             0             0
# 4    Exec-managerial      Husband  White    Male             0             0
#
#    hours-per-week native-country income
# ...

# %%
# data information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9765 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             9765 non-null   int64
#  1   workclass       9765 non-null   object
#  2   fnlwgt          9765 non-null   int64
#  3   education       9765 non-null   object
#  4   education-num   9765 non-null   int64
#  5   marital-status  9765 non-null   object
#  6   occupation      9765 non-null   object
#  7   relationship    9765 non-null   object
#  8   race            9765 non-null   object
#  9   sex             9765 non-null   object
#  10  capital-gain    9765 non-null   int64
#  11  capital-loss    9765 non-null   int64
#  12  hours-per-week  9765 non-null   int64
#  13  native-country  9765 non-null   object
#  14  income          9765 non-null   object
# dtypes: int64(6), object(9)
# memory usage: 1.2+ MB

# %%
# Detecting missing values
data.isna()
# Out:
#         age  workclass  fnlwgt  education  education-num  marital-status  \
# 0     False      False   False      False          False           False
# 1     False      False   False      False          False           False
# 2     False      False   False      False          False           False
# 3     False      False   False      False          False           False
# 4     False      False   False      False          False           False
# ...     ...        ...     ...        ...            ...             ...
# 9995  False      False   False      False          False           False
# 9996  False      False   False      False          False           False
# 9997  False      False   False      False          False           False
# 9998  False      False   False      False          False           False
# 9999  False      False   False      False          False           False
#
#       occupation  relationship   race    sex  capital-gain  capital-loss  \
# ...

# %%
# We can also check if the dataframe comntains any missing values
data.isna().any()
# Out:
# age               False
# workclass          True
# fnlwgt            False
# education         False
# education-num     False
# marital-status    False
# occupation         True
# relationship      False
# race              False
# sex               False
# capital-gain      False
# capital-loss      False
# hours-per-week    False
# native-country     True
# income            False
# dtype: bool

# %%
# counting missing values 
data.isna().sum()
# Out:
# age                 0
# workclass         175
# fnlwgt              0
# education           0
# education-num       0
# marital-status      0
# occupation        175
# relationship        0
# race                0
# sex                 0
# capital-gain        0
# capital-loss        0
# hours-per-week      0
# native-country     61
# income              0
# dtype: int64

# %%
# We can use plot to visualize the missing values
data.isna().sum().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# After the detection of missing values, we can either drop the missing values or fill them with a specific value.
#
# - droping missing values: we can use the `df.dropna()` method to drop missing values from the DataFrame. The `df.dropna()` method removes rows with missing values from the DataFrame. The syntax is as follows:
#
# `df.dropna()`
#
# - filling missing values: we can use the `df.fillna()` method to fill missing values in the DataFrame. The `df.fillna()` method fills missing values in the DataFrame with a specified value. The syntax is as follows:
#
# `df.fillna(value)`

# %%
# this will drop all the rows with missing values
data = data.dropna()

# %%
data.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %% [markdown]
# ______

# %%
# Data importation 
file = r'/Users/teslim/OneDrive/12_console_dca.xlsx'
dca_data = pd.read_excel(file)
dca_data.head()
# Out:
#    systemloanId         DCA 2 Assignment_Date Assignment_Type  \
# 0  305401649499           NaN    Jul 13, 2020           61-90
# 1  305919711003  Stephen Udoh     Oct 7, 2020          91-120
# 2  305380284878           NaN     Jul 6, 2020          91-120
# 3  305380284878           NaN     Jul 6, 2020          91-120
# 4  305996407259           NaN     Oct 7, 2020          91-120
#
#    Amount_Delinquent  Repayment_Amount   mobilePhone1  \
# 0                NaN           38000.0  2348023133719
# 1           14983.33            2300.0  2348186023049
# 2                NaN           10500.0  2348062507954
# 3                NaN            7000.0  2348062507954
# 4           30693.40            3000.0  2348050295205
#
#                    emailAddress     BankName  loanAmount   Value_Date  \
# 0     ajibolaibrahim2@gmail.com   First Bank   153333.34  Aug 1, 2021
# 1         peresinde68@gmail.com      GT Bank    23000.00  Aug 1, 2021
# ...

# %%
# check the boolean values of the data frame
dca_data.isna().any()
# Out:
# systemloanId          False
# DCA 2                  True
# Assignment_Date       False
# Assignment_Type       False
# Amount_Delinquent      True
# Repayment_Amount      False
# mobilePhone1          False
# emailAddress          False
# BankName               True
# loanAmount            False
# Value_Date            False
# Posting_Date          False
# transactionId         False
# BalanceOutstanding    False
# dtype: bool

# %%
# check for missing values
dca_data.isna().sum()
# Out:
# systemloanId            0
# DCA 2                 205
# Assignment_Date         0
# Assignment_Type         0
# Amount_Delinquent     298
# Repayment_Amount        0
# mobilePhone1            0
# emailAddress            0
# BankName                1
# loanAmount              0
# Value_Date              0
# Posting_Date            0
# transactionId           0
# BalanceOutstanding      0
# dtype: int64

# %%
# plot the missing values
dca_data.isna().sum().plot(kind='bar')
# Out:
# <Axes: >

# %%
# filling the mssing values with the mean of the column
dca_missing_data_remove = dca_data.fillna(0)
dca_missing_data_remove
# Out:
#      systemloanId             DCA 2 Assignment_Date Assignment_Type  \
# 0    305401649499                 0    Jul 13, 2020           61-90
# 1    305919711003      Stephen Udoh     Oct 7, 2020          91-120
# 2    305380284878                 0     Jul 6, 2020          91-120
# 3    305380284878                 0     Jul 6, 2020          91-120
# 4    305996407259                 0     Oct 7, 2020          91-120
# ..            ...               ...             ...             ...
# 445  306757417283                 0    Jan 12, 2021          91-120
# 446  306636404787  Olalekan Olaokun    Jan 12, 2021          91-120
# 447  305645708159  Olalekan Olaokun     Jul 6, 2020          91-120
# 448  305785433039      Ridwan Akeeb     Oct 7, 2020          91-120
# 449  305710458073                 0     Oct 7, 2020          91-120
#
#      Amount_Delinquent  Repayment_Amount   mobilePhone1  \
# 0                 0.00          38000.00  2348023133719
# ...

# %%
# check for missing values after the filling
dca_missing_data_remove.isnull().sum()
# Out:
# systemloanId          0
# DCA 2                 0
# Assignment_Date       0
# Assignment_Type       0
# Amount_Delinquent     0
# Repayment_Amount      0
# mobilePhone1          0
# emailAddress          0
# BankName              0
# loanAmount            0
# Value_Date            0
# Posting_Date          0
# transactionId         0
# BalanceOutstanding    0
# dtype: int64

# %% [markdown]
# ### Creating DataFrames
# ____

# %% [markdown]
# Dictionary is a collection of key-value pairs. It is a data structure that is used to store data in Python. A dictionary is created using curly braces `{}` and key-value pairs separated by a colon `:`. The keys in a dictionary must be unique, and they are used to access the corresponding values. The syntax for creating a dictionary is as follows:
#
# `dictionary = {'key1': value1, 'key2': value2, 'key3': value3}`

# %%
# creating Dictonary 
my_dict = {     "title": "Charlotte's Web",     "author": "E.B. White",     "published": 1952 } 
my_dict
# Out:
# {'title': "Charlotte's Web", 'author': 'E.B. White', 'published': 1952}

# %%
# accessing the key of the dictionary
my_dict["title"]
# Out:
# "Charlotte's Web"

# %% [markdown]
# There are ways to create a dataframe from strach. Two of the method will be dicussed, which are
# - From a list of dictonary
# - From a ditionary of list
#
# From the list of dictionary, the dataframe is built by construction of row by row, and on the method of costruction from the dictionary of list, it is built by column by column.

# %% [markdown]
# #### From a list of dictionary
# ____

# %% [markdown]
# <img src="dataframe_practice_01.png" style="width:880px; height:124px" title="dataframe to create">

# %%
list_of_dog = [     
                 {"name": "Ginger", "breed": "Dachshund", "height_cm": 22, "weight_kg": 10, "date_of_birth": "2019-03-14"},       
                 {"name": "Scout", "breed": "Dalmatian", "height_cm": 59,      "weight_kg": 25, "date_of_birth": "2019-05-09"}   
    ] 

# creating a data frame from the list of dictionaries with the us of pd.DataFrame
dog = pd.DataFrame(list_of_dog)
print(dog)
# Out:
#      name      breed  height_cm  weight_kg date_of_birth
# 0  Ginger  Dachshund         22         10    2019-03-14
# 1   Scout  Dalmatian         59         25    2019-05-09

# %%
list_of_book = [     
                {"title": "Charlotte's Web", "author": "E.B. White", "published": 1952},     
                {"title": "Charlie and the Chocolate Factory", "author": "Roald Dahl", "published": 1964},     
                {"title": "James and the Giant Peach", "author": "Roald Dahl", "published": 1961} 
                ]

book = pd.DataFrame(list_of_book)
book
# Out:
#                                title      author  published
# 0                    Charlotte's Web  E.B. White       1952
# 1  Charlie and the Chocolate Factory  Roald Dahl       1964
# 2          James and the Giant Peach  Roald Dahl       1961

# %% [markdown]
# #### From a dictionary of list
# ____

# %%
dict_of_lists = {      
                 "name": ["Ginger", "Scout"],      
                 "breed": ["Dachshund", "Dalmatian"],     
                 "height_cm": [22, 59],      
                 "weight_kg": [10, 25],     
                 "date_of_birth": ["2019-03-14",      "2019-05-09"]   
    }  

new_dogs = pd.DataFrame(dict_of_lists) 
new_dogs
# Out:
#      name      breed  height_cm  weight_kg date_of_birth
# 0  Ginger  Dachshund         22         10    2019-03-14
# 1   Scout  Dalmatian         59         25    2019-05-09

# %% [markdown]
# #### Dataframe to CSV
# ____

# %% [markdown]
# it is important to be able to save our dataframe to a CSV file. We can use the `df.to_csv()` method to save the DataFrame to a CSV file. The `df.to_csv()` method saves the DataFrame to a CSV file. The syntax is as follows:
#
# `df.to_csv('file_name.csv', index=False, path='path')`
#
# where
# - `file_name.csv` is the name of the CSV file to save the DataFrame to,
# - `index=False` specifies that the index should not be saved to the CSV file, and
# - `path` is the path to the directory where the CSV file should be saved.

# %%
new_dogs.to_csv("new_dogs.csv", index=False)
