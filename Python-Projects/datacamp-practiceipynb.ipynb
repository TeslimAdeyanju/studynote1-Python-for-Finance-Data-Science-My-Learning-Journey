# %%
import pandas as pd

df = pd.read_csv('word_population_data.csv')
df.dropna(inplace=True)

# %%
df
# Out:
#      Rank CCA3  Country/Territory           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country/Territory            234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              234 non-null    int64
#  6   2020 Population              234 non-null    int64
#  7   2015 Population              234 non-null    int64
#  8   2010 Population              234 non-null    int64
#  9   2000 Population              234 non-null    int64
#  10  1990 Population              234 non-null    int64
#  11  1980 Population              234 non-null    int64
#  12  1970 Population              234 non-null    int64
# ...

# %%
# clean the column_headers

def clean_columns_header(df):
    df.columns = df.columns.str.lower()
    df.columns = df.columns.str.strip()
    df.columns = df.columns.str.replace(" ", "_")
    return df

# %%
clean_columns_header(df)
# Out:
#      rank cca3  country/territory           capital continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022_population  2020_population  2015_population  2010_population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
df.columns.to_list()
# Out:
# ['rank',
#  'cca3',
#  'country/territory',
#  'capital',
#  'continent',
#  '2022_population',
#  '2020_population',
#  '2015_population',
#  '2010_population',
#  '2000_population',
#  '1990_population',
#  '1980_population',
#  '1970_population',
#  'area_(km²)',
#  'density_(per_km²)',
#  'growth_rate',
#  'world_population_percentage']

# %%
numerical_data = df.select_dtypes(exclude='object').columns
categorical_data = df.select_dtypes(include='object').columns

# %%
numerical_data.to_list()
# Out:
# ['rank',
#  '2022_population',
#  '2020_population',
#  '2015_population',
#  '2010_population',
#  '2000_population',
#  '1990_population',
#  '1980_population',
#  '1970_population',
#  'area_(km²)',
#  'density_(per_km²)',
#  'growth_rate',
#  'world_population_percentage']

# %%
categorical_data.to_list()
# Out:
# ['cca3', 'country/territory', 'capital', 'continent']

# %%
## clean the content of the column

def clean_content_column(df,columns_name):
    df[columns_name] =  df[columns_name].astype(str)
    df[columns_name] =  df[columns_name].str.lower()
    df[columns_name] =  df[columns_name].str.strip()
    df[columns_name] =  df[columns_name].str.replace(" ", "")
    return df

# %%
for columns_name in categorical_data:
    clean_data = clean_content_column(df,columns_name)

# %%
for columns in numerical_data:
    df[columns] = df[columns].astype(float)

# %%
df
# Out:
#       rank cca3 country/territory         capital continent  2022_population  \
# 0     36.0  afg       afghanistan           kabul      asia       41128771.0
# 1    138.0  alb           albania          tirana    europe        2842321.0
# 2     34.0  dza           algeria         algiers    africa       44903225.0
# 3    213.0  asm     americansamoa        pagopago   oceania          44273.0
# 4    203.0  and           andorra  andorralavella    europe          79824.0
# ..     ...  ...               ...             ...       ...              ...
# 229  226.0  wlf   wallisandfutuna        mata-utu   oceania          11572.0
# 230  172.0  esh     westernsahara         elaaiún    africa         575986.0
# 231   46.0  yem             yemen           sanaa      asia       33696614.0
# 232   63.0  zmb            zambia          lusaka    africa       20017675.0
# 233   74.0  zwe          zimbabwe          harare    africa       16320537.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   rank                         234 non-null    float64
#  1   cca3                         234 non-null    object
#  2   country/territory            234 non-null    object
#  3   capital                      234 non-null    object
#  4   continent                    234 non-null    object
#  5   2022_population              234 non-null    float64
#  6   2020_population              234 non-null    float64
#  7   2015_population              234 non-null    float64
#  8   2010_population              234 non-null    float64
#  9   2000_population              234 non-null    float64
#  10  1990_population              234 non-null    float64
#  11  1980_population              234 non-null    float64
# ...

# %%
df = df.rename(columns={'cca3': 'country_code'})

# %%
df
# Out:
#       rank country_code country/territory         capital continent  \
# 0     36.0          afg       afghanistan           kabul      asia
# 1    138.0          alb           albania          tirana    europe
# 2     34.0          dza           algeria         algiers    africa
# 3    213.0          asm     americansamoa        pagopago   oceania
# 4    203.0          and           andorra  andorralavella    europe
# ..     ...          ...               ...             ...       ...
# 229  226.0          wlf   wallisandfutuna        mata-utu   oceania
# 230  172.0          esh     westernsahara         elaaiún    africa
# 231   46.0          yem             yemen           sanaa      asia
# 232   63.0          zmb            zambia          lusaka    africa
# 233   74.0          zwe          zimbabwe          harare    africa
#
#      2022_population  2020_population  2015_population  2010_population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# ...

# %%
df.columns.to_list()
# Out:
# ['rank',
#  'country_code',
#  'country/territory',
#  'capital',
#  'continent',
#  '2022_population',
#  '2020_population',
#  '2015_population',
#  '2010_population',
#  '2000_population',
#  '1990_population',
#  '1980_population',
#  '1970_population',
#  'area_(km²)',
#  'density_(per_km²)',
#  'growth_rate',
#  'world_population_percentage']

# %%
df['capital'].iat[56]
# Out:
# 'quito'

# %%
df.index
# Out:
# RangeIndex(start=0, stop=234, step=1)

# %%
df['2020_population'].loc[[0,4,8]]
# Out:
# 0    38972230.0
# 4       77700.0
# 8    45036032.0
# Name: 2020_population, dtype: float64

# %%
# First set the index to country_code
df = df.set_index('country_code')

# %%
df
# Out:
#                rank country/territory         capital continent  \
# country_code
# afg            36.0       afghanistan           kabul      asia
# alb           138.0           albania          tirana    europe
# dza            34.0           algeria         algiers    africa
# asm           213.0     americansamoa        pagopago   oceania
# and           203.0           andorra  andorralavella    europe
# ...             ...               ...             ...       ...
# wlf           226.0   wallisandfutuna        mata-utu   oceania
# esh           172.0     westernsahara         elaaiún    africa
# yem            46.0             yemen           sanaa      asia
# zmb            63.0            zambia          lusaka    africa
# zwe            74.0          zimbabwe          harare    africa
#
#               2022_population  2020_population  2015_population  \
# country_code
# afg                41128771.0       38972230.0       33753499.0
# ...

# %%
# Now we can access by country code
df.loc[['afg', 'and']].T
# Out:
# country_code                         afg             and
# rank                                36.0           203.0
# country/territory            afghanistan         andorra
# capital                            kabul  andorralavella
# continent                           asia          europe
# 2022_population               41128771.0         79824.0
# 2020_population               38972230.0         77700.0
# 2015_population               33753499.0         71746.0
# 2010_population               28189672.0         71519.0
# 2000_population               19542982.0         66097.0
# 1990_population               10694796.0         53569.0
# 1980_population               12486631.0         35611.0
# 1970_population               10752971.0         19860.0
# area_(km²)                      652230.0           468.0
# density_(per_km²)                63.0587        170.5641
# growth_rate                       1.0257            1.01
# ...

# %%
# mutilple row and single column

df.loc[['afg','and','arm'],'capital']
# Out:
# country_code
# afg             kabul
# and    andorralavella
# arm           yerevan
# Name: capital, dtype: object

# %%
df.index
# Out:
# Index(['afg', 'alb', 'dza', 'asm', 'and', 'ago', 'aia', 'atg', 'arg', 'arm',
#        ...
#        'uzb', 'vut', 'vat', 'ven', 'vnm', 'wlf', 'esh', 'yem', 'zmb', 'zwe'],
#       dtype='object', name='country_code', length=234)

# %%
df.columns
# Out:
# Index(['rank', 'country/territory', 'capital', 'continent', '2022_population',
#        '2020_population', '2015_population', '2010_population',
#        '2000_population', '1990_population', '1980_population',
#        '1970_population', 'area_(km²)', 'density_(per_km²)', 'growth_rate',
#        'world_population_percentage'],
#       dtype='object')

# %%
df.loc[:,'2015_population']
# Out:
# country_code
# afg    33753499.0
# alb     2882481.0
# dza    39543154.0
# asm       51368.0
# and       71746.0
#           ...
# wlf       12182.0
# esh      491824.0
# yem    28516545.0
# zmb    16248230.0
# zwe    14154937.0
# Name: 2015_population, Length: 234, dtype: float64

# %%
df.iloc[1, 0:]
# Out:
# rank                               138.0
# country/territory                albania
# capital                           tirana
# continent                         europe
# 2022_population                2842321.0
# 2020_population                2866849.0
# 2015_population                2882481.0
# 2010_population                2913399.0
# 2000_population                3182021.0
# 1990_population                3295066.0
# 1980_population                2941651.0
# 1970_population                2324731.0
# area_(km²)                       28748.0
# density_(per_km²)                98.8702
# growth_rate                       0.9957
# world_population_percentage         0.04
# Name: alb, dtype: object

# %%
df.reset_index()
# Out:
#     country_code   rank country/territory         capital continent  \
# 0            afg   36.0       afghanistan           kabul      asia
# 1            alb  138.0           albania          tirana    europe
# 2            dza   34.0           algeria         algiers    africa
# 3            asm  213.0     americansamoa        pagopago   oceania
# 4            and  203.0           andorra  andorralavella    europe
# ..           ...    ...               ...             ...       ...
# 229          wlf  226.0   wallisandfutuna        mata-utu   oceania
# 230          esh  172.0     westernsahara         elaaiún    africa
# 231          yem   46.0             yemen           sanaa      asia
# 232          zmb   63.0            zambia          lusaka    africa
# 233          zwe   74.0          zimbabwe          harare    africa
#
#      2022_population  2020_population  2015_population  2010_population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# ...

# %%
df.loc[df['rank']>100, 'capital']
# Out:
# country_code
# alb            tirana
# asm          pagopago
# and    andorralavella
# aia         thevalley
# atg       saintjohn’s
#             ...
# ury        montevideo
# vut         port-vila
# vat       vaticancity
# wlf          mata-utu
# esh           elaaiún
# Name: capital, Length: 134, dtype: object

# %%
df
# Out:
#                rank country/territory         capital continent  \
# country_code
# afg            36.0       afghanistan           kabul      asia
# alb           138.0           albania          tirana    europe
# dza            34.0           algeria         algiers    africa
# asm           213.0     americansamoa        pagopago   oceania
# and           203.0           andorra  andorralavella    europe
# ...             ...               ...             ...       ...
# wlf           226.0   wallisandfutuna        mata-utu   oceania
# esh           172.0     westernsahara         elaaiún    africa
# yem            46.0             yemen           sanaa      asia
# zmb            63.0            zambia          lusaka    africa
# zwe            74.0          zimbabwe          harare    africa
#
#               2022_population  2020_population  2015_population  \
# country_code
# afg                41128771.0       38972230.0       33753499.0
# ...

# %%
df[df['continent'].eq('africa')] & df['rank'].gt(100)]]
# Out:
#   Cell In[38], line 1
#     df[df['continent'].eq('africa')] & df['rank'].gt(100)]]
#                                                          ^
# SyntaxError: unmatched ']'

# %%
african_countries = df[df['continent'].eq('africa')]

# %%
rank_above_100 = df['rank'].gt(100)

# %%
m = african_countries[rank_above_100.reindex(african_countries.index).fillna(False)]
m
# Out:
#                rank       country/territory      capital continent  \
# country_code
# bwa           144.0                botswana     gaborone    africa
# cpv           171.0               capeverde        praia    africa
# caf           117.0  centralafricanrepublic       bangui    africa
# com           163.0                 comoros       moroni    africa
# dji           160.0                djibouti     djibouti    africa
# gnq           152.0        equatorialguinea       malabo    africa
# eri           132.0                 eritrea       asmara    africa
# swz           159.0                eswatini      mbabane    africa
# gab           146.0                   gabon   libreville    africa
# gmb           142.0                  gambia       banjul    africa
# gnb           149.0           guinea-bissau       bissau    africa
# lso           147.0                 lesotho       maseru    africa
# lbr           121.0                 liberia     monrovia    africa
# ...

# %%
m[m['2022_population'].between(1_000_000, 20_000_000)]
# Out:
#                rank       country/territory      capital continent  \
# country_code
# bwa           144.0                botswana     gaborone    africa
# caf           117.0  centralafricanrepublic       bangui    africa
# dji           160.0                djibouti     djibouti    africa
# gnq           152.0        equatorialguinea       malabo    africa
# eri           132.0                 eritrea       asmara    africa
# swz           159.0                eswatini      mbabane    africa
# gab           146.0                   gabon   libreville    africa
# gmb           142.0                  gambia       banjul    africa
# gnb           149.0           guinea-bissau       bissau    africa
# lso           147.0                 lesotho       maseru    africa
# lbr           121.0                 liberia     monrovia    africa
# lby           107.0                   libya      tripoli    africa
# mrt           126.0              mauritania   nouakchott    africa
# ...
