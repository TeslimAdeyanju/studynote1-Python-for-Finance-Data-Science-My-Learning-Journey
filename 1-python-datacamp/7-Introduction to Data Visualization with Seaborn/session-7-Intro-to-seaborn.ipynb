# %%
import matplotlib.pyplot as plt
import seaborn as sns 
import pandas as pd

# %%
uk = pd.read_excel(r'/Users/teslim/OneDrive/generaldata/1_uk_2024_election.xlsx', sheet_name='5')
uk
# Out:
#               CONSTITUENCY                    REGION          2019  \
# 0             Amber Valley             East Midlands  Conservative
# 1                 Ashfield             East Midlands  Conservative
# 2                Bassetlaw             East Midlands  Conservative
# 3                 Bolsover             East Midlands  Conservative
# 4        Boston & Skegness             East Midlands  Conservative
# ..                     ...                       ...           ...
# 645        Thirsk & Malton  Yorkshire and the Humber  Conservative
# 646   Wakefield & Rothwell  Yorkshire and the Humber  Conservative
# 647  Wetherby & Easingwold  Yorkshire and the Humber  Conservative
# 648           York Central  Yorkshire and the Humber        Labour
# 649             York Outer  Yorkshire and the Humber  Conservative
#
#              2024  TURNOUT %  SHARE %
# 0          Labour       60.3     37.0
# 1       Reform UK       58.6     42.8
# 2          Labour       57.4     41.2
# ...

# %%
uk.columns = uk.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

# %%
uk.columns
# Out:
# Index(['constituency', 'region', nan, nan, 'turnout_%', 'share_%'], dtype='object')

# %%
uk.columns.values[2]= 'year_2019'
uk.columns.values[3]='year_2024'

# %%
uk.head()
# Out:
#         constituency         region     year_2019  year_2024  turnout_%  \
# 0       Amber Valley  East Midlands  Conservative     Labour       60.3
# 1           Ashfield  East Midlands  Conservative  Reform UK       58.6
# 2          Bassetlaw  East Midlands  Conservative     Labour       57.4
# 3           Bolsover  East Midlands  Conservative     Labour       56.5
# 4  Boston & Skegness  East Midlands  Conservative  Reform UK       53.4
#
#    share_%
# 0     37.0
# 1     42.8
# 2     41.2
# 3     40.5
# 4     38.4

# %%
uk.nunique()
# Out:
# constituency    650
# region           12
# year_2019        12
# year_2024        16
# turnout_%       253
# share_%         256
# dtype: int64

# %%
fig, ax = plt.subplots(figsize=(20, 6))

plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 650 entries, 0 to 649
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CONSTITUENCY  650 non-null    object
#  1   REGION        650 non-null    object
#  2   2019          650 non-null    object
#  3   2024          650 non-null    object
#  4   TURNOUT %     649 non-null    float64
#  5   SHARE %       649 non-null    float64
# dtypes: float64(2), object(4)
# memory usage: 30.6+ KB

# %%
sns.countplot(data=df, y='REGION')
# Out:
# <Axes: xlabel='count', ylabel='REGION'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Sample Data
data = {
    'Category': ['A', 'A', 'A', 'B', 'B', 'B', 'C', 'C', 'C'],
    'SubCategory': ['X', 'Y', 'X', 'Y', 'Y', 'X', 'X', 'Y', 'Y']
}
df = pd.DataFrame(data)

# Count Plot with hue
sns.countplot(data=df, x='Category', hue='SubCategory')
plt.title("Count Plot with hue")
plt.xlabel("Category")
plt.ylabel("Count")
plt.legend(title="SubCategory")
plt.show()

# %%
sns.countplot(data=df, x='Category', order=['C', 'B', 'A'])
plt.title("Ordered Count Plot")
plt.show()

# %%
sns.countplot(
    data=df,
    x='Category',
    palette='viridis',
    order=['C', 'B', 'A'],
    hue='SubCategory'
)
plt.show()

# %%
sns.countplot(data=df, x='Category', order=['C', 'B', 'A'])
plt.title("Ordered Count Plot")
plt.show()

# %%
sns.countplot(
    data=df,
    x='Category',
    hue='SubCategory',
    hue_order=['Y', 'X']
)
plt.title("Count Plot with Hue Order")
plt.legend(title="SubCategory")
plt.show()

# %%
sns.countplot(data=df, x='Category', orient='v')  # Vertical
plt.title("Vertical Orientation")
plt.show()

sns.countplot(data=df, y='Category', orient='h')  # Horizontal
plt.title("Horizontal Orientation")
plt.show()

# %%
sns.countplot(data=df, x='Category', palette='Spectral', hue='SubCategory')
plt.title("Count Plot with Custom Palette")
plt.show()

# %%
import seaborn as sns
sns.palplot(sns.color_palette("Oranges", n_colors=5))
plt.show()

# %%
sns.choose_colorbrewer_palette(data_type='qualitative', as_cmap=False)
# Out:
# interactive(children=(Dropdown(description='name', options=('Set1', 'Set2', 'Set3', 'Paired', 'Accent', 'Paste…
# [(0.8941176470588236, 0.10196078431372549, 0.10980392156862745),
#  (0.21568627450980393, 0.49411764705882355, 0.7215686274509804),
#  (0.30196078431372547, 0.6862745098039216, 0.2901960784313726),
#  (0.596078431372549, 0.3058823529411765, 0.6392156862745098),
#  (1.0, 0.4980392156862745, 0.0),
#  (1.0, 1.0, 0.2),
#  (0.6509803921568628, 0.33725490196078434, 0.1568627450980392),
#  (0.9686274509803922, 0.5058823529411764, 0.7490196078431373),
#  (0.6, 0.6, 0.6)]

# %%
sns.countplot(data=df, x='Category', palette='PuOr', hue='SubCategory')
plt.title("Using Sequential Blues Palette")
plt.show()

# %%
custom_palette = ['#FF5733', '#33FF57', '#3357FF']

sns.countplot(data=df, x='Category', palette=custom_palette, hue='SubCategory')
plt.title("Using Custom Palette")
plt.show()
# Out:
# /var/folders/v9/v9j8bf6j2r5cr97thvfgxxyh0000gn/T/ipykernel_39595/3290183505.py:3: UserWarning: The palette list has more values (3) than needed (2), which may not be intended.
#   sns.countplot(data=df, x='Category', palette=custom_palette, hue='SubCategory')

# %%
sns.countplot(data=df, x='Category', color='red')
plt.title("Single Color Count Plot")
plt.show()

# %%
sns.countplot(data=df, y='Category', palette='coolwarm', saturation=0.5, hue='SubCategory')
plt.title("Count Plot with Low Saturation")
plt.show()

# %%
sns.countplot(data=df, x='Category', width=0.2, hue='SubCategory')
plt.title("Count Plot with Thin Bars")
plt.show()

# %%
sns.countplot(data=df, x='Category', hue='SubCategory', dodge=False)
plt.title("Count Plot with Overlaid Bars")
plt.legend(title="SubCategory")
plt.show()

# %%
sns.countplot(data=df, x='Category', hue='SubCategory', dodge=True)
plt.title("Count Plot with Overlaid Bars")
plt.legend(title="SubCategory")
plt.show()

# %%
plt.style.use('ggplot')
fig, ax = plt.subplots(figsize=(20, 6))
sns.countplot(data=df, x='Category', ax=ax, palette='coolwarm', hue='SubCategory')
ax.set_title("Count Plot on Specific Axes")
plt.show()

# %%
plt.style.use('default')

# %%
sns.countplot(
    data=df,
    x='Category',
    hue='SubCategory',
    order=['C', 'A', 'B'],
    hue_order=['Y', 'X'],
    palette='viridis',
    saturation=0.8,
    width=0.6
)
plt.title("Comprehensive Count Plot")
plt.legend(title="SubCategory")
plt.show()

# %%
from seaborn import load_dataset

# Load Titanic dataset
titanic = load_dataset('titanic')

# Count plot with multiple features
sns.countplot(
    data=titanic,
    x='class',
    hue='sex',
    palette='coolwarm',
    order=['First', 'Second', 'Third'],
    saturation=0.9
)
plt.title("Titanic Class Distribution by Gender")
plt.legend(title="Gender")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load Titanic dataset
titanic = sns.load_dataset('titanic')

# Display first few rows of the dataset
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.scatterplot(data=titanic, x='age', y='fare')
plt.title("Basic Scatter Plot")
plt.show()

# %%
sns.scatterplot(data=titanic, x='age', y='fare', hue='survived')
plt.title("Scatter Plot with Hue")
plt.legend(title="Survived")
plt.show()

# %%
sns.scatterplot(data=titanic, x='age', y='fare', hue='survived', style='sex')
plt.title("Scatter Plot with Hue and Style")
plt.legend(title="Survived/Class")
plt.show()

# %%
sns.scatterplot(data=titanic, x='age', y='fare', size='sibsp', sizes=(20, 200))
plt.title("Scatter Plot with Variable Sizes")
plt.legend(title="Number of Siblings/Spouses")
plt.show()

# %%
sns.scatterplot(data=titanic, x='age', y='fare', hue='survived', palette='dark')
plt.title("Scatter Plot with Custom Palette")
plt.legend(title="Survived")
plt.show()

# %%
sns.scatterplot(data=titanic, x='age', y='fare', hue='survived', hue_order=[1, 0], palette='dark')
plt.title("Scatter Plot with Ordered Hue")
plt.legend(title="Survived")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20
                                , 6))
sns.scatterplot(
    data=titanic, 
    x='age', 
    y='fare', 
    hue='survived', 
    style='class', 
    size='sibsp', 
    sizes=(30, 300), 
    palette='dark'
)
plt.title("Comprehensive Scatter Plot")
plt.legend(title="Survived/Class/SibSp")
plt.show()

# %%
sns.scatterplot(data=titanic, x='age', y='fare', alpha=0.3, palette='dark', hue='sex', size='parch', sizes=(20, 200))
plt.title("Scatter Plot with Transparency")
plt.show()

# %%
sns.scatterplot(data=titanic, x='age', y='fare', size='sibsp', sizes=(50, 800))
plt.title("Scatter Plot with Custom Marker Sizes")
plt.legend(title="SibSp")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20
                                , 6))
sns.scatterplot(data=titanic, x='age', y='fare', ax=ax, hue='survived', style='class')
ax.set_title("Scatter Plot on Specific Axes")
plt.show()

# %%
df
# Out:
#   Category SubCategory
# 0        A           X
# 1        A           Y
# 2        A           X
# 3        B           Y
# 4        B           Y
# 5        B           X
# 6        C           X
# 7        C           Y
# 8        C           Y

# %%
FILE_PATH = R'/'

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip', hue='smoker')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load datasets
tips = sns.load_dataset('tips')
fmri = sns.load_dataset('fmri')
penguins = sns.load_dataset('penguins')
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(data=tips, x='total_bill', y='tip', kind='scatter')
plt.title("Basic Scatter Plot")
plt.show()

# %%
fmri = sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(data=tips, x='total_bill', y='tip', kind='scatter')
plt.title("Basic Scatter Plot")
plt.show()

# %%
sns.relplot(data=fmri, x='timepoint', y='signal', kind='line', errorbar=None)
plt.title("Basic Line Plot")
plt.show()

# %%
sns.relplot(data=fmri, x='timepoint', y='signal', kind='line', errorbar='sd')
plt.title("Basic Line Plot")
plt.show()

# %%
sns.relplot(data=tips, x='total_bill', y='tip', hue='sex', kind='scatter')
plt.title("Scatter Plot with Hue")
plt.show()

# %%
sns.relplot(data=tips, x='total_bill',hue='sex', y='tip', kind='scatter')

# %%
sns.relplot(data=fmri, x='timepoint', y='signal', hue='region', kind='line')
plt.title("Line Plot with Hue")
plt.show()

# %%
sns.relplot(data=tips, x='total_bill', y='tip', size='size', sizes=(20, 200), kind='scatter')
plt.title("Scatter Plot with Variable Sizes")
plt.show()

# %%
sns.relplot(data=tips, x='total_bill', y='tip', style='sex', kind='scatter')
plt.title("Scatter Plot with Style")
plt.show()

# %%
sns.relplot(data=penguins, x='bill_length_mm', y='bill_depth_mm', col='species', kind='scatter')
plt.suptitle("Faceted Scatter Plot", y=1.05)
plt.show()

# %%
sns.relplot(data = tips, x='total_bill', y='tip', col='sex', kind='scatter')
plt.suptitle("Faceted Scatter Plot", y=1.05)
plt.show()

# %%
sns.relplot(data=fmri, x='timepoint', y='signal', hue='event', kind='line', col='region')
plt.suptitle("Faceted Line Plot", y=1.05)
plt.show()

# %%
sns.relplot(data=fmri, x='timepoint', y='signal', hue='event', style='event', kind='line', dashes=False)
plt.title("Line Plot with Custom Dashes")
plt.show()

# %%
sns.relplot(data=tips, x='total_bill', y='tip', alpha=0.6, kind='scatter')
plt.title("Scatter Plot with Transparency")
plt.show()

# %%
sns.relplot(data=penguins, 
            x='bill_length_mm', 
            y='bill_depth_mm', 
            row='sex', 
            col='species', 
            kind='scatter')
            
plt.suptitle("Faceted Scatter Plot with Row and Column", y=1.05)
plt.show()

# %%
sns.relplot(data=tips, 
            x='total_bill', 
            y='tip', 
            size='size', 
            sizes=(50, 300), 
            kind='scatter')
            
            
plt.title("Scatter Plot with Custom Marker Sizes")
plt.show()

# %%
sns.relplot(data = tips, 
            x='total_bill', 
            y='tip', 
            row ='sex', 
            kind='scatter')
            
            
plt.suptitle("Faceted Scatter Plot", y=1.05)
plt.show()

# %%
sns.relplot(data=tips, 
            x="total_bill", 
            y="tip", 
            kind="scatter", 
            col="day", 
            col_wrap=4)

plt.show()

# %%
sns.relplot(data=tips, 
						x="total_bill",
						y="tip", 
						kind="scatter", 
						col="day", 
						col_wrap=2, 
						col_order=["Thur", "Fri", "Sat", "Sun"])

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
data = sns.load_dataset('tips')
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(data=data, 
            x='time', 
            y='total_bill', 
            kind='box', 
            fliersize=0)
            
            
plt.title("Box Plot of Total Bill by Day")
plt.show()

# %%
sns.catplot(data=data, 
            x='time', 
            y='total_bill', 
            kind='box')
            
            
plt.title("Box Plot of Total Bill by Day")
plt.show()

# %%
sns.catplot(data=data, 
            x='day', 
            y='total_bill', 
            kind='strip', 
            jitter=True)
            
plt.title("Strip Plot of Total Bill by Day")
plt.show()

# %%
sns.catplot(data=data, 
            x='day', 
            y='total_bill', 
            kind='swarm', 
            hue='sex')
            
plt.title("Swarm Plot of Total Bill by Day with Hue")
plt.show()

# %%
sns.catplot(data=data, 
            x='day', 
            y='total_bill', 
            kind='box', 
            hue='smoker',
              fliersize=0)
            
plt.title("Box Plot of Total Bill by Day")
plt.show()

# %%
sns.catplot(data=data, 
            x='day', 
            y='total_bill', 
            kind='violin', 
            hue='smoker', 
            split=True)
            
plt.title("Violin Plot of Total Bill by Day")
plt.show()

# %%
sns.catplot(data=data, 
            x='day', 
            y='total_bill', 
            kind='boxen')
            
plt.title("Boxen Plot of Total Bill by Day")
plt.show()

# %%
sns.catplot(data=data, 
            x='day', 
            y='total_bill', 
            kind='bar', 
            hue='time', 
            errorbar='sd')
plt.title("Bar Plot of Total Bill by Day")
plt.show()

# %%
sns.catplot(data=data, 
            x='day', 
            y='total_bill', 
            kind='point', 
            hue='time')
plt.title("Point Plot of Total Bill by Day")
plt.show()

# %%
sns.catplot(data=data, 
            x='day', 
            kind='count', 
            hue='sex')
plt.title("Count Plot of Days with Hue")
plt.show()

# %%
sns.catplot(
    data=data,
    x='day',
    y='total_bill',
    hue='smoker',
    kind='bar',
    order=['Sat', 'Sun', 'Thur', 'Fri'],
    hue_order=['Yes', 'No']
)
plt.show()

# %%
sns.catplot(data=data, 
            x='day', 
            y='total_bill', 
            kind='bar', 
            hue='smoker', 
            palette='coolwarm')
plt.show()

# %%
sns.catplot(data=data, 
            x='day', 
            y='total_bill', 
            kind='bar', 
            height=5, 
            aspect=1.1)
plt.show()

# %%
sns.catplot(data=data, 
            x='day', 
            y='total_bill', 
            col='sex', 
            kind='bar', 
            margin_titles=True)
plt.show()

# %%
sns.catplot(data=data, 
            x='day', 
            y='total_bill', 
            kind='violin', 
            hue='smoker', 
            legend_out=False)
plt.show()

# %%
sns.catplot(data=data, 
            x='day', 
            y='total_bill', 
            col='time', 
            kind='bar', 
            sharey=False)
plt.show()

# %%
sns.catplot(data=data, 
            x='day', 
            y='total_bill', 
            hue='sex', 
            kind='swarm', 
            dodge=True)
plt.show()

# %%
sns.catplot(
    data=data,
    x='day',
    y='total_bill',
    hue='smoker',
    col='sex',
    row='time',
    kind='bar',
    height=6,
    aspect=1.2,
    palette='muted',
    margin_titles=True,
    sharey=False
)
plt.show()

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import seaborn as sns

# %%
# Out:
# matplotlib.axes._axes.Axes

# %%
import seaborn as sns

# %%
fmri = sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
g = sns.catplot(data=fmri, x='timepoint', y='signal', kind='box')

g.fig.suptitle("Box Plot of Signal by Timepoint", y=1.05)

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

fig = plt.figure(figsize=(8, 6))
grid = GridSpec(3, 3, figure=fig)  # Define a 3x3 grid

# Create subplots with custom sizes
ax1 = fig.add_subplot(grid[0, 0])        # Top-left cell
ax2 = fig.add_subplot(grid[0, 1:])      # Top-right two cells
ax3 = fig.add_subplot(grid[1:, 0])      # Bottom-left two rows
ax4 = fig.add_subplot(grid[1:, 1:])     # Bottom-right section

plt.show()

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 2, figsize=(8, 6))  # 2x2 grid of subplots
axes[0, 0].plot([1, 2, 3], [1, 4, 9])           # Top-left plot
axes[0, 1].plot([1, 2, 3], [9, 4, 1])           # Top-right plot
axes[1, 0].plot([1, 2, 3], [1, 2, 3])           # Bottom-left plot
axes[1, 1].plot([1, 2, 3], [3, 2, 1])           # Bottom-right plot

plt.show()

# %%
for i in sns.get_dataset_names():
    print(i)
# Out:
# anagrams
# anscombe
# attention
# brain_networks
# car_crashes
# diamonds
# dots
# dowjones
# exercise
# flights
# fmri
# geyser
# glue
# healthexp
# iris
# mpg
# penguins
# planets
# seaice
# taxis
# tips
# titanic

# %%
df = sns.load_dataset('glue')

# %%
df.columns
# Out:
# Index(['Model', 'Year', 'Encoder', 'Task', 'Score'], dtype='object')

# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import seaborn as sns

# Load the dataset
penguins = sns.load_dataset("penguins")

# Create the figure and GridSpec
fig = plt.figure(figsize=(12, 8))
grid = GridSpec(3, 3, figure=fig)

# Add subplots with custom sizes
ax1 = fig.add_subplot(grid[0, 0])  # Top-left cell
sns.histplot(penguins['flipper_length_mm'], ax=ax1, kde=True, color='blue')
ax1.set_title('Flipper Length')

ax2 = fig.add_subplot(grid[0, 1:])  # Top-right two cells
sns.scatterplot(data=penguins, x='bill_length_mm', y='bill_depth_mm', hue='species', ax=ax2)
ax2.set_title('Bill Length vs. Depth')

ax3 = fig.add_subplot(grid[1:, 0])  # Bottom-left two rows
sns.boxplot(data=penguins, x='species', y='body_mass_g', ax=ax3, palette='Set2')
ax3.set_title('Body Mass by Species')

ax4 = fig.add_subplot(grid[1:, 1:])  # Bottom-right section
sns.heatmap(penguins.corr(numeric_only=True), annot=True, cmap='coolwarm', ax=ax4)
ax4.set_title('Correlation Heatmap')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/v9/v9j8bf6j2r5cr97thvfgxxyh0000gn/T/ipykernel_43120/2398721293.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=penguins, x='species', y='body_mass_g', ax=ax3, palette='Set2')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
penguins = sns.load_dataset("penguins")

# Create a 2x2 grid of subplots
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

# Plot in each subplot
sns.histplot(penguins['flipper_length_mm'], ax=axes[0, 0], kde=True, color='blue')
axes[0, 0].set_title('Flipper Length')

sns.scatterplot(data=penguins, x='bill_length_mm', y='bill_depth_mm', hue='species', ax=axes[0, 1])
axes[0, 1].set_title('Bill Length vs. Depth')

sns.boxplot(data=penguins, x='species', y='body_mass_g', ax=axes[1, 0], palette='Set2')
axes[1, 0].set_title('Body Mass by Species')

sns.heatmap(penguins.corr(numeric_only=True), annot=True, cmap='coolwarm', ax=axes[1, 1])
axes[1, 1].set_title('Correlation Heatmap')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/v9/v9j8bf6j2r5cr97thvfgxxyh0000gn/T/ipykernel_43120/2668571917.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=penguins, x='species', y='body_mass_g', ax=axes[1, 0], palette='Set2')

# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import seaborn as sns

# Load the dataset
penguins = sns.load_dataset("penguins")

# Create the figure and GridSpec
fig = plt.figure(figsize=(12, 8))
grid = GridSpec(3, 3, figure=fig)

# Add subplots with custom sizes
ax1 = fig.add_subplot(grid[0, 0])  # Top-left cell
sns.histplot(penguins['flipper_length_mm'], ax=ax1, kde=True, color='blue')
ax1.set_title('Flipper Length')

ax2 = fig.add_subplot(grid[0, 1:])  # Top-right two cells
sns.scatterplot(data=penguins, x='bill_length_mm', y='bill_depth_mm', hue='species', ax=ax2)
ax2.set_title('Bill Length vs. Depth')

ax3 = fig.add_subplot(grid[1:, 0])  # Bottom-left two rows
sns.boxplot(data=penguins, x='species', y='body_mass_g', ax=ax3, palette='Set2')
ax3.set_title('Body Mass by Species')

ax4 = fig.add_subplot(grid[1:, 1:])  # Bottom-right section
sns.heatmap(penguins.corr(numeric_only=True), annot=True, cmap='coolwarm', ax=ax4)
ax4.set_title('Correlation Heatmap')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/v9/v9j8bf6j2r5cr97thvfgxxyh0000gn/T/ipykernel_43120/2398721293.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=penguins, x='species', y='body_mass_g', ax=ax3, palette='Set2')

# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import seaborn as sns

# Load the dataset
penguins = sns.load_dataset("penguins")

# Create the figure
fig = plt.figure(figsize=(14, 8))
grid = GridSpec(3, 4, figure=fig)

# GridSpec: Custom-sized plots
ax1 = fig.add_subplot(grid[0, 0:2])  # Top-left two columns
sns.histplot(penguins['flipper_length_mm'], ax=ax1, kde=True, color='blue')
ax1.set_title('Flipper Length')

ax2 = fig.add_subplot(grid[0, 2:])  # Top-right two columns
sns.scatterplot(data=penguins, x='bill_length_mm', y='bill_depth_mm', hue='species', ax=ax2)
ax2.set_title('Bill Length vs. Depth')

# plt.subplots: Uniform grid below
axes = [fig.add_subplot(grid[i, j]) for i in range(1, 3) for j in range(4)]
for i, ax in enumerate(axes):
    sns.boxplot(data=penguins, x='species', y='body_mass_g', ax=ax, palette='Set2')
    ax.set_title(f'Subplot {i+1}')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/v9/v9j8bf6j2r5cr97thvfgxxyh0000gn/T/ipykernel_43120/4136751418.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=penguins, x='species', y='body_mass_g', ax=ax, palette='Set2')
# /var/folders/v9/v9j8bf6j2r5cr97thvfgxxyh0000gn/T/ipykernel_43120/4136751418.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=penguins, x='species', y='body_mass_g', ax=ax, palette='Set2')
# /var/folders/v9/v9j8bf6j2r5cr97thvfgxxyh0000gn/T/ipykernel_43120/4136751418.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10, 6))  # Create a figure of size 8x6 inches
plt.show()

# %%
fig = plt.figure(figsize=(10, 6))  # Create a figure of size 10x6 inches
ax = fig.add_subplot(111)  # Add an axes to the figure
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

fig = plt.figure(figsize=(8, 6))
gs = GridSpec(3, 3, figure=fig)

ax1 = fig.add_subplot(gs[0, :])       # First row, spanning all columns
ax2 = fig.add_subplot(gs[1, :-1])    # Second row, first two columns
ax3 = fig.add_subplot(gs[1:, -1])    # Second and third rows, last column
ax4 = fig.add_subplot(gs[2, :-1])    # Last row, first two columns

plt.show()

# %%
fig = plt.figure(figsize=(10, 6))  # Create a figure of size 10x6 inches
ax = fig.add_subplot(111)  # Add an axes to the figure
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import seaborn as sns

# Load the dataset
penguins = sns.load_dataset("penguins")

# Create the figure and GridSpec
fig = plt.figure(figsize=(12, 8))
grid = GridSpec(3, 3, figure=fig)

# Add subplots with custom sizes
ax1 = fig.add_subplot(grid[0, 0])  # Top-left cell
sns.histplot(penguins['flipper_length_mm'], ax=ax1, kde=True, color='blue')
ax1.set_title('Flipper Length')

ax2 = fig.add_subplot(grid[0, 1:])  # Top-right two cells
sns.scatterplot(data=penguins, x='bill_length_mm', y='bill_depth_mm', hue='species', ax=ax2)
ax2.set_title('Bill Length vs. Depth')

ax3 = fig.add_subplot(grid[1:, 0])  # Bottom-left two rows
sns.boxplot(data=penguins, x='species', y='body_mass_g', ax=ax3, palette='Set2')
ax3.set_title('Body Mass by Species')

ax4 = fig.add_subplot(grid[1:, 1:])  # Bottom-right section
sns.heatmap(penguins.corr(numeric_only=True), annot=True, cmap='coolwarm', ax=ax4)
ax4.set_title('Correlation Heatmap')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/v9/v9j8bf6j2r5cr97thvfgxxyh0000gn/T/ipykernel_43120/1827397098.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=penguins, x='species', y='body_mass_g', ax=ax3, palette='Set2')
