# %%
import sys

# %%
for  path in sys.path:
    print(path)
# Out:
# /Users/teslim/.local/share/uv/python/cpython-3.11.15-macos-aarch64-none/lib/python311.zip
# /Users/teslim/.local/share/uv/python/cpython-3.11.15-macos-aarch64-none/lib/python3.11
# /Users/teslim/.local/share/uv/python/cpython-3.11-macos-aarch64-none/lib/python3.11/lib-dynload
#
# /Users/teslim/TeslimWorkSpace/MainClass/1-Modules-Python/.venv/lib/python3.11/site-packages

# %%
import greetings

# Use the functions
message1 = greetings.say_hello("Alice")
print(message1)
# Out:
# Greetings module v1.0.0 loaded successfully!
# Hello, Alice! Welcome to Python modules!

# %%
import greetings

# Use the functions
message1 = greetings.say_hello("Alice")
print(message1)

message2 = greetings.say_goodbye("Bob")
print(message2)

# Access module variables
print(f"Module version: {greetings.MODULE_VERSION}")
print(f"Default greeting: {greetings.DEFAULT_GREETING}")

# Access module data
stats = greetings.get_greeting_stats()
print(f"Module stats: {stats}")
# Out:
# Hello, Alice! Welcome to Python modules!
# Goodbye, Bob! Thanks for using our module!
# Module version: 1.0.0
# Default greeting: Hello, World!
# Module stats: {'total_greetings': 2, 'languages': ['English'], 'author': 'Your Name'}
# Hello, Alice! Welcome to Python modules!
# Goodbye, Bob! Thanks for using our module!
# Module version: 1.0.0
# Default greeting: Hello, World!
# Module stats: {'total_greetings': 2, 'languages': ['English'], 'author': 'Your Name'}

# %%
dir(greetings)  # List all attributes and methods in the greetings module
# Out:
# ['DEFAULT_GREETING',
#  'MODULE_VERSION',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'get_greeting_stats',
#  'say_goodbye',
#  'say_hello']

# %%
import test_module
# Out:
# Hello, Alice! Welcome to Python modules!
